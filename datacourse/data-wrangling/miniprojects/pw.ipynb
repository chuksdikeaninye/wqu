# %%
# %logstop
# %logstart -rtq ~/.logs/pw.py append
import seaborn as sns
sns.set()

# %%
from static_grader import grader

# %% [markdown]
# # PW Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to use basic Python data structures, define functions, and control program flow. We will be using these concepts to perform some fundamental data wrangling tasks such as joining data sets together, splitting data into groups, and aggregating data into summary statistics.
# **Please do not use `pandas` or `numpy` to answer these questions.**
#
# We will be working with medical data from the British NHS on prescription drugs. Since this is real data, it contains many ambiguities that we will need to confront in our analysis. This is commonplace in data science, and is one of the lessons you will learn in this miniproject.

# %% [markdown]
# ## Downloading the data
#
# We first need to download the data we'll be using from Amazon S3:

# %%
# %%bash
# mkdir pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/201701scripts_sample.json.gz -nc -P ./pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/practices.json.gz -nc -P ./pw-data
# Out:
# mkdir: cannot create directory ‘pw-data’: File exists
# File ‘./pw-data/201701scripts_sample.json.gz’ already there; not retrieving.
#
# File ‘./pw-data/practices.json.gz’ already there; not retrieving.

# %% [markdown]
# ## Loading the data
#
# The first step of the project is to read in the data. We will discuss reading and writing various kinds of files later in the course, but the code below should get you started.

# %%
import gzip
import simplejson as json

# %%
with gzip.open('./pw-data/201701scripts_sample.json.gz', 'rb') as f:
    scripts = json.load(f)

with gzip.open('./pw-data/practices.json.gz', 'rb') as f:
    practices = json.load(f)

# %% [markdown]
# This data set comes from Britain's National Health Service. The `scripts` variable is a list of prescriptions issued by NHS doctors. Each prescription is represented by a dictionary with various data fields: `'practice'`, `'bnf_code'`, `'bnf_name'`, `'quantity'`, `'items'`, `'nic'`, and `'act_cost'`.

# %%
scripts[:2]
# Out:
# [{'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'N81013',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81013',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500}]

# %%
len(scripts)
# Out:
# 382726

# %% [markdown]
# A [glossary of terms](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10686/Download-glossary-of-terms-for-GP-prescribing---presentation-level/pdf/PLP_Presentation_Level_Glossary_April_2015.pdf/) and [FAQ](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10048/FAQs-Practice-Level-Prescribingpdf/pdf/PLP_FAQs_April_2015.pdf/) is available from the NHS regarding the data. Below we supply a data dictionary briefly describing what these fields mean.
#
# | Data field |Description|
# |:----------:|-----------|
# |`'practice'`|Code designating the medical practice issuing the prescription|
# |`'bnf_code'`|British National Formulary drug code|
# |`'bnf_name'`|British National Formulary drug name|
# |`'quantity'`|Number of capsules/quantity of liquid/grams of powder prescribed|
# | `'items'`  |Number of refills (e.g. if `'quantity'` is 30 capsules, 3 `'items'` means 3 bottles of 30 capsules)|
# |  `'nic'`   |Net ingredient cost|
# |`'act_cost'`|Total cost including containers, fees, and discounts|

# %% [markdown]
# The `practices` variable is a list of member medical practices of the NHS. Each practice is represented by a dictionary containing identifying information for the medical practice. Most of the data fields are self-explanatory. Notice the values in the `'code'` field of `practices` match the values in the `'practice'` field of `scripts`.

# %%
practices[:2]
# Out:
# [{'code': 'A81001',
#   'name': 'THE DENSHAM SURGERY',
#   'addr_1': 'THE HEALTH CENTRE',
#   'addr_2': 'LAWSON STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 1HU'},
#  {'code': 'A81002',
#   'name': 'QUEENS PARK MEDICAL CENTRE',
#   'addr_1': 'QUEENS PARK MEDICAL CTR',
#   'addr_2': 'FARRER STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 2AW'}]

# %% [markdown]
# In the following questions we will ask you to explore this data set. You may need to combine pieces of the data set together in order to answer some questions. Not every element of the data set will be used in answering the questions.

# %% [markdown]
# ## Question 1: summary_statistics
#
# Our beneficiary data (`scripts`) contains quantitative data on the number of items dispensed (`'items'`), the total quantity of item dispensed (`'quantity'`), the net cost of the ingredients (`'nic'`), and the actual cost to the patient (`'act_cost'`). Whenever working with a new data set, it can be useful to calculate summary statistics to develop a feeling for the volume and character of the data. This makes it easier to spot trends and significant features during further stages of analysis.
#
# Calculate the sum, mean, standard deviation, and quartile statistics for each of these quantities. Format your results for each quantity as a list: `[sum, mean, standard deviation, 1st quartile, median, 3rd quartile]`. We'll create a `tuple` with these lists for each quantity as a final result.

# %%
def mean(values, precision=None):
    #values is a python list. we want to return the mean of the values list
    if precision:
        return round(sum(values) / len(values), precision)
    else:
        return sum(values)/ len(values)

# %%
mean([10, 20 ,30])
# Out:
# 20.0

# %%
from math import sqrt

def std(values):
    #values is a python list. we want to return the standard deviation of the values list
    avg = mean(values)
    return sqrt(sum([(number - avg)**2 for number in values])/len(values))

# %%
from math import ceil

def quartile(values, q):
    #returns the element in values for the q-th quartile.
    #Note: Assume that the value is already sorted
    #q is a floating point number.
    
    index = ceil(q * len(values))
    return values[index]

# %%
[d ['nic'] for d in scripts]
# Out:
# [5.98,
#  1.95,
#  64.51,
#  9.21,
#  28.92,
#  82.62,
#  13.47,
#  64.0,
#  3.9,
#  19.48,
#  37.67,
#  112.5,
#  66.26,
#  126.6,
#  25.81,
#  20.46,
#  34.59,
#  35.26,
#  69.6,
#  39.03,
#  18.39,
#  14.62,
#  29.15,
#  3.31,
#  40.8,
#  23.76,
#  370.85,
#  105.42,
#  6.3,
#  30.78,
#  5.5,
#  382.54,
#  30.0,
#  17.8,
#  24.04,
#  73.13,
#  41.76,
#  22.4,
#  9.5,
#  43.33,
#  7.02,
#  17.2,
#  68.86,
#  40.01,
#  73.78,
#  172.14,
#  40.01,
#  68.86,
#  42.95,
#  494.0,
#  128.27,
#  37.44,
#  33.18,
#  78.0,
#  187.0,
#  60.39,
#  10.88,
#  32.2,
#  28.1,
#  279.73,
#  1.04,
#  0.1,
#  19.74,
#  7.1,
#  46.85,
#  80.44,
#  38.6,
#  7.72,
#  42.63,
#  275.33,
#  9.97,
#  5.68,
#  55.72,
#  4.98,
#  11.76,
#  5.52,
#  153.44,
#  111.31,
#  62.6,
#  14.56,
#  20.02,
#  7.32,
#  88.81,
#  16.05,
#  105.76,
#  81.18,
#  6.98,
#  45.31,
#  48.27,
#  6.05,
#  22.47,
#  6.8,
#  14.0,
#  10.35,
#  16.11,
#  4.84,
#  2.4,
#  4.59,
#  8.62,
#  12.6,
#  21.94,
#  44.14,
#  9.75,
#  38.72,
#  10.22,
#  32.82,
#  23.7,
#  68.7,
#  5.2,
#  12.96,
#  70.3,
#  2.35,
#  21.93,
#  5.25,
#  207.93,
#  117.12,
#  166.7,
#  66.55,
#  8.81,
#  6.12,
#  6.6,
#  3.8,
#  6.42,
#  7.28,
#  21.49,
#  14.36,
#  14.2,
#  23.29,
#  42.2,
#  74.76,
#  85.0,
#  99.8,
#  3.71,
#  3.46,
#  0.84,
#  0.9,
#  8.82,
#  10.92,
#  2.13,
#  16.78,
#  31.62,
#  144.43,
#  9.0,
#  5.08,
#  8.04,
#  42.78,
#  167.95,
#  126.44,
#  324.51,
#  6.6,
#  2.3,
#  2.48,
#  7.44,
#  4.65,
#  29.04,
#  15.68,
#  10.35,
#  3.18,
#  3.88,
#  4.89,
#  22.4,
#  47.32,
#  83.17,
#  2.62,
#  1.46,
#  16.52,
#  52.73,
#  117.0,
#  7.78,
#  10.74,
#  1.83,
#  6.2,
#  13.15,
#  11.9,
#  8.53,
#  8.86,
#  30.38,
#  2.88,
#  27.0,
#  6.75,
#  47.27,
#  34.93,
#  121.7,
#  108.87,
#  9.14,
#  14.16,
#  31.45,
#  12.38,
#  14.54,
#  12.58,
#  4.73,
#  18.28,
#  10.37,
#  37.89,
#  73.58,
#  25.24,
#  2.17,
#  118.25,
#  24.56,
#  57.9,
#  23.1,
#  6.85,
#  9.03,
#  11.23,
#  25.69,
#  102.75,
#  167.08,
#  39.53,
#  5.98,
#  1.98,
#  7.71,
#  24.74,
#  4.24,
#  261.11,
#  40.17,
#  71.4,
#  73.85,
#  42.38,
#  37.0,
#  3.04,
#  51.0,
#  844.2,
#  193.8,
#  904.4,
#  199.1,
#  30.5,
#  14.44,
#  146.35,
#  20.12,
#  382.2,
#  8.46,
#  180.3,
#  156.12,
#  108.18,
#  14.24,
#  37.4,
#  153.04,
#  117.55,
#  89.75,
#  21.36,
#  25.19,
#  236.79,
#  4.54,
#  14.09,
#  9.72,
#  53.52,
#  17.4,
#  23.4,
#  76.58,
#  21.86,
#  87.6,
#  236.98,
#  10.44,
#  112.5,
#  14.4,
#  12.6,
#  7.2,
#  292.5,
#  18.15,
#  2.92,
#  12.6,
#  105.33,
#  204.82,
#  87.78,
#  13.84,
#  20.76,
#  33.36,
#  5.56,
#  209.22,
#  1172.5,
#  33.5,
#  23.0,
#  28.6,
#  27.5,
#  18.0,
#  4.22,
#  2.39,
#  69.04,
#  146.6,
#  22.2,
#  185.5,
#  339.57,
#  16.29,
#  175.92,
#  29.32,
#  87.96,
#  47.36,
#  27.72,
#  99.0,
#  38.0,
#  83.16,
#  66.0,
#  494.0,
#  114.0,
#  1078.92,
#  299.7,
#  25.51,
#  72.0,
#  210.0,
#  40.92,
#  42.52,
#  72.28,
#  105.0,
#  118.96,
#  5.44,
#  280.0,
#  455.6,
#  105.0,
#  654.72,
#  70.0,
#  297.4,
#  28.0,
#  227.8,
#  236.25,
#  178.44,
#  163.7,
#  22.0,
#  4.5,
#  30.59,
#  17.75,
#  6.28,
#  4.36,
#  13.58,
#  20.72,
#  8.55,
#  20.96,
#  42.33,
#  6.11,
#  14.23,
#  40.55,
#  1.55,
#  1.2,
#  7.99,
#  52.9,
#  119.21,
#  8.39,
#  13.2,
#  0.89,
#  0.65,
#  101.57,
#  46.17,
#  2.7,
#  17.44,
#  12.28,
#  5.44,
#  8.35,
#  48.42,
#  27.38,
#  205.82,
#  21.56,
#  5.75,
#  52.1,
#  20.9,
#  3.41,
#  63.5,
#  46.69,
#  16.79,
#  4.65,
#  15.96,
#  4.75,
#  5.73,
#  46.16,
#  8.8,
#  1.86,
#  10.15,
#  1.7,
#  0.88,
#  3.56,
#  4.2,
#  6.47,
#  57.44,
#  54.0,
#  12.21,
#  1.32,
#  4.21,
#  2.73,
#  16.38,
#  0.92,
#  12.57,
#  9.59,
#  2.56,
#  4.48,
#  4.19,
#  2.25,
#  3.86,
#  8.98,
#  2.3,
#  37.2,
#  95.49,
#  74.39,
#  42.44,
#  234.81,
#  67.34,
#  129.2,
#  1.37,
#  3.24,
#  5.76,
#  10.88,
#  11.47,
#  4.04,
#  36.69,
#  216.72,
#  133.2,
#  83.47,
#  23.9,
#  151.49,
#  112.97,
#  70.07,
#  54.03,
#  83.13,
#  1.94,
#  28.48,
#  30.89,
#  13.69,
#  12.98,
#  114.46,
#  97.06,
#  58.32,
#  13.43,
#  11.92,
#  4.74,
#  13.88,
#  30.72,
#  29.04,
#  31.36,
#  18.92,
#  73.62,
#  46.8,
#  95.56,
#  65.7,
#  34.8,
#  43.95,
#  2.11,
#  10.92,
#  238.04,
#  159.23,
#  2.63,
#  30.81,
#  50.96,
#  29.11,
#  39.62,
#  23.33,
#  60.0,
#  32.67,
#  68.71,
#  32.38,
#  53.09,
#  53.09,
#  68.6,
#  166.32,
#  83.16,
#  62.82,
#  52.65,
#  12.43,
#  25.34,
#  6.27,
#  9.14,
#  34.17,
#  26.86,
#  29.2,
#  3.9,
#  41.88,
#  7.92,
#  2.08,
#  70.81,
#  165.6,
#  0.98,
#  101.91,
#  8.53,
#  59.39,
#  10.54,
#  35.6,
#  504.84,
#  35.11,
#  12.34,
#  451.27,
#  26.16,
#  21.67,
#  34.69,
#  22.26,
#  29.13,
#  6.28,
#  8.96,
#  37.56,
#  100.17,
#  51.72,
#  61.74,
#  54.86,
#  12.59,
#  53.97,
#  37.77,
#  22.56,
#  43.04,
#  40.24,
#  138.36,
#  42.3,
#  60.5,
#  45.24,
#  32.05,
#  22.56,
#  106.65,
#  31.6,
#  15.8,
#  51.48,
#  31.95,
#  25.86,
#  1.94,
#  70.07,
#  97.06,
#  55.54,
#  41.6,
#  32.85,
#  1.54,
#  103.56,
#  16.79,
#  26.15,
#  15.5,
#  30.24,
#  264.21,
#  20.26,
#  15.37,
#  27.43,
#  24.25,
#  61.77,
#  7.58,
#  14.29,
#  13.37,
#  7.73,
#  7.15,
#  407.68,
#  25.0,
#  42.47,
#  168.3,
#  7.63,
#  47.98,
#  40.64,
#  44.95,
#  124.6,
#  47.04,
#  125.44,
#  80.5,
#  193.2,
#  128.8,
#  547.4,
#  161.0,
#  708.4,
#  161.0,
#  257.6,
#  15.97,
#  28.45,
#  15.48,
#  15.99,
#  136.32,
#  92.06,
#  381.36,
#  1.38,
#  14.04,
#  3.83,
#  24.05,
#  47.36,
#  99.89,
#  8.82,
#  79.08,
#  205.96,
#  5.44,
#  57.89,
#  18.06,
#  11.16,
#  8.3,
#  56.0,
#  8.36,
#  1.79,
#  11.29,
#  60.05,
#  414.24,
#  35.3,
#  12.06,
#  144.0,
#  47.94,
#  114.76,
#  5.2,
#  12.32,
#  35.89,
#  88.06,
#  179.24,
#  16.8,
#  43.13,
#  5.39,
#  26.09,
#  58.68,
#  73.34,
#  13.0,
#  9.92,
#  7.08,
#  26.16,
#  6.33,
#  12.98,
#  37.81,
#  31.25,
#  18.95,
#  8.33,
#  1.77,
#  46.09,
#  150.45,
#  10.82,
#  15.63,
#  23.47,
#  0.88,
#  9.45,
#  81.1,
#  16.8,
#  35.08,
#  442.39,
#  41.76,
#  54.6,
#  54.6,
#  6.4,
#  5.32,
#  14.56,
#  192.75,
#  21.97,
#  5.22,
#  39.9,
#  2.56,
#  2.86,
#  176.76,
#  73.3,
#  23.8,
#  0.94,
#  60.45,
#  26.32,
#  3.27,
#  94.97,
#  2.88,
#  5.65,
#  12.36,
#  24.78,
#  7.76,
#  18.8,
#  49.68,
#  2.62,
#  1.36,
#  2.56,
#  0.9,
#  46.8,
#  35.98,
#  60.02,
#  17.43,
#  24.36,
#  31.28,
#  10.88,
#  8.12,
#  26.52,
#  23.2,
#  5.32,
#  13.34,
#  2.51,
#  6.42,
#  24.94,
#  1.92,
#  33.41,
#  10.85,
#  93.54,
#  47.5,
#  107.71,
#  19.0,
#  5.46,
#  0.84,
#  29.77,
#  21.6,
#  9.68,
#  11.76,
#  0.79,
#  3.36,
#  10.98,
#  1.47,
#  51.51,
#  32.13,
#  169.86,
#  634.14,
#  612.0,
#  28.31,
#  133.56,
#  86.8,
#  176.76,
#  20.4,
#  38.16,
#  249.0,
#  1278.2,
#  259.11,
#  346.72,
#  42.0,
#  252.0,
#  10.38,
#  1.5,
#  0.87,
#  12.28,
#  106.6,
#  13.44,
#  12.36,
#  272.62,
#  23.55,
#  63.08,
#  364.42,
#  25.6,
#  380.21,
#  235.44,
#  235.87,
#  63.2,
#  33.26,
#  232.82,
#  36.59,
#  695.21,
#  365.9,
#  115.86,
#  1.84,
#  3.98,
#  9.8,
#  299.36,
#  299.34,
#  33.26,
#  204.72,
#  71.36,
#  28.64,
#  6.84,
#  19.98,
#  31.52,
#  348.25,
#  47.91,
#  15.97,
#  287.28,
#  276.08,
#  109.45,
#  108.79,
#  105.28,
#  69.44,
#  228.85,
#  3.06,
#  21.06,
#  397.37,
#  228.81,
#  216.38,
#  193.34,
#  46.68,
#  118.94,
#  84.0,
#  489.86,
#  17.94,
#  2.75,
#  79.24,
#  7.02,
#  8.91,
#  75.0,
#  64.18,
#  5.06,
#  19.98,
#  4.12,
#  12.16,
#  7.3,
#  34.04,
#  83.6,
#  89.22,
#  11.09,
#  30.67,
#  30.67,
#  11.35,
#  39.6,
#  12.5,
#  10.61,
#  4.35,
#  20.72,
#  8.72,
#  4.2,
#  34.44,
#  86.01,
#  348.44,
#  368.6,
#  23.25,
#  82.14,
#  37.7,
#  1.7,
#  4.52,
#  27.08,
#  183.0,
#  34.97,
#  13.35,
#  24.98,
#  217.36,
#  21.6,
#  13.38,
#  20.84,
#  1.69,
#  3.39,
#  12.57,
#  20.68,
#  14.7,
#  11.28,
#  3.32,
#  38.64,
#  18.16,
#  8.24,
#  37.4,
#  14.32,
#  42.96,
#  23.25,
#  2.43,
#  10.2,
#  4.2,
#  48.45,
#  9.55,
#  52.5,
#  78.13,
#  58.39,
#  264.53,
#  11.76,
#  130.72,
#  69.43,
#  50.96,
#  51.56,
#  77.34,
#  170.14,
#  7.48,
#  8.94,
#  68.85,
#  55.08,
#  5.54,
#  5.43,
#  38.67,
#  13.01,
#  322.69,
#  23.05,
#  28.88,
#  86.64,
#  54.99,
#  28.88,
#  15.48,
#  0.78,
#  29.14,
#  11.15,
#  1.66,
#  12.17,
#  67.14,
#  80.28,
#  61.88,
#  361.02,
#  11.88,
#  30.24,
#  30.35,
#  1.79,
#  235.0,
#  451.44,
#  225.72,
#  77.96,
#  3.25,
#  2.0,
#  73.14,
#  9.64,
#  104.65,
#  50.41,
#  79.55,
#  13.44,
#  56.63,
#  10.16,
#  27.16,
#  2.4,
#  8.34,
#  6.92,
#  5.92,
#  21.24,
#  76.32,
#  29.52,
#  27.12,
#  51.45,
#  14.72,
#  6.2,
#  10.93,
#  4.6,
#  11.4,
#  43.6,
#  21.98,
#  208.81,
#  229.6,
#  7.35,
#  44.1,
#  6.66,
#  13.46,
#  3.53,
#  14.42,
#  58.68,
#  64.66,
#  188.4,
#  340.8,
#  149.72,
#  11.2,
#  39.2,
#  108.78,
#  21.84,
#  60.9,
#  14.93,
#  9.75,
#  24.8,
#  76.08,
#  9.24,
#  10.45,
#  26.0,
#  148.1,
#  106.5,
#  24.01,
#  9.65,
#  6.96,
#  16.28,
#  99.66,
#  4.06,
#  187.26,
#  20.88,
#  26.1,
#  18.63,
#  6.52,
#  2.68,
#  28.23,
#  33.64,
#  5.49,
#  27.16,
#  4.3,
#  19.52,
#  28.32,
#  4.54,
#  6.13,
#  6.96,
#  29.31,
#  6.66,
#  19.1,
#  3.5,
#  63.36,
#  8.79,
#  143.18,
#  18.25,
#  1.74,
#  45.92,
#  55.79,
#  16.2,
#  9.69,
#  9.66,
#  33.04,
#  5.0,
#  8.54,
#  18.45,
#  145.78,
#  113.09,
#  8.91,
#  7.01,
#  7.53,
#  24.08,
#  4.47,
#  39.7,
#  51.58,
#  52.36,
#  18.48,
#  27.41,
#  22.22,
#  11.37,
#  58.32,
#  12.15,
#  14.58,
#  13.86,
#  105.55,
#  24.0,
#  15.72,
#  56.3,
#  11.26,
#  14.38,
#  7.19,
#  13.12,
#  9.12,
#  15.89,
#  203.42,
#  2.32,
#  7.06,
#  3.36,
#  3.64,
#  21.15,
#  32.12,
#  4.68,
#  4.68,
#  80.34,
#  6.64,
#  23.53,
#  85.77,
#  37.98,
#  51.75,
#  10.95,
#  10.95,
#  128.81,
#  27.5,
#  20.0,
#  55.8,
#  181.35,
#  13.95,
#  33.15,
#  36.6,
#  ...]

# %%
def describe(data, key): #data is a list of dictionaries, key is a key in each dictionary in data
    
    values = sorted([d[key] for d in data]) #This gets the number for a given key in dictionary
    
    
    total = sum(values)  #Sum
    avg = mean(values) #mean
    s = std(values) #standard deviation
    q25 = quartile(values, 0.25) #1st quartile, Q1
    med = quartile(values, 0.50) #Median
    q75 = quartile(values, 0.75) #3rd quartile, Q3

    return (total, avg, s, q25, med, q75)

# %%
describe(scripts, 'items')
# Out:
# (4410054, 11.522744731217633, 33.11216633979208, 1, 3, 8)

# %%
describe(scripts, 'quantity')
# Out:
# (316356836, 826.5883059943667, 3872.1810146090156, 30, 120, 466)

# %%
describe(scripts, 'nic')
# Out:
# (29048309.790000085, 75.89844899484248, 197.57282662775233, 7.7, 22.62, 65.95)

# %%
describe(scripts, 'act_cost')
# Out:
# (27053937.60000044, 70.68748295125087, 183.267318953028, 7.25, 21.24, 61.54)

# %%
summary = [('items', describe(scripts, 'items')),
           ('quantity', describe(scripts, 'quantity')),
           ('nic', describe(scripts, 'nic')),
           ('act_cost', describe(scripts, 'act_cost'))]

# %%
summary
# Out:
# [('items', (4410054, 11.522744731217633, 33.11216633979208, 1, 3, 8)),
#  ('quantity',
#   (316356836, 826.5883059943667, 3872.1810146090156, 30, 120, 466)),
#  ('nic',
#   (29048309.790000085,
#    75.89844899484248,
#    197.57282662775233,
#    7.7,
#    22.62,
#    65.95)),
#  ('act_cost',
#   (27053937.60000044,
#    70.68748295125087,
#    183.267318953028,
#    7.25,
#    21.24,
#    61.54))]

# %%
grader.score.pw__summary_statistics(summary)
# Out:
# ==================
# Your score: 1.000
# ==================

# %% [markdown]
# ## Question 2: most_common_item
#
# Often we are not interested only in how the data is distributed in our entire data set, but within particular groups -- for example, how many items of each drug (i.e. `'bnf_name'`) were prescribed? Calculate the total items prescribed for each `'bnf_name'`. What is the most commonly prescribed `'bnf_name'` in our data?
#
# To calculate this, we first need to split our data set into groups corresponding with the different values of `'bnf_name'`. Then we can sum the number of items dispensed within in each group. Finally we can find the largest sum.
#
# We'll use `'bnf_name'` to construct our groups. You should have *5619* unique values for `'bnf_name'`.

# %%
bnf_names = { s['bnf_name'] for s in scripts}
assert(len(bnf_names) == 5619)

# %%
bnf_names = set([d['bnf_name'] for d in scripts])

# %%
len(set([s['bnf_name'] for s in scripts]))
# Out:
# 5619

# %%
bnf_names
# Out:
# {'Hospiform 10cm x 4m Conform Syn Band',
#  'Warfarin Sod_Oral Susp 1mg/1ml S/F',
#  'Maxitram SR_Cap 50mg',
#  'Trimethoprim_Tab 200mg',
#  'Fragmin_Inj 25 000u/ml 0.6ml Pfs',
#  'Co-Amilofruse_Tab 5mg/40mg',
#  'Trental 400_Tab 400mg',
#  'CosmoCol_Oral Pdr Sach (Orng Lem & Lim)',
#  'Teleflex_Rusch Leg Bag 500ml 10cm Tubing',
#  'Dulaglutide_Inj 0.75mg/0.5ml Pf Dev',
#  'Hydrocort But_Scalp Lot 0.1%',
#  'Dalteparin Sod_Inj 25 000u/ml 0.4ml Pfs',
#  'Dalivit_Dps',
#  'Medikinet XL_Cap 20mg',
#  'Bumetanide_Tab 1mg',
#  'Diazepam_Tab 5mg',
#  'Dexameth_Oral Soln 2mg/5ml S/F',
#  'Aquacel Ag 5cm x 5cm Wound Dress Proteas',
#  'Sod Algin/Pot Bicarb_Susp S/F',
#  'Clobavate_Oint 0.05%',
#  'Prempak-C_C/Pk Tab 1.25mg/150mcg',
#  'Aprovel_Tab 150mg',
#  'Ins Detemir_Inj 100u/ml 3ml Pf Pen',
#  'Gaviscon_Liq Orig Aniseed Relief',
#  'Medicareplus_Medi Derma-S Barrier Crm 90',
#  'Fosinopril Sod_Tab 10mg',
#  'Ispag Husk_Gran Sach 3.5g G/F',
#  'FemSeven 50_Patch 50mcg/24hrs',
#  'Dovobet_Gel Applic',
#  'Methylpred Acet/Lidoc_Inj 80/20mg/2ml Vl',
#  'ActiLymph Class 1 B/Knee Closed Toe Sand',
#  'Xatral_XL Tab 10mg',
#  'Activa Leg Ulcer Hose Kit Med Clsd Toe C',
#  'Cetirizine HCl_Oral Soln 1mg/1ml S/F',
#  'CliniMed_Appeel Advance No Sting Medic A',
#  'Viazem XL_Cap 300mg',
#  'Hypromellose_Eye Dps 0.5%',
#  'Movicol-Half_Pdr Sach 6.9g (Lem & Lim)',
#  'K-Y Lubri Jelly',
#  'Adipine XL_Tab 60mg',
#  'Carvedilol_Tab 25mg',
#  'Carbocisteine_Oral Soln 250mg/5ml',
#  'Carvedilol_Tab 6.25mg',
#  'Tegaderm Foam Adh Oval 10cm x 11cm Wound',
#  'Forticreme Complete_Dessert (F/Fruits)',
#  'Prednisolone_Tab E/C 2.5mg',
#  'Nicotine_Nsl Spy 500mcg (200 D) 10ml',
#  'Volumatic',
#  'Promethazine Teoclate_Tab 25mg',
#  'Pramipexole_Tab 350mcg',
#  'Thick & Easy_Food Thickener Pdr Sach 9g',
#  'Alimemazine Tart_Tab 10mg',
#  'Esomeprazole_Tab E/C 40mg',
#  'Losec_Cap E/C 10mg',
#  'ChloraPrep_Soln Applic 3ml',
#  'Water For Inj_20ml Amp',
#  'Doublebase_Emollient Bath Add',
#  'Madopar_Tab Disper 50mg/12.5mg',
#  'Morph Sulf_Cap 30mg M/R',
#  'Aquacel Ag 15cm x 15cm Wound Dress Prote',
#  'Zipzoc_Zn Ox Impregnated Medic Stkn',
#  'Fragmin_Inj 25 000u/ml 0.5ml Pfs',
#  'Mezolar Matrix_T/Derm Patch 37.5mcg/hr',
#  '3m Health Care_Cavilon No Sting 3ml Barr',
#  'Bupeaze_Transdermal Patch 35mcg/hr(96hr)',
#  'Uro-Tainer Twin Solution R 2 x 30ml Cath',
#  'Gamolenic Acid_Cap 80mg',
#  'OneTouch Delica Lancets 0.32mm/30 Gauge',
#  'Norethist_Tab 350mcg',
#  'Lodoxamide Trometamol_Eye Dps 0.1%',
#  'Colecal & Calc_Tab Chble 880u/2.5g',
#  'Tildiem_Tab 60mg',
#  'AMI_Suportx Ostomy & A/Support Ladies Br',
#  'Hepat A_Vac 1440u/ml 1ml Pfs',
#  'Mesalazine_Foam Aero Enem 1g/D 14g',
#  'Ibuleve_Max Strgh Gel 10%',
#  'Cardioplen XL_Tab 2.5mg',
#  'Betameth Diprop_Oint 0.05%',
#  'Ins Degludec_100u/ml 3ml Cart',
#  'Ferrograd_Filmtab',
#  'Enstilar_Foam Aero 50mcg/0.5mg/g',
#  'Clarithromycin_Oral Susp 250mg/5ml',
#  'Cocois_Oint',
#  'Imodium_Original Cap 2mg',
#  'AproDerm Emollient Crm 450g',
#  'Genius_G/F Bread Wte (Cut)',
#  'Candesartan Cilexetil_Tab 4mg',
#  'Coloplast_Sensura Mio Midi DrnblBag Grey',
#  'Evacal D3_Tab Chble 400u/1.5g',
#  'Levonelle_Tab 1.5mg',
#  'Mediven Elegance Class 1 B/Knee Closed T',
#  'Ismo 20_Tab 20mg',
#  'Melatonin_Cap 10mg',
#  'Premarin_Tab 1.25mg',
#  'Hydrofilm 10cm x 12.5cm Vp Adh Film Dres',
#  'Hydrocort_Tab 10mg',
#  'Clopixol_Tab 2mg',
#  'Etodolac_Tab 600mg M/R',
#  'Repinex XL_Tab 8mg',
#  'Sumatriptan_Inj 6mg/0.5ml Pfs Ref',
#  'Alprostadil_Cont Pack Inj 10mcg Cart',
#  'Alimemazine Tart_Oral Soln 30mg/5ml',
#  'Slo-Phyllin_Cap 125mg',
#  'CarePoint Needles Pen Inj Screw On 6mm',
#  'Calcipotriol_Scalp Soln 50mcg/ml',
#  'Sinemet CR_Tab 250mg',
#  'Lormetazepam_Tab 1mg',
#  'Sorbsan Ribbon (+ Probe) 40cm Wound Dres',
#  'Trio_Elisse Sting Free Skin Barrier Spy',
#  'Ponstan_Cap 250mg',
#  'Amoxil_Cap 250mg',
#  'Esomeprazole_Cap E/C 20mg',
#  'kliniderm superabsorbent 20cm x 20cm Pfa',
#  'Colecal_Tab 400u',
#  'CosmoCol_Half Oral Pdr Sach 6.9g',
#  'Simvador_Tab 10mg',
#  'Uniphyllin Continus_Tab 400mg',
#  'Gz & Cott Tiss BP 1988',
#  'Coloplast_Conveen Sheath Liner',
#  'Verapamil HCl_Tab 120mg M/R',
#  'Dansac_Nova Mini Cap Opqe C/Fit 20-50mm',
#  'Escitalopram_Tab 5mg',
#  'Timolol_Eye Dps 0.5%',
#  'Balneum Plus_Crm',
#  'Pelican_Cohesive Seals Sml 48mm',
#  'Amlodipine_Oral Soln 5mg/5ml S/F',
#  'E45_Emollient Bath Oil',
#  'Menthol & Eucalyptus_Inh BP 1980',
#  'Ovranette_Tab 150mcg/30mcg',
#  'Fresubin 2kcal Fibre_Drink (6 Flav)',
#  'L.IN.C_LINC-Flo Night Drain Bag Ster Nrv',
#  'Angitil SR 90_Cap 90mg',
#  'Glibenclamide_Tab 5mg',
#  'Influenza_Vac Inact 0.5ml Pfs',
#  'Premarin_Tab 300mcg',
#  'Convatec_Sensi-Care Sting Free Prote Bar',
#  'Telfast 120_Tab 120mg',
#  'Salbutamol_Tab 4mg',
#  'Viscotears_Eye Gel 2mg/g 0.6ml Ud',
#  'Metformin HCl_Tab 850mg',
#  'Bonviva_Tab 150mg F/C',
#  'Doublebase_Dayleve gel',
#  'Algivon 10cm x 10cm Wound Dress Algin St',
#  'Molaxole_Pdr Sach',
#  'Dihydrocodeine Tart_Tab 90mg M/R',
#  'Clotrimazole_Pess 100mg',
#  'Arthrotec 75_Tab',
#  'Malathion_Aq Lot 0.5%',
#  'Brinzolamide_Eye Dps 10mg/ml',
#  'Salts_Confidence Natural Drnbl Pch Trans',
#  'E45_Emollient Shower Crm',
#  'Ipinnia XL_Tab 8mg',
#  'B.Braun Actreen Male Glys Set Nelaton 8-',
#  'Olanzapine_Orodisper Tab 20mg S/F',
#  'Colecal_Cap 20 000u',
#  'Half Beta-Prograne MR_Cap 80mg',
#  'Sumatriptan_Inj 6mg/0.5ml Pfs + Dev',
#  'Clindamycin Phos_Gel 1%',
#  'Reletrans_Transdermal Patch 10mcg/hr',
#  'Zomig_Rapimelt Orodisper Tab 5mg',
#  'Tubifast 2-Way Stch 10.75cm x 1m YellowS',
#  'Teoptic_Eye Dps 1%',
#  'Juvela_G/F W/F Flakes',
#  'Maxijul Super Solb_Pdr',
#  'Risperidone_Tab 2mg',
#  'Promethazine HCl_Tab 10mg',
#  'Tentrini Pack_G/F M/Fibre Feed',
#  'Tetracycline_Tab 250mg',
#  'Fluticasone/Formoterol_Inh 125/5mcg 120D',
#  'Betnesol-N_Ear/Eye/Nose Dps',
#  'Coloplast_SenSura Mio Click B/Plt D/Conv',
#  'Subutex_Tab Subling 2mg',
#  'Tegaderm + Pad 9cm x 15cm VP Adh Film Dr',
#  'Epilim 500_Tab E/C 500mg',
#  'Cosopt_Ocumeter Plus Eye Dps',
#  'Zerolatum Plus_Bath Additive',
#  'Oxcarbazepine_Tab 300mg',
#  'Atomoxetine HCl_Cap 25mg',
#  'Memantine HCl_Oral Soln 10mg/ml S/F',
#  'Matrifen_Patch 25mcg/hr',
#  'Ascorbic Acid_Tab 200mg',
#  'Dansac_NovaLife 1 Open + View Midi Opqe',
#  'Alprostadil_Urethral Stick 1mg',
#  'Betaxolol_Soln Eye Dps 0.5%',
#  'Paliperidone_Inj 150mg/1.5ml Pfs',
#  'Hydromol_Bath & Shower Emollient',
#  'Serevent_Accuhaler 50mcg (60 D)',
#  'Goserelin Acet_Implant 3.6mg Pfs',
#  'Chemydur 60 XL_Tab 60mg',
#  'Calamine_Lot',
#  'Coloplast_Sensura Mio Maxi Drnbl Bag Tra',
#  'Diamox SR_Cap 250mg',
#  'Spiroco XL_Tab 8mg',
#  'Dorzolamide_Eye Dps 2%',
#  'Movelat_Gel',
#  'Propiverine HCl_Cap 30mg M/R',
#  'Sod Valpr_Oral Soln 200mg/5ml',
#  'Methylphenidate HCl_Tab 10mg',
#  'Estradiol/Norethist Acet_Tab 2mg/1mg',
#  'Midazolam_Liq Spec 50mg/5ml',
#  'Zetuvit E 20cm x 40cm Pfa Cellulose Dres',
#  'Ins Insuman Comb 25 SoloStar_3ml Pf Pen',
#  'N-A Dress 9.5cm x 9.5cm Type 1 Ktd Visco',
#  'Hydroxychlor Sulf_Tab 200mg',
#  'Sytron_Elix 190mg/5ml S/F',
#  'Unomedical_Careline Leg Bag Straps',
#  'Elleste Solo_Tab 2mg',
#  'Prucalopride_Tab 1mg',
#  'Flurbiprofen_Loz 8.75mg',
#  'Allevyn Gentle Border 12.5cm x 12.5cm Wo',
#  'Hospicrepe 233 10cm x 4.5m Cott Stch Ban',
#  'Episenta_Gran Sach 500mg M/R',
#  'Diprobase_Crm',
#  'Mesalazine_Suppos 1g',
#  'Isosorbide Dinit_Tab 20mg M/R',
#  'UrgoKTwo Size 25-32cm (10cm) M/Layer Com',
#  'Flamazine_Crm 1%',
#  'Anastrozole_Tab 1mg',
#  'Salts_SecuPlast Mouldable Seals Stnd',
#  'Zetuvit Plus 15cm x 20cm Super-Absorb Dr',
#  'Juvela_G/F Loaf P/Bke',
#  'Cyanocobalamin_Tab 1mg M/R',
#  'Seebri_Breezhaler Inh Cap 55mcg + Dev',
#  'Combivent UDVs_Neb Soln Ud 2.5ml',
#  'Actico 10cm x 6m Short Stch Compress Ban',
#  'Lansoprazole_Orodisper Tab 30mg',
#  'Furosemide_Tab 40mg',
#  'Paraf_Soft Wte (S)',
#  'Felodipine_Tab 10mg M/R',
#  'Softpore 10cm x 20cm Pfa + Adh Border Dr',
#  'Naloxegol_Tab 25mg',
#  'Buccolam_Oromuc Soln 10mg/2ml Oral Pfs',
#  'Calogen_Emuls (Sbery)',
#  'Moclobemide_Tab 300mg',
#  'Scanpor 2.5cm x 10m Surg Adh Tape Perm N',
#  'Elvanse_Cap 40mg',
#  'Omeprazole_Oral Susp 10mg/5ml',
#  'Solpadol_Cap 30mg/500mg',
#  'Simvastatin_Tab 40mg',
#  'C-View 10cm x 12cm VP Adh Film Dress',
#  'Ethosuximide_Oral Soln 250mg/5ml',
#  'Timolol_Gel Eye Dps 1mg/g 0.4g Ud P/F',
#  'Exorex_Crm',
#  'Vistamethasone_Ear/Eye/Nose Dps 0.1%',
#  'Zomorph_Cap 10mg',
#  'Spiriva_Pdr For Inh Cap 18mcg+HandiHaler',
#  'Melophthal 0.5% Carmellose Eye Dps 0.4ml',
#  'Venlalic XL_Tab 225mg',
#  'Omeprazole_Oral Susp 20mg/5ml',
#  'Duloxetine HCl_Cap G/R 60mg',
#  'Isosorbide Mononit_Cap 60mg M/R',
#  'Beclomet Diprop_Nsl Spy 50mcg (200 D)',
#  'Fluorome_Eye Dps 0.1%',
#  'Fluocinolone Aceton_Crm 0.00625%',
#  'Dosulepin HCl_Cap 25mg',
#  'Vagisil_Medic Creme',
#  'Insight Cannula Swab Lge Tracheo Cleanin',
#  'Co-Tenidone_Tab 100mg/25mg',
#  'Latanoprost/Timolol_Eye Dps 50mcg/5mg/ml',
#  'Lorazepam_Tab 1mg',
#  'Vega_ZM3 Multivit/Min V/Cap',
#  'Bullen_Shelter Safe-Seal',
#  'Comfifast MultiStretch 2-way Stch 10.75c',
#  'Labetalol HCl_Tab 200mg',
#  'GluNEO (Reagent)_Strips',
#  'Fexofenadine HCl_Tab 30mg',
#  'Medroxyprogest Acet_Tab 100mg',
#  'Nabumetone_Tab 500mg',
#  'CarePoint Needles Pen Inj Screw On 8mm',
#  'Venlablue XL_Cap 37.5mg',
#  'Modafinil_Tab 200mg',
#  'Urea_Lot 10%',
#  'GelTears_Ophth Gel 0.2%',
#  'Isotrex_Gel 0.05%',
#  'Glucophage SR_Tab 750mg',
#  'Estraderm MX 100_Patch',
#  'Coloplast_Simpla Plus Leg Bag Ster 500ml',
#  'DesmoMelt_Oral Lyoph 120mcg',
#  'Subutex_Tab Subling 8mg',
#  'Madopar_Cap 100mg/25mg',
#  'Ethinylestr/Norelgest_24 Hr T/Derm Patch',
#  'Calc & Ergocalciferol_Tab 400u',
#  'Docusate Sod_Oral Soln 12.5mg/5ml S/F',
#  'TheiCal D-3_Tab Chble 1000mg/880u',
#  'Zumenon_Tab 2mg',
#  'Incruse Ellipta_Inh 55mcg (30D)',
#  'Sigvaris Cotton Class 1 B/Knee Closed To',
#  'Acenocoumarol_Tab 1mg',
#  'Salts_Fresh Aire Odour Eliminating Deod',
#  'Fluticasone Prop_Inha 250mcg (120 D) CFF',
#  'Fresenius Sod Chlor Top Irrig 0.9% 1L',
#  'Convatec_Orahesive Pdr',
#  'Etrivex_Shampoo 500mcg/g',
#  'Ephed HCl_Nsl Dps 0.5% BP',
#  'Hylo-Forte Sod Hyaluronate Eye Dps 0.2%',
#  'Hyoscine Butylbrom_Inj 20mg/ml 1ml Amp',
#  'Convatec_System 2 Belt',
#  'Erythromycin_Ethylsuc Susp 125mg/5ml S/F',
#  'CliniFix Tube Holder 110mm x 25mm Cath A',
#  'Diclofenac Sod_Gel 3%',
#  'Saxagliptin_Tab 5mg',
#  'Relvar Ellipta_Inha 184mcg/22mcg (30 D)',
#  'Menthol In Aq_Crm 2%',
#  'Salts_Dermacol Stoma Collar 35mm',
#  'Olmesartan Medox/Hydchloroth_Tab 20/12.5',
#  'Adizem-XL_Cap 240mg',
#  'Jevity 1.5kcal_Liq',
#  'Ropinirole HCl_Tab 3mg M/R',
#  'Terazosin HCl_Tab 5mg',
#  'Dalacin T_Top Lot 1%',
#  'Nicorette_Chewing Gum 4mg S/F(Icy Wte)',
#  'Complan_Shake Pdr Sach 57g (Banana)',
#  'Alphagan_Eye Dps 0.2%',
#  'Ethinylestr/Gestodene_Tab 20mcg/75mcg',
#  'CliniFast 7.5cm x 3m (Blue) Stkntte Elas',
#  'Clomifene Cit_Tab 50mg',
#  'Losec MUPS_Tab Disper 10mg (E/C Pellets)',
#  'Dovobet_Gel 0.005%/0.05%',
#  'Vipdomet_Tab 12.5mg/1g',
#  'Digoxin_Oral Soln Paed 50mcg/ml',
#  'Aciferol D3_Oral Soln 3 000u/ml',
#  'Rabeprazole Sod_Tab E/C 20mg',
#  'Cetaphil_Gentle Skin Cleanser',
#  'Mercilon_Tab',
#  'Mag Glycerophos_Oral Soln 121.25mg/5ml',
#  'Coloplast_Coloplast Prote Rings 20mm',
#  'Naftidrofuryl Oxal_Cap 100mg',
#  'Alfuzosin HCl_Tab 10mg M/R',
#  'Zetuvit E (Non-Ster) 10cm x 20cm Pfa Cel',
#  'Toujeo_300u/ml 1.5ml Pf SoloStar Pen',
#  'Coloplast SpeediCath Fle Size 10-14 (30-',
#  'Zapain_Cap 30mg/500mg',
#  'Dronedarone HCl_Tab 400mg',
#  'Co-Careldopa_Tab 25mg/100mg',
#  'Nutrison_Energy M/Fibre Liq (Vanilla)',
#  'Lisinopril_Tab 20mg',
#  'Levothyrox Sod_Tab 25mcg',
#  'Indometacin_Cap 50mg',
#  'Zovirax_Crm 5%',
#  'Movelat Relief_Gel',
#  'Meloxicam_Tab 15mg',
#  'Nitromin_P/Spy 400mcg (200 D)',
#  'Thiamine HCl_Tab 100mg',
#  'Zeroneum Bath Add',
#  'kliniderm superabsorbent 10cm x 15cm Pfa',
#  'Tizanidine HCl_Tab 4mg',
#  'Ins Humalog_KwikPen 200u/ml 3ml Pf Pen',
#  'Kliniderm fiber cmc 10cm x 10cm Wound Dr',
#  'Methotrexate_Inj 22.5mg/0.45ml PF Dev',
#  'Dextrogel_Gel 40%',
#  'Canesten_Oral&Crm Duo(1 Cap 150mg/Crm2%)',
#  'Eczmol_Crm 1%',
#  'Sumatriptan_Aq Nsl Spy 10mg/0.1ml Ud',
#  'Targinact_Tab 10mg/5mg M/R',
#  'Starch Maize Modified_Pdr Sach 12g G/F',
#  'Rewisca_Cap 100mg',
#  'Clonazepam_Tab 500mcg',
#  'Codeine Phos_Tab 60mg',
#  'Durogesic DTrans_T/Derm Patch 25mcg',
#  'Demeclocycline HCl_Cap 150mg',
#  'Gloves (100 Gauge) (Disp) Polyth Occlusi',
#  'Flecainide Acet_Tab 100mg',
#  'Welland_Aura Drnbl Ileo Pouch Maxi Clr C',
#  'Galantamine_Cap 8mg M/R',
#  'Unifine Pentips Needles Pen Inj Screw On',
#  'Clotrimazole_Soln 1%',
#  'Aspen_Sorbaderm No-Sting Barrier Film 1m',
#  'CliniFast 10.75cm x 3m (Yellow) Stkntte',
#  'Neoral_Cap 50mg',
#  'Evolve Hypromellose 0.3% Eye Dps 10ml P/',
#  'Aliskiren_Tab 300mg',
#  'Venaxx XL_Cap 75mg',
#  'Heparin Sod_Soln 10u/ml 5ml Amp',
#  'Qvar 100_Inha 100mcg (200 D)',
#  'Salts_Confidence Comfort + Flexifit Neon',
#  'Betmiga_Tab 50mg M/R',
#  'Tubifast 2-Way Stch 7.5cm x 5m (Blue) St',
#  'Oxycodone HCl_Oral Soln 5mg/5ml S/F',
#  'OxyNorm_Cap 5mg',
#  'Uro-Tainer NaCl 100ml Cath Maint Soln',
#  'Oxycodone HCl_Inj 10mg/ml 1ml Amp',
#  'Nicardipine HCl_Cap 30mg',
#  'Gyno-Daktarin_Crm 2% + Applic (14D)',
#  'Adcal-D3_Capl 750mg/200u',
#  'Loperamide HCl_Orodisper Tab 2mg S/F',
#  'CliniMed_LBF Ster No Sting Barrier Film',
#  'Zoladex_Implant 3.6mg SafeSystem Pfs',
#  'Calc Carb_Tab Chble 2.5g S/F',
#  'Cefalexin_Oral Susp 125mg/5ml',
#  'Cardura XL_Tab 4mg',
#  'Rasagiline Mesil_Tab 1mg',
#  'Co-Trimoxazole_Tab 80mg/400mg',
#  'Sod Clodronate_Tab 800mg',
#  'Mometasone Fur_Oint 0.1%',
#  'Mylife Penfine Classic Pen Inj Screw On',
#  'Piriton_Syr 2mg/5ml',
#  'Coloplast_SenSura Mio Orig Midi Clsd Bag',
#  'Longtec_Tab 5mg M/R',
#  'Coban Self-Adherent 10cm x 6m M/Layer Co',
#  'Venlafaxine_Tab 37.5mg M/R',
#  'Dimeticone_Lot 4%',
#  'Coloplast_Brava Mouldable Rings 48mm x 2',
#  'Sebco_Oint',
#  'Rewisca_Cap 25mg',
#  'Greenlan Lancets 0.35mm/28 Gauge',
#  'Depo-Medrone_Inj 40mg/ml 2ml Vl',
#  'Femara_Tab 2.5mg',
#  'Etonogestrel_Implant 68mg',
#  'Rectogesic_Oint 0.4%',
#  'Humapen Luxura HD 3ml 0.5u (1-30u) Hypod',
#  'Respond_OstoMart OstoFix Flng Security T',
#  'Dressit Ster Dress Pack',
#  'Chloramphen_Eye Dps 0.5% Ud',
#  'Glyceryl Trinit_Oint 0.4%',
#  'Juvela_G/F Tea Bisc',
#  'Hydrocort/Miconazole Nit_Oint 1%/2%',
#  'Lorazepam_Oral Soln 500mcg/5ml',
#  'Microdot Droplet Needles Pen Inj Screw O',
#  'Chlordiazepox HCl_Cap 5mg',
#  'Bisacodyl_Suppos 5mg',
#  'Hollister_Conform 2 Flex Wear 55mm Float',
#  'Miconazole Nit_Crm 2%',
#  'Donepezil HCl_Tab 10mg',
#  'Oestrogel_Gel 0.06% 80g (64 Applic)',
#  'Respond_OstoMart OstoMist Blackberry P/S',
#  'Hollister_Adapt Conformable Convex Barri',
#  'Mylife Pura (Reagent)_Strips',
#  'Veil_Finishing Pdr',
#  'Unilet ComforTouch Lancets 0.375mm/28 Ga',
#  'Prograf_Cap 1mg',
#  'Coloplast_SenSura Soft Seal Bag Maxi Tra',
#  'Silver Sulfadiazine_Crm 1%',
#  'Movicol_Liq S/F',
#  'Methadone HCl_Mix 1mg/1ml S/F',
#  'Cathejell Lidocaine C Lubricant Gel 12.5',
#  'Creon 10000_Cap E/C',
#  'Fybogel_H/Fbre Gran Eff Sach3.5g OrngS/F',
#  'Levofloxacin_Tab 250mg',
#  'Bisacodyl_Suppos 10mg',
#  'Juvela_G/F W/F Cornflakes',
#  'Fluanxol_Tab 500mcg',
#  'Midazolam HCl_Inj 5mg/ml 2ml Amp',
#  'Hydrocort_Crm 1%',
#  'Tiotropium/Olodaterol_Inha2.5/2.5mcg 60D',
#  'Lamotrigine_Tab Disper 100mg S/F',
#  'Half Securon SR_Tab 120mg',
#  'Elleste Solo MX 40_Patch 40mcg/24hrs',
#  'Allevyn Ag Gentle 10cm x 10cm Wound Dres',
#  'Coloplast_SenSura Mio Click B/Plt L/Conv',
#  'Gz Swabs 7.5cm x 7.5cm Ster',
#  'Flexi-Ban 10cm x 3.5m Sub-Compress Waddi',
#  'Jobst Elvarex Soft Acc For L/Extrem Clos',
#  'Sudocrem_Antis Healing Crm',
#  'Theophylline_Tab 300mg M/R',
#  'Dansac_Nova 2 Urost Pouch Clr Flng 43mm',
#  'Coloplast_Simpla Profile Night Bag + 120',
#  'Exenatide_Inj 10mcg/0.04ml 2.4mlPfs(60D)',
#  'Convatec_Combihesive Natura Flx Flng 45m',
#  'Buscopan Cramps_Tab 10mg',
#  'Stilnoct_Tab 10mg',
#  'Ursodeoxycholic Acid_Susp 250mg/5ml S/F',
#  'Paliperidone_Inj 100mg/1ml Pfs',
#  'Jade_Ultra Flex Self-Adh Sheath Clr Inte',
#  'Risperidone_Tab 500mcg',
#  'GlucoRx Safety Lancets 1.6mm/30 Gauge',
#  'Estring_Vag Delivery System 7.5mcg/24hr',
#  'Alogliptin_Tab 12.5mg',
#  'Strepsils_Loz Sbery S/F',
#  'Lido HCl/Adren (Base)_Inj 1% 20ml Vl',
#  'Dansac_Soft Paste',
#  'Evorel 100_Patch',
#  'Fencino_Transdermal Patch 100mcg/hr',
#  'Vortioxetine_Tab 20mg',
#  'BD Viva Needles Pen Inj Screw On 4mm/32',
#  'Pentasa_Suppos 1g',
#  'Sitagliptin_Tab 50mg',
#  'Methotrexate_Tab 10mg',
#  'Erythromycin_Ethylsuc Susp 250mg/5ml',
#  'Estradiol_Val Tab 1mg',
#  'Mesalazine_Gran Sach 1g M/R S/F',
#  'Amitriptyline HCl_Tab 50mg',
#  'Sukkarto SR_Tab 500mg',
#  'Emerade_Auto Inj 1/1000 1mg/ml 0.3ml',
#  'Iodoflex Paste 5g Wound Dress H/Gel Ster',
#  'Tranylcypromine Sulf_Tab 10mg',
#  'Otrivine_Adult Nsl P/Spy 0.1% 10ml',
#  'Clomipramine HCl_Tab 75mg M/R',
#  'Rochester_Clr Advantage Slc Sheath Lge 3',
#  'Fultium-D3_Oral Dps 2 740u/ml',
#  'Zonegran_Cap 50mg',
#  'Covidien Dover All Slc Foy Male 5-10ml 1',
#  'Oxcarbazepine_Oral Susp 300mg/5ml S/F',
#  'Limb LimbO Adult 1/2 Leg Lge Build/Short',
#  'Juvela_G/F Fibre Bread Roll',
#  'Hypromellose/Dextran 70_Eye Dps 0.3/0.1%',
#  'Aymes Complete Starter Pack_Liq',
#  'Zomorph_Cap 100mg',
#  'CliniSupplies_ProSys Night Bag Non-Ster',
#  'Morph Sulf_Oral Soln 10mg/5ml',
#  'UrgoKTwo Size 18-25cm (10cm) M/Layer Com',
#  'Clotrimazole_Crm 10%',
#  'Coloplast_Assura Seal Ex B/Plt 50mm Flng',
#  'QV Gentle Wsh',
#  'Epanutin_Susp 30mg/5ml',
#  'Abidec_Dps',
#  'Mirapexin_Tab 1.05mg M/R',
#  'Opus_Lift Plus 360 Citrus Medical Adh Re',
#  'Enalapril Mal_Tab 10mg',
#  'Phenytoin_Sod Cap 100mg',
#  'Mediven For Men Class 2 B/Knee Closed To',
#  'Ins Hum Insulat_Penfill 100u/ml 3ml',
#  'K-Lite Long 10cm x 5.25m M/Layer Compres',
#  'Chloral Hydrate_Oral Soln 500mg/5ml',
#  'Plavix_Tab 75mg',
#  'Hirudoid_Crm 0.3%',
#  'Fresubin 2kcal_Drink (6 Flav)',
#  'Ibandronic Acid_Tab 150mg',
#  'Caverject_Inj Pack (40mcg Vl + Dil)',
#  'Ramipril_Tab 2.5mg',
#  'Champix_2Wk Tt Init Pack (Tab 0.5mg/1mg)',
#  'Fostair_Inh 200mcg/6mcg (120D) CFF',
#  'Fml_Ophth Susp 0.1%',
#  'Prednisolone_Tab 2.5mg',
#  'Ketoconazole_Crm 2%',
#  'Bumetanide_Tab 5mg',
#  'Pro D3 Forte_Oral Soln 3 000u/ml',
#  'Alissa Carmellose 0.5% Eye Dps 0.4ml Ud',
#  'Barkat_G/F W/F Coffee Bisc',
#  'Morph Sulf_Tab 100mg M/R',
#  'Theophylline_Tab 200mg M/R',
#  'Hollister_Compact Closed Pouch Transpt C',
#  'Tildiem Ret 90_Tab 90mg',
#  'Azithromycin_Oral Susp 200mg/5ml',
#  'KerraLite Cool Non-Adh 6cm x 6cm Wound D',
#  'Lumecare Singles Hypromellose Eye Dps 0.',
#  'Microgynon 30 ED_Tab',
#  'Felodipine_Tab 2.5mg M/R',
#  'Ethinylest/Norgestimate_Tab 35mcg/250mcg',
#  'Aquacel Foam Adhesive 10cm x 20cm Wound',
#  'Diltiazem HCl_Cap 200mg M/R',
#  'Loestrin 30_Tab',
#  'Kentera_Transdermal Patch 3.9mg/24hrs',
#  'Co-Proxamol_Tab 32.5mg/325mg',
#  'Benzoyl Per_Gel 5%',
#  'Oxybutynin HCl_Liq Spec 2.5mg/5ml',
#  'Amoxicillin_Cap 250mg',
#  'Kapake_Cap 30mg/500mg',
#  'NovoFine Needles Pen Inj Screw On 8mm',
#  'OxyContin_Tab 40mg M/R',
#  'K-Soft 10cm x 3.5m M/Layer Compress Band',
#  'Carbimazole_Tab 5mg',
#  'ActivHeal Hydrocolloid 10cm x 10cm Wound',
#  'Carbocisteine_Soln750mg/10mlSach10ml S/F',
#  'Voltarol Emulgel_Aq Gel 1.16%',
#  'Erythromycin_Cap E/C 250mg',
#  'Bullen Hi-Slip Plus Hydro Nelaton Male 8',
#  'Enoxaparin_Inj 150mg/ml 0.8ml Pfs',
#  'Fortisip_Yogurt Style Liq (3 Flav)',
#  'Epilim_Syr 200mg/5ml',
#  'Neutrogena_T/Gel 2 in 1 Shampoo & Cond',
#  'Coloplast_SenSura Soft Seal Midi Split S',
#  'Ins Humalog_100u/ml 10ml Vl',
#  'Aminophylline Hydrate_Tab 225mg M/R',
#  'Medroxyprogest Acet_Tab 5mg',
#  'Normacol Plus_Gran',
#  'Chloroquine Phos_Tab 250mg',
#  'Dioralyte_Pdr Sach (Citrus)',
#  'Lacosamide_Tab 100mg',
#  'Quetiapine_Tab 150mg M/R',
#  'OptiLube Ster Lubri Jelly Sach 5g',
#  'Mst Continus_Tab 100mg',
#  'Gaviscon Advance_Liq (Aniseed) (Reckitt)',
#  'Zestril_Tab 20mg',
#  'Fultium-D3_Cap 800u',
#  'Peak_Combimate SuperFlex 2-Piece Flng 57',
#  'Tubilux Sod Chlor Nsl Dps 0.9%',
#  'Tadalafil_Tab 2.5mg',
#  'N-A Ultra 9.5cm x 9.5cm Type 1 Ktd Visco',
#  'GlucoMen Sensor (Reagent)_Strips',
#  'Fluoxetine HCl_Cap 20mg',
#  'Coloplast_Assura Maxi Clr Bag C/Fit 10-5',
#  'Omeprazole_Tab Disper 10mg (E/C Pellets)',
#  'Advazorb 7.5cm x 7.5cm Wound Dress Polyu',
#  'Glutafin Select_G/F Fibre Loaf Brown(Cut',
#  'Morphgesic SR_Tab 10mg',
#  'ProSys_Independence No Sting Adh Remover',
#  'Cetraben_Bath Oil',
#  'Samaritan_Olive Oil',
#  'Nutramigen 1 + LGG_Pdr',
#  'Sterculia_Gran 62% Sach 7g G/F',
#  'Roaccutane_Cap 10mg',
#  'Respond_HiLINE Stch Unisex Ostomy Belt 1',
#  'Rozex_Gel 0.75%',
#  'Urgotul 10cm x 10cm Wound Dress Soft Pol',
#  'Trachi-Dress Sml 60mm x 82mm TRDRE0001 T',
#  'Hydrocort But_Oint 0.1%',
#  'Betnovate RD_Oint 0.025%',
#  'Mag Sulf_Paste',
#  'Multi-thick_Pdr',
#  'Dansac_NovaLife 1 Convex Open + View Mid',
#  'Betameth Val_Crm 0.025% (1 in 4)',
#  'Mirena_Intra-Uterine System',
#  'Forceval_Cap',
#  'Utrogestan_Cap 100mg',
#  'Ispag Husk_Gran Eff Sach 3.5g Orange S/F',
#  'B.Braun Actreen Fle Glys Set Nelaton 6-1',
#  'Class 1 Stnd C/Kt B/Knee Stkn Elas Hose',
#  'Morph Sulf_Tab 10mg M/R',
#  'Estradiol_Gel 0.06% 80g (64 Applic)',
#  'Liq Paraf_Liq',
#  'Unomedical_Careline+ Leg Bag + Lever Tap',
#  'Tegretol Prolonged Release_Tab 400mg M/R',
#  'Hollister_Moderma Flex Soft Convex Drnbl',
#  'Nebilet_Tab 5mg',
#  'Cyprote Acet_Tab 50mg',
#  'Fostair NEXThaler_Inh 200mcg/6mcg (120D)',
#  'Feanolla_Tab 75mcg',
#  'Viridal Duo_S/Pack Inj 40mcg Cart',
#  'Durafiber 10cm x 10cm Wound Dress Protea',
#  'GlucoRx Q (Reagent)_Strips',
#  'Ursodeoxycholic Acid_Tab 150mg',
#  'Bimatoprost/Timolol_EyeDps300mcg/5mg 0.4',
#  'Unspecified Stkntte 7.5cm x 0.5m Elasctd',
#  'LoFric Origo+Water Nelaton Male 40cm Siz',
#  'Tamiflu_Cap 75mg',
#  'Isotard 60 XL_Tab 60mg',
#  'Morph Sulf_Tab 20mg',
#  'Vensir XL_Cap 75mg',
#  'Gabapentin_Oral Soln 50mg/ml S/F',
#  'Lyrica_Cap 150mg',
#  'Dansac_GX-tra Seals Washers 20mm (50mm O',
#  'Bramox_Tab 5mg',
#  'Erythromycin Stearate_Tab 500mg',
#  'Isosorbide Mononit_Cap 40mg M/R',
#  'Plenachol_Cap 20 000u',
#  'Testosterone_Gel 50mg/5g Ud Tube',
#  'Rizatriptan_Orodisper Tab 10mg S/F',
#  'PaediaSure Plus_Liq (3 Flav)',
#  'Normacol_Gran 62% Sach 7g',
#  'Ethinylest/Levonorgest_Tab 30/150mcg',
#  'Loratadine_Oral Soln 5mg/5ml',
#  'Ketorolac Trometamol_Eye Dps 0.5%',
#  'Kendall Kerlix AMD Gauze 11.4cm x 3.7m T',
#  'Sertraline HCl_Tab 50mg',
#  'Doxepin_Cap 50mg',
#  'Chlorphenamine Mal_Oral Soln 2mg/5ml',
#  'Timoptol-LA_Ophth Gel-Forming Soln 0.25%',
#  'GlucoRx Lancets 0.31mm/30 Gauge',
#  'Oxycodone HCl_Tab 30mg M/R',
#  'QV Crm',
#  'Isotard 25 XL_Tab 25mg',
#  'Tinzaparin Sod_Inj 20 000u/ml 0.5ml Pfs',
#  'InVita D3_Oral Soln 25 000u/1ml',
#  'Comfifast 10.75cm x 3m (Yellow)Stkntte E',
#  'Fresubin 2kcal Creme_Dessert (Cappucino)',
#  'Salts_SecuPlast Aloe Rings 25mm',
#  'Oxycodone HCl/NaloxoneHCl_Tab 20/10mgM/R',
#  'Saizen_Inj 6mg/1.03ml Cart',
#  'Swabs 10cm x 10cm Fabric Filmated Non-Wo',
#  'Ichthopaste (6/2%) 7.5cm x 6m Zn Paste &',
#  'Lido HCl_Inj 1% 10ml Amp',
#  'Allevyn Gentle Border 7.5cm x 7.5cm Woun',
#  'Daktarin Aktiv_Pdr Spy 0.16% 100g',
#  'Ensure Shake_Oral Pdr Sach 57g (Choc)',
#  'Coloplast_Brava Lubricating Deod 240ml',
#  'Infatrini Peptisorb_Liq',
#  'Aviva (Reagent)_Strips',
#  'Capasal_Therapeutic Shampoo',
#  'Fenofibrate_Cap 67mg (Micronised)',
#  'Propranolol HCl_Cap 160mg M/R',
#  'Salbutamol_Inh Soln 5mg/2.5ml Ud',
#  'Actilite 5cm x 5cm Manuka Honey Ster Gz',
#  'Tadalafil_Tab 10mg',
#  'Nasobec Aq_Nsl Spy 50mcg (200 D) 30ml',
#  'Methadone HCl_Mix 1mg/1ml',
#  'Urgotul Silver 10cm x 12cm Wound Dress S',
#  'Estradiol_Vag Delivery System7.5mcg/24hr',
#  'Jobst Opaque Class 1 Knee High Closed To',
#  'Peristeen Rectal Cath (10-Pack)',
#  'Prednisolone_Tab 10mg',
#  'Metoject_PEN Inj 20mg/0.4ml Pf Pen',
#  'Sumatriptan_Aq Nsl Spy 20mg/0.1ml Ud',
#  'Progesterone_Pess 400mg',
#  'Alfacalcidol_Cap 1mcg',
#  'Desmopressin Acet_Tab 200mcg',
#  'Methyldopa_Tab 500mg',
#  'Ins Tresiba_FlexTouch 200u/ml 3ml Pf Pen',
#  'Xylomet HCl_Nsl Spy 0.1% 10ml',
#  'Metoclopramide HCl_Inj 5mg/ml 2ml Amp',
#  'Coloplast SpeediCath Compact Plus Fle 10',
#  'APO-go PFS_Inf 5mg/ml 10ml Pfs',
#  'SodiClor_Oral Soln 1.46g/5ml',
#  'Lisinopril/Hydchloroth_Tab 20mg/12.5mg',
#  'Rinatec_Aq Nsl Spy 21mcg (180D) 15ml CFF',
#  'Monopost_Eye Dps 50mcg/ml 0.2mlUd P/F',
#  'Sharpsguard 5L',
#  'Amias_Tab 16mg',
#  'Escitalopram_Tab 20mg',
#  'Spiriva Respimat_Inha 2.5mcg (60D) + Dev',
#  'C-View 12cm x 12cm VP Adh Film Dress',
#  'Lodine Sr_Tab 600mg',
#  'Hy-Opti 0.1% Sod Hyaluronate Eye Dps 10m',
#  'Clinipod Sod Chlor Top Irrig 0.9% 20ml',
#  'Amitriptyline HCl_Tab 10mg',
#  'MacuShield_Cap',
#  'Levocetirizine_Oral Soln 500mcg/ml S/F',
#  'Eurax_Crm 10%',
#  'Oilatum_Crm (New Form) (Liq)',
#  'Umeclidinium/Vilanterol_Inha 65/22mcg30D',
#  'Prednisolone_Tab Solb 5mg',
#  'Dansac_Non Sting Adh Remover Sach',
#  'Augmentin-Duo 400/57_Pdr For Susp S/F',
#  'One-Alpha_Cap 500ng',
#  'Hylo-Fresh Sod Hyaluronate Eye Dps P/F 1',
#  'Goserelin Acet_Implant 10.8mg Pfs',
#  'Juvela_G/F Fresh Loaf Wte (Cut)',
#  'Chlorhex Glucon_Soln 4%',
#  'Vagifem_Vag Tab 10mcg',
#  'Tibolone_Tab 2.5mg',
#  'Nedocromil Sod_Eye Dps Aq 2%',
#  'Celluvisc_Eye Dps 0.5% 0.4ml Ud',
#  'Amoxil_Cap 500mg',
#  'Oilatum_Emollient',
#  'Zantac_Tab 300mg',
#  'Etoricoxib_Tab 30mg',
#  'C D Medical_Peel Easy Adh Remover Spy 50',
#  'Nerisone Fte_Oily Crm 0.3%',
#  'BSN_Cutimed Prote Crm 90g',
#  'Abasaglar_100u/ml 3ml Cart',
#  'Glucotabs_Tab (Tangy Orange)',
#  'Coloplast_Assura Insp Midi Closed Bag Tr',
#  'Valupak_Multivit & Mineral Tab OAD',
#  'CliniMed_Appeel No Sting Medical Adh Rem',
#  'Shortec_Cap 5mg',
#  'Tubifast 2-Way Stch 7.5cm x 1m (Blue) St',
#  'Fucibet_Crm',
#  'Combigan_Eye Dps',
#  'Ranolazine_Tab 375mg M/R',
#  'Rizatriptan_Tab 5mg',
#  'Respond_OstoMart OstoPEEL Mint No Sting',
#  'Lithium Carb_Tab 250mg',
#  'Pholcodine_Linct Strong 10mg/5ml S/F',
#  'Levonorgest_Tab 30mcg',
#  'Sod Cromoglicate_Eye Dps 2% 0.3ml Ud P/F',
#  'KerraPro 10 x 10 x 0.3cm Sheet Low Frict',
#  'Vivotif_(Oral Vac) Cap',
#  'Aspirin_Tab 300mg',
#  'Dianette_Tab 2mg/35mcg',
#  'Hydromol Sod Pidolate Crm 2.5% 50g (App)',
#  'Eumovate_Crm 0.05%',
#  'Acipimox_Cap 250mg',
#  'Dhc Continus_Tab 60mg',
#  'Amiloride HCl/Bumetanide_Tab 5mg/1mg',
#  'Calcipotriol/Betameth_Gel 0.005%/0.05%',
#  'Ins Glargine_Inj 100u/ml 3ml Pf Pen',
#  'Mesorb 10cm x 10cm Pfa Cellulose Dress',
#  'Clotrimazole_Pess 500mg',
#  'Equasym XL_Cap 20mg',
#  'Amoxicillin_Cap 500mg',
#  'Minims_Artificial Tears Ud P/F',
#  'Betameth Diprop/Clotrimazole_Crm0.064/1%',
#  'Dermatonics Once Heel Balm',
#  'Aciferol D3_Tab 20 000u',
#  'Canesten HC_Crm',
#  'Fexofenadine HCl_Tab 120mg',
#  'Valsartan_Tab 320mg',
#  'Nicorette Invisi_Patch 25mg/16hrs',
#  'Ellaone_Tab 30mg',
#  'Zolpidem Tart_Tab 5mg',
#  'Jade_Velcro Leg Strap',
#  'Viazem XL_Cap 360mg',
#  'Thicken Aid_Pdr',
#  'Anhydrol Fte_A-Pers Soln 20%',
#  'Perindopril Erbumine_Tab 8mg',
#  'Peristeen System',
#  'Oramorph_Oral Soln Conc 20mg/ml S/F',
#  'Nutramigen 2 LIPIL_Pdr',
#  'Provox TrachPhone HME 7707 Tracheo B/Aid',
#  'Nebusal Sod Chlor 7% Inh Soln 4ml',
#  'Ibuprofen_Tab 600mg',
#  'Coloplast_SenSura Click Soft Seal B/Plt',
#  'Natecal D3_Tab Chble 600mg/400u',
#  'Clobazam_Oral Susp 5mg/5ml S/F',
#  'Xemacort_Crm',
#  'Isosorbide Mononit_Tab 20mg',
#  'Bactroban_Crm 2%',
#  'Midodrine HCl_Tab 2.5mg',
#  'Levetiracetam_Tab 500mg',
#  'Clonidine HCl_Tab 100mcg',
#  'Emla_Crm 5%',
#  'Biatain Slc 12.5cm x 12.5cm Wound Dress',
#  'Oxybutynin HCl_Tab 10mg M/R',
#  'Mobile (Reagent)_Strips',
#  'Hollister_Conform 2 Flat Barrier +Adh 55',
#  'Jade_Ultra Flex Extra Self-Adh Sheath Cl',
#  'Piloc HCl_Eye Dps 4%',
#  'GlucoMen LX Sensor (Reagent)_Strips',
#  'PolyMem 7cm x 7cm Wound Dress Polyureth',
#  'Repaglinide_Tab 500mcg',
#  'Mezolar Matrix_TransdermalPatch 50mcg/hr',
#  'Sirdupla_Inh 125mcg/25mcg (120D)',
#  'Mebendazole_Oral Susp 100mg/5ml',
#  'Welland_FreeStyle Vie Convex Drnbl Pch M',
#  'Fortijuce_S/Pack Liq',
#  'Gliclazide_Tab 80mg',
#  'Omeprazole_Oral Susp 5mg/5ml',
#  'Hypromellose_Eye Dps 0.32%',
#  'Colomycin_Inj 2 000 000u Vl (Dry)',
#  'Singulair_Tab 10mg',
#  'Adoport_Cap 500mcg',
#  'Cipralex_Tab 20mg',
#  'Ondansetron HCl_Tab 8mg',
#  'Coloplast_SenSura Soft Seal Maxi Transpt',
#  'Lixisenatide_Inj 10mcg+20mcg/0.2ml 3mlPf',
#  'Verapamil HCl_Tab 40mg',
#  'Advagraf_Cap 1mg M/R',
#  'Loratadine_Tab 10mg',
#  'Ranitidine HCl_Tab 75mg',
#  'Mesorb 10cm x 15cm Pfa Cellulose Dress',
#  'Seroquel_Tab 100mg',
#  'Glutafin_G/F W/F H/Fbre Cracker',
#  'Tears Naturale_Eye Dps',
#  'Nystaform-HC_Oint',
#  'Neoclarityn_Tab 5mg',
#  'Fortini_Liq (2 Flav)',
#  'Isopto_Alkaline 1%',
#  'Vit E_Cap 75u',
#  'Etoricoxib_Tab 120mg',
#  'Monomil XL_Tab 60mg',
#  'Trifluoperazine_Oral Soln 1mg/5ml S/F',
#  'Epilim Chrono 500_Tab 500mg C/R',
#  'Carbimazole_Tab 20mg',
#  'Flixotide_Evohaler 125mcg (120 D)',
#  'Humapen Savvio Blue 3ml 1u (1-60u) Hypod',
#  'Salbutamol_Inha B/A 100mcg (200 D) CFF',
#  'Mometasone Fur_Crm 0.1%',
#  'Ethinylest/Norethist_Tab 35mcg/500mcg',
#  'Juvela_G/F Mix Wte',
#  'Silvercel Non-Adher 11cm x 11cm Wound Dr',
#  'Clindamycin Phos_Vag Crm 2% + Applic',
#  'Hollister_Conform 2 Maxi Closed Pouch +',
#  'Dosulepin HCl_Tab 75mg',
#  'Ropinirole HCl_Tab 1mg',
#  'Aclid/Formot_PdrFor Inh 396/11.8mcg(60D)',
#  'Micronor_Tab 350mcg',
#  'Aquacel Ag Extra 10cm x 10cm Wound Dress',
#  'Coloplast_Assura Insp C/exity S/Seal Max',
#  'Orlistat_Cap 60mg',
#  'Hollister_Compact Urost Pouch Transpt C/',
#  'Mepilex Border 7cm x 7.5cm Wound Dress S',
#  'ActiFormCool 10cm x 10cm Wound Dress H/G',
#  'Acti-Fast 2-Way Stch 10.75cmx5m(Yell)Stk',
#  'HBVAXPRO_Vac 10mcg/ml 1ml Pfs',
#  'Lustral_Tab 50mg',
#  'Pioglitazone HCl_Tab 15mg',
#  'Water For Inj_2ml Amp',
#  'Fortini_Smoothie Multi Fibre Liq(2 Flav)',
#  'E45_Lot',
#  'Povitulle 5cm x 5cm Povidone Iodine Fabr',
#  'Sotalol HCl_Tab 40mg',
#  'OxyNorm_Cap 20mg',
#  'Doxepin HCl_Crm 5%',
#  'Rosuvastatin Calc_Tab 20mg',
#  'Opatanol_Eye Dps 1mg/ml',
#  'Glutafin_G/F W/F Pasta Shell',
#  'Ramipril_Cap 5mg',
#  'Repinex XL_Tab 2mg',
#  'Seretide 500_Accuhaler 500mcg/50mcg(60D)',
#  'Morphgesic SR_Tab 30mg',
#  'Convatec_Combihesive Natura Closed Pouch',
#  'Ins Humulin I_KwikPen 100u/ml 3ml Pf Pen',
#  'AMI_Suportx Ostomy/Hernia Easy Peel Supp',
#  'Ranitidine HCl_Tab 300mg',
#  'Ezetimibe_Tab 10mg',
#  'Saline Steripoule_Inh Soln 0.9% 2.5ml Ud',
#  'BuTrans_Transdermal Patch 20mcg/hr',
#  'Levothyrox Sod_Oral Soln 50mcg/5ml S/F',
#  'Furosemide_Oral Soln 20mg/5ml S/F',
#  'Doxycycline Hyclate_Cap 50mg',
#  'Revaxis_Vac 0.5ml Pfs',
#  'Stericlens Sod Chlor Top Irrig A/Spy 240',
#  'Provera_Tab 100mg',
#  'Metolazone_Tab 2.5mg',
#  'Efracea_Cap 40mg M/R',
#  'Maexeni_Tab 150mcg/30mcg',
#  'Glycopyrronium Brom_Inj 0.2mg/ml 3ml Amp',
#  'Ventolin_Evohaler 100mcg (200 D)',
#  'Perampanel_Tab 10mg',
#  'Hospilite 15cm x 4.5m Cott Polyam & Elas',
#  'Arimidex_Tab 1mg',
#  'Adizem-XL_Cap 120mg',
#  'Fluclox Sod_Oral Soln 250mg/5ml',
#  'Lithium Carb_Tab 400mg M/R',
#  'Aymes Shake_S/Pack Pdr',
#  'Octasa_MR Tab E/C 400mg',
#  'Circadin_Tab 2mg M/R',
#  'Saxagliptin_Tab 2.5mg',
#  'Nebivolol_Tab 2.5mg',
#  'Dexameth_Tab Solb 2mg S/F',
#  'Pyridox HCl_Tab 50mg',
#  'Linaclotide_Cap 290mcg',
#  'Hydromorphone HCl_Cap 8mg M/R',
#  'Sod Bicarb_Cap 500mg',
#  'Cefalexin_Oral Susp 250mg/5ml',
#  'Mupirocin_Oint 2%',
#  'PF Drops 1% Carmellose Eye Dps 10ml',
#  'Miconazole_Oromucosal Gel 20mg/g S/F',
#  'Paracet_Oral Susp Paed 120mg/5ml S/F',
#  'Simvastatin_Tab 20mg',
#  'Zerobase Crm (Appl)',
#  'ActivHeal Hydrogel 8g Wound Dress H/Gel',
#  'Ethinylestr_Tab 10mcg',
#  'Fluticasone Prop_Pdr For Inh 500mcg(60D)',
#  'Galpseud Plus_Linct S/F',
#  'Clinimed_HydroFrame Mini Flange Extender',
#  'Myfortic_Tab 180mg G/R',
#  'LoFric Non PVC Nelaton Male 8-22 (30-Pac',
#  'Tocoph Acet_Susp 500mg/5ml',
#  'Haloperidol Decan_Inj 50mg/ml 1ml Amp',
#  'Augmentin_Tab 375mg',
#  'Zetuvit Plus 10cm x 10cm Super-Absorb Dr',
#  'Glucose_Gel 40%',
#  'Mag Hydrox_Mix',
#  'Bard_Uriplan Leg Bag 10cm Inlet Tube 750',
#  'Prednisolone Sod Phos_Ear/Eye Dps 0.5%',
#  'Isomol Gel 100g',
#  'Carteolol HCl_Eye Dps 1%',
#  'Glucojuice_Liq',
#  'Praxilene_Cap 100mg',
#  'Nurse It Ster Dress Pack',
#  'Zindaclin_Gel 1%',
#  'Hydrocort/Clotrimazole_Crm 1%/1%',
#  'ConvaTec_ConvaTec Silesse Sting Free Ski',
#  'Keppra_Tab 750mg',
#  'Atarax_Tab 25mg',
#  'CliniMed_Hyperseal Washers Sml (2.5mm th',
#  'Prothiaden_Tab 75mg',
#  'Angitil SR 180_Cap 180mg',
#  'Flixotide_Evohaler 250mcg (120 D)',
#  'Calc Acet_Tab 950mg',
#  'Slo-Phyllin_Cap 250mg',
#  'Hypromellose/Dextran 70_Eye Dps.3/.1% Ud',
#  'Entacapone_Tab 200mg',
#  'WyCath H2O Nelaton Soft Tip Male 40cm 10',
#  'Sunsense_Ultra Lot Spf 50+',
#  'Amorolfine HCl_Nail Lacquer Kit 5% 5ml',
#  'TriCare Needles Pen Inj Screw On 4mm/32',
#  'Opus_SkinSafe Non Sting Prote Film',
#  'Mefenamic Acid_Cap 250mg',
#  'Azithromycin_Tab 250mg',
#  'Mupirocin_Nsl Oint 2%',
#  'Levetiracetam_Oral Soln 500mg/5ml S/F',
#  'Mextra Superabsorbent 20cmx30cm Wound Dr',
#  'Femodette_Tab',
#  'Fluticasone/Salmeterol_Inh 250/50mcg 60D',
#  'Biotene Moisturising Mthwsh',
#  'Nerisone_Oily Crm 0.1%',
#  'Fluticasone Prop_Crm 0.05%',
#  'Xenical_Cap 120mg',
#  'Nefopam HCl_Tab 30mg',
#  'Alprostadil_Inj 10mcg Pfs Cart',
#  'Nutrison Pack_1200 Complete M/Fibre Liq',
#  'Betameth Val_Crm 0.1%',
#  'Elleste Duet_Tab 1mg',
#  'KerraPro 10 x 10 x 1.2cm Sheet Low Frict',
#  'Prontosan Top Irrig 40ml',
#  'Procyclidine HCl_Oral Soln 5mg/5ml S/F',
#  'Nystan_Susp (Ready Mixed)',
#  'Calci-D_Tab Chble 1g/1 000u',
#  'Advazorb Border Lite 7.5cm x 7.5cm Wound',
#  'Respond_OstoMart Cool Comfort Unisex Gmt',
#  'Advazorb 10cm x 10cm Wound Dress Polyure',
#  'Coloplast_Trident T2 Leg Bag 500ml Adjus',
#  'DuoDERM Ex Thin 7.5cm x 7.5cm Wound Dres',
#  'Elantan LA 25_Cap 25mg',
#  'Matrifen_Patch 50mcg/hr',
#  'Aspen_Sorbaderm Barrier Crm 28g',
#  'CliniMed_Hyperseal Washers+Manuka HoneyS',
#  'Alphaderm_Top Steroid Crm 1%/10%',
#  'Piroxicam_Orodisper Tab 20mg S/F',
#  'Terbinafine HCl_Crm 1%',
#  'Metoclopramide HCl_Oral Soln 5mg/5ml S/F',
#  'Barkat_G/F W/F Cornflakes',
#  'Beclomet Diprop_Inha 100mcg (200 D) CFF',
#  'GlucoMen Visio (Reagent)_Strips',
#  'Aquacel Foam Non-Adhesive 10cm x 10cm Wo',
#  'Fluocinonide_Oint 0.05%',
#  'Flotros_Tab 20mg',
#  'Salamol E-Breathe_Inh 100mcg (200 D) CFF',
#  'Coloplast_Trident T1 Leg Bag 500ml Short',
#  'Episenta_Cap 300mg M/R',
#  'Aciclovir_Tab Disper 800mg',
#  'Serc-8_Tab 8mg',
#  'Peptac_Liq (Aniseed) S/F',
#  'Indapamide_Tab 1.5mg M/R',
#  'Mebeverine HCl_Tab 135mg',
#  'Unilet Eco Lancets 0.375mm/28 Gauge',
#  'Trazodone HCl_Oral Liq 50mg/5ml S/F',
#  'Coloplast SpeediCath Compact Set Fle Siz',
#  'MicardisPlus_Tab 80mg/12.5mg',
#  ...}

# %%
bnf_names
# Out:
# {'Hospiform 10cm x 4m Conform Syn Band',
#  'Warfarin Sod_Oral Susp 1mg/1ml S/F',
#  'Maxitram SR_Cap 50mg',
#  'Trimethoprim_Tab 200mg',
#  'Fragmin_Inj 25 000u/ml 0.6ml Pfs',
#  'Co-Amilofruse_Tab 5mg/40mg',
#  'Trental 400_Tab 400mg',
#  'CosmoCol_Oral Pdr Sach (Orng Lem & Lim)',
#  'Teleflex_Rusch Leg Bag 500ml 10cm Tubing',
#  'Dulaglutide_Inj 0.75mg/0.5ml Pf Dev',
#  'Hydrocort But_Scalp Lot 0.1%',
#  'Dalteparin Sod_Inj 25 000u/ml 0.4ml Pfs',
#  'Dalivit_Dps',
#  'Medikinet XL_Cap 20mg',
#  'Bumetanide_Tab 1mg',
#  'Diazepam_Tab 5mg',
#  'Dexameth_Oral Soln 2mg/5ml S/F',
#  'Aquacel Ag 5cm x 5cm Wound Dress Proteas',
#  'Sod Algin/Pot Bicarb_Susp S/F',
#  'Clobavate_Oint 0.05%',
#  'Prempak-C_C/Pk Tab 1.25mg/150mcg',
#  'Aprovel_Tab 150mg',
#  'Ins Detemir_Inj 100u/ml 3ml Pf Pen',
#  'Gaviscon_Liq Orig Aniseed Relief',
#  'Medicareplus_Medi Derma-S Barrier Crm 90',
#  'Fosinopril Sod_Tab 10mg',
#  'Ispag Husk_Gran Sach 3.5g G/F',
#  'FemSeven 50_Patch 50mcg/24hrs',
#  'Dovobet_Gel Applic',
#  'Methylpred Acet/Lidoc_Inj 80/20mg/2ml Vl',
#  'ActiLymph Class 1 B/Knee Closed Toe Sand',
#  'Xatral_XL Tab 10mg',
#  'Activa Leg Ulcer Hose Kit Med Clsd Toe C',
#  'Cetirizine HCl_Oral Soln 1mg/1ml S/F',
#  'CliniMed_Appeel Advance No Sting Medic A',
#  'Viazem XL_Cap 300mg',
#  'Hypromellose_Eye Dps 0.5%',
#  'Movicol-Half_Pdr Sach 6.9g (Lem & Lim)',
#  'K-Y Lubri Jelly',
#  'Adipine XL_Tab 60mg',
#  'Carvedilol_Tab 25mg',
#  'Carbocisteine_Oral Soln 250mg/5ml',
#  'Carvedilol_Tab 6.25mg',
#  'Tegaderm Foam Adh Oval 10cm x 11cm Wound',
#  'Forticreme Complete_Dessert (F/Fruits)',
#  'Prednisolone_Tab E/C 2.5mg',
#  'Nicotine_Nsl Spy 500mcg (200 D) 10ml',
#  'Volumatic',
#  'Promethazine Teoclate_Tab 25mg',
#  'Pramipexole_Tab 350mcg',
#  'Thick & Easy_Food Thickener Pdr Sach 9g',
#  'Alimemazine Tart_Tab 10mg',
#  'Esomeprazole_Tab E/C 40mg',
#  'Losec_Cap E/C 10mg',
#  'ChloraPrep_Soln Applic 3ml',
#  'Water For Inj_20ml Amp',
#  'Doublebase_Emollient Bath Add',
#  'Madopar_Tab Disper 50mg/12.5mg',
#  'Morph Sulf_Cap 30mg M/R',
#  'Aquacel Ag 15cm x 15cm Wound Dress Prote',
#  'Zipzoc_Zn Ox Impregnated Medic Stkn',
#  'Fragmin_Inj 25 000u/ml 0.5ml Pfs',
#  'Mezolar Matrix_T/Derm Patch 37.5mcg/hr',
#  '3m Health Care_Cavilon No Sting 3ml Barr',
#  'Bupeaze_Transdermal Patch 35mcg/hr(96hr)',
#  'Uro-Tainer Twin Solution R 2 x 30ml Cath',
#  'Gamolenic Acid_Cap 80mg',
#  'OneTouch Delica Lancets 0.32mm/30 Gauge',
#  'Norethist_Tab 350mcg',
#  'Lodoxamide Trometamol_Eye Dps 0.1%',
#  'Colecal & Calc_Tab Chble 880u/2.5g',
#  'Tildiem_Tab 60mg',
#  'AMI_Suportx Ostomy & A/Support Ladies Br',
#  'Hepat A_Vac 1440u/ml 1ml Pfs',
#  'Mesalazine_Foam Aero Enem 1g/D 14g',
#  'Ibuleve_Max Strgh Gel 10%',
#  'Cardioplen XL_Tab 2.5mg',
#  'Betameth Diprop_Oint 0.05%',
#  'Ins Degludec_100u/ml 3ml Cart',
#  'Ferrograd_Filmtab',
#  'Enstilar_Foam Aero 50mcg/0.5mg/g',
#  'Clarithromycin_Oral Susp 250mg/5ml',
#  'Cocois_Oint',
#  'Imodium_Original Cap 2mg',
#  'AproDerm Emollient Crm 450g',
#  'Genius_G/F Bread Wte (Cut)',
#  'Candesartan Cilexetil_Tab 4mg',
#  'Coloplast_Sensura Mio Midi DrnblBag Grey',
#  'Evacal D3_Tab Chble 400u/1.5g',
#  'Levonelle_Tab 1.5mg',
#  'Mediven Elegance Class 1 B/Knee Closed T',
#  'Ismo 20_Tab 20mg',
#  'Melatonin_Cap 10mg',
#  'Premarin_Tab 1.25mg',
#  'Hydrofilm 10cm x 12.5cm Vp Adh Film Dres',
#  'Hydrocort_Tab 10mg',
#  'Clopixol_Tab 2mg',
#  'Etodolac_Tab 600mg M/R',
#  'Repinex XL_Tab 8mg',
#  'Sumatriptan_Inj 6mg/0.5ml Pfs Ref',
#  'Alprostadil_Cont Pack Inj 10mcg Cart',
#  'Alimemazine Tart_Oral Soln 30mg/5ml',
#  'Slo-Phyllin_Cap 125mg',
#  'CarePoint Needles Pen Inj Screw On 6mm',
#  'Calcipotriol_Scalp Soln 50mcg/ml',
#  'Sinemet CR_Tab 250mg',
#  'Lormetazepam_Tab 1mg',
#  'Sorbsan Ribbon (+ Probe) 40cm Wound Dres',
#  'Trio_Elisse Sting Free Skin Barrier Spy',
#  'Ponstan_Cap 250mg',
#  'Amoxil_Cap 250mg',
#  'Esomeprazole_Cap E/C 20mg',
#  'kliniderm superabsorbent 20cm x 20cm Pfa',
#  'Colecal_Tab 400u',
#  'CosmoCol_Half Oral Pdr Sach 6.9g',
#  'Simvador_Tab 10mg',
#  'Uniphyllin Continus_Tab 400mg',
#  'Gz & Cott Tiss BP 1988',
#  'Coloplast_Conveen Sheath Liner',
#  'Verapamil HCl_Tab 120mg M/R',
#  'Dansac_Nova Mini Cap Opqe C/Fit 20-50mm',
#  'Escitalopram_Tab 5mg',
#  'Timolol_Eye Dps 0.5%',
#  'Balneum Plus_Crm',
#  'Pelican_Cohesive Seals Sml 48mm',
#  'Amlodipine_Oral Soln 5mg/5ml S/F',
#  'E45_Emollient Bath Oil',
#  'Menthol & Eucalyptus_Inh BP 1980',
#  'Ovranette_Tab 150mcg/30mcg',
#  'Fresubin 2kcal Fibre_Drink (6 Flav)',
#  'L.IN.C_LINC-Flo Night Drain Bag Ster Nrv',
#  'Angitil SR 90_Cap 90mg',
#  'Glibenclamide_Tab 5mg',
#  'Influenza_Vac Inact 0.5ml Pfs',
#  'Premarin_Tab 300mcg',
#  'Convatec_Sensi-Care Sting Free Prote Bar',
#  'Telfast 120_Tab 120mg',
#  'Salbutamol_Tab 4mg',
#  'Viscotears_Eye Gel 2mg/g 0.6ml Ud',
#  'Metformin HCl_Tab 850mg',
#  'Bonviva_Tab 150mg F/C',
#  'Doublebase_Dayleve gel',
#  'Algivon 10cm x 10cm Wound Dress Algin St',
#  'Molaxole_Pdr Sach',
#  'Dihydrocodeine Tart_Tab 90mg M/R',
#  'Clotrimazole_Pess 100mg',
#  'Arthrotec 75_Tab',
#  'Malathion_Aq Lot 0.5%',
#  'Brinzolamide_Eye Dps 10mg/ml',
#  'Salts_Confidence Natural Drnbl Pch Trans',
#  'E45_Emollient Shower Crm',
#  'Ipinnia XL_Tab 8mg',
#  'B.Braun Actreen Male Glys Set Nelaton 8-',
#  'Olanzapine_Orodisper Tab 20mg S/F',
#  'Colecal_Cap 20 000u',
#  'Half Beta-Prograne MR_Cap 80mg',
#  'Sumatriptan_Inj 6mg/0.5ml Pfs + Dev',
#  'Clindamycin Phos_Gel 1%',
#  'Reletrans_Transdermal Patch 10mcg/hr',
#  'Zomig_Rapimelt Orodisper Tab 5mg',
#  'Tubifast 2-Way Stch 10.75cm x 1m YellowS',
#  'Teoptic_Eye Dps 1%',
#  'Juvela_G/F W/F Flakes',
#  'Maxijul Super Solb_Pdr',
#  'Risperidone_Tab 2mg',
#  'Promethazine HCl_Tab 10mg',
#  'Tentrini Pack_G/F M/Fibre Feed',
#  'Tetracycline_Tab 250mg',
#  'Fluticasone/Formoterol_Inh 125/5mcg 120D',
#  'Betnesol-N_Ear/Eye/Nose Dps',
#  'Coloplast_SenSura Mio Click B/Plt D/Conv',
#  'Subutex_Tab Subling 2mg',
#  'Tegaderm + Pad 9cm x 15cm VP Adh Film Dr',
#  'Epilim 500_Tab E/C 500mg',
#  'Cosopt_Ocumeter Plus Eye Dps',
#  'Zerolatum Plus_Bath Additive',
#  'Oxcarbazepine_Tab 300mg',
#  'Atomoxetine HCl_Cap 25mg',
#  'Memantine HCl_Oral Soln 10mg/ml S/F',
#  'Matrifen_Patch 25mcg/hr',
#  'Ascorbic Acid_Tab 200mg',
#  'Dansac_NovaLife 1 Open + View Midi Opqe',
#  'Alprostadil_Urethral Stick 1mg',
#  'Betaxolol_Soln Eye Dps 0.5%',
#  'Paliperidone_Inj 150mg/1.5ml Pfs',
#  'Hydromol_Bath & Shower Emollient',
#  'Serevent_Accuhaler 50mcg (60 D)',
#  'Goserelin Acet_Implant 3.6mg Pfs',
#  'Chemydur 60 XL_Tab 60mg',
#  'Calamine_Lot',
#  'Coloplast_Sensura Mio Maxi Drnbl Bag Tra',
#  'Diamox SR_Cap 250mg',
#  'Spiroco XL_Tab 8mg',
#  'Dorzolamide_Eye Dps 2%',
#  'Movelat_Gel',
#  'Propiverine HCl_Cap 30mg M/R',
#  'Sod Valpr_Oral Soln 200mg/5ml',
#  'Methylphenidate HCl_Tab 10mg',
#  'Estradiol/Norethist Acet_Tab 2mg/1mg',
#  'Midazolam_Liq Spec 50mg/5ml',
#  'Zetuvit E 20cm x 40cm Pfa Cellulose Dres',
#  'Ins Insuman Comb 25 SoloStar_3ml Pf Pen',
#  'N-A Dress 9.5cm x 9.5cm Type 1 Ktd Visco',
#  'Hydroxychlor Sulf_Tab 200mg',
#  'Sytron_Elix 190mg/5ml S/F',
#  'Unomedical_Careline Leg Bag Straps',
#  'Elleste Solo_Tab 2mg',
#  'Prucalopride_Tab 1mg',
#  'Flurbiprofen_Loz 8.75mg',
#  'Allevyn Gentle Border 12.5cm x 12.5cm Wo',
#  'Hospicrepe 233 10cm x 4.5m Cott Stch Ban',
#  'Episenta_Gran Sach 500mg M/R',
#  'Diprobase_Crm',
#  'Mesalazine_Suppos 1g',
#  'Isosorbide Dinit_Tab 20mg M/R',
#  'UrgoKTwo Size 25-32cm (10cm) M/Layer Com',
#  'Flamazine_Crm 1%',
#  'Anastrozole_Tab 1mg',
#  'Salts_SecuPlast Mouldable Seals Stnd',
#  'Zetuvit Plus 15cm x 20cm Super-Absorb Dr',
#  'Juvela_G/F Loaf P/Bke',
#  'Cyanocobalamin_Tab 1mg M/R',
#  'Seebri_Breezhaler Inh Cap 55mcg + Dev',
#  'Combivent UDVs_Neb Soln Ud 2.5ml',
#  'Actico 10cm x 6m Short Stch Compress Ban',
#  'Lansoprazole_Orodisper Tab 30mg',
#  'Furosemide_Tab 40mg',
#  'Paraf_Soft Wte (S)',
#  'Felodipine_Tab 10mg M/R',
#  'Softpore 10cm x 20cm Pfa + Adh Border Dr',
#  'Naloxegol_Tab 25mg',
#  'Buccolam_Oromuc Soln 10mg/2ml Oral Pfs',
#  'Calogen_Emuls (Sbery)',
#  'Moclobemide_Tab 300mg',
#  'Scanpor 2.5cm x 10m Surg Adh Tape Perm N',
#  'Elvanse_Cap 40mg',
#  'Omeprazole_Oral Susp 10mg/5ml',
#  'Solpadol_Cap 30mg/500mg',
#  'Simvastatin_Tab 40mg',
#  'C-View 10cm x 12cm VP Adh Film Dress',
#  'Ethosuximide_Oral Soln 250mg/5ml',
#  'Timolol_Gel Eye Dps 1mg/g 0.4g Ud P/F',
#  'Exorex_Crm',
#  'Vistamethasone_Ear/Eye/Nose Dps 0.1%',
#  'Zomorph_Cap 10mg',
#  'Spiriva_Pdr For Inh Cap 18mcg+HandiHaler',
#  'Melophthal 0.5% Carmellose Eye Dps 0.4ml',
#  'Venlalic XL_Tab 225mg',
#  'Omeprazole_Oral Susp 20mg/5ml',
#  'Duloxetine HCl_Cap G/R 60mg',
#  'Isosorbide Mononit_Cap 60mg M/R',
#  'Beclomet Diprop_Nsl Spy 50mcg (200 D)',
#  'Fluorome_Eye Dps 0.1%',
#  'Fluocinolone Aceton_Crm 0.00625%',
#  'Dosulepin HCl_Cap 25mg',
#  'Vagisil_Medic Creme',
#  'Insight Cannula Swab Lge Tracheo Cleanin',
#  'Co-Tenidone_Tab 100mg/25mg',
#  'Latanoprost/Timolol_Eye Dps 50mcg/5mg/ml',
#  'Lorazepam_Tab 1mg',
#  'Vega_ZM3 Multivit/Min V/Cap',
#  'Bullen_Shelter Safe-Seal',
#  'Comfifast MultiStretch 2-way Stch 10.75c',
#  'Labetalol HCl_Tab 200mg',
#  'GluNEO (Reagent)_Strips',
#  'Fexofenadine HCl_Tab 30mg',
#  'Medroxyprogest Acet_Tab 100mg',
#  'Nabumetone_Tab 500mg',
#  'CarePoint Needles Pen Inj Screw On 8mm',
#  'Venlablue XL_Cap 37.5mg',
#  'Modafinil_Tab 200mg',
#  'Urea_Lot 10%',
#  'GelTears_Ophth Gel 0.2%',
#  'Isotrex_Gel 0.05%',
#  'Glucophage SR_Tab 750mg',
#  'Estraderm MX 100_Patch',
#  'Coloplast_Simpla Plus Leg Bag Ster 500ml',
#  'DesmoMelt_Oral Lyoph 120mcg',
#  'Subutex_Tab Subling 8mg',
#  'Madopar_Cap 100mg/25mg',
#  'Ethinylestr/Norelgest_24 Hr T/Derm Patch',
#  'Calc & Ergocalciferol_Tab 400u',
#  'Docusate Sod_Oral Soln 12.5mg/5ml S/F',
#  'TheiCal D-3_Tab Chble 1000mg/880u',
#  'Zumenon_Tab 2mg',
#  'Incruse Ellipta_Inh 55mcg (30D)',
#  'Sigvaris Cotton Class 1 B/Knee Closed To',
#  'Acenocoumarol_Tab 1mg',
#  'Salts_Fresh Aire Odour Eliminating Deod',
#  'Fluticasone Prop_Inha 250mcg (120 D) CFF',
#  'Fresenius Sod Chlor Top Irrig 0.9% 1L',
#  'Convatec_Orahesive Pdr',
#  'Etrivex_Shampoo 500mcg/g',
#  'Ephed HCl_Nsl Dps 0.5% BP',
#  'Hylo-Forte Sod Hyaluronate Eye Dps 0.2%',
#  'Hyoscine Butylbrom_Inj 20mg/ml 1ml Amp',
#  'Convatec_System 2 Belt',
#  'Erythromycin_Ethylsuc Susp 125mg/5ml S/F',
#  'CliniFix Tube Holder 110mm x 25mm Cath A',
#  'Diclofenac Sod_Gel 3%',
#  'Saxagliptin_Tab 5mg',
#  'Relvar Ellipta_Inha 184mcg/22mcg (30 D)',
#  'Menthol In Aq_Crm 2%',
#  'Salts_Dermacol Stoma Collar 35mm',
#  'Olmesartan Medox/Hydchloroth_Tab 20/12.5',
#  'Adizem-XL_Cap 240mg',
#  'Jevity 1.5kcal_Liq',
#  'Ropinirole HCl_Tab 3mg M/R',
#  'Terazosin HCl_Tab 5mg',
#  'Dalacin T_Top Lot 1%',
#  'Nicorette_Chewing Gum 4mg S/F(Icy Wte)',
#  'Complan_Shake Pdr Sach 57g (Banana)',
#  'Alphagan_Eye Dps 0.2%',
#  'Ethinylestr/Gestodene_Tab 20mcg/75mcg',
#  'CliniFast 7.5cm x 3m (Blue) Stkntte Elas',
#  'Clomifene Cit_Tab 50mg',
#  'Losec MUPS_Tab Disper 10mg (E/C Pellets)',
#  'Dovobet_Gel 0.005%/0.05%',
#  'Vipdomet_Tab 12.5mg/1g',
#  'Digoxin_Oral Soln Paed 50mcg/ml',
#  'Aciferol D3_Oral Soln 3 000u/ml',
#  'Rabeprazole Sod_Tab E/C 20mg',
#  'Cetaphil_Gentle Skin Cleanser',
#  'Mercilon_Tab',
#  'Mag Glycerophos_Oral Soln 121.25mg/5ml',
#  'Coloplast_Coloplast Prote Rings 20mm',
#  'Naftidrofuryl Oxal_Cap 100mg',
#  'Alfuzosin HCl_Tab 10mg M/R',
#  'Zetuvit E (Non-Ster) 10cm x 20cm Pfa Cel',
#  'Toujeo_300u/ml 1.5ml Pf SoloStar Pen',
#  'Coloplast SpeediCath Fle Size 10-14 (30-',
#  'Zapain_Cap 30mg/500mg',
#  'Dronedarone HCl_Tab 400mg',
#  'Co-Careldopa_Tab 25mg/100mg',
#  'Nutrison_Energy M/Fibre Liq (Vanilla)',
#  'Lisinopril_Tab 20mg',
#  'Levothyrox Sod_Tab 25mcg',
#  'Indometacin_Cap 50mg',
#  'Zovirax_Crm 5%',
#  'Movelat Relief_Gel',
#  'Meloxicam_Tab 15mg',
#  'Nitromin_P/Spy 400mcg (200 D)',
#  'Thiamine HCl_Tab 100mg',
#  'Zeroneum Bath Add',
#  'kliniderm superabsorbent 10cm x 15cm Pfa',
#  'Tizanidine HCl_Tab 4mg',
#  'Ins Humalog_KwikPen 200u/ml 3ml Pf Pen',
#  'Kliniderm fiber cmc 10cm x 10cm Wound Dr',
#  'Methotrexate_Inj 22.5mg/0.45ml PF Dev',
#  'Dextrogel_Gel 40%',
#  'Canesten_Oral&Crm Duo(1 Cap 150mg/Crm2%)',
#  'Eczmol_Crm 1%',
#  'Sumatriptan_Aq Nsl Spy 10mg/0.1ml Ud',
#  'Targinact_Tab 10mg/5mg M/R',
#  'Starch Maize Modified_Pdr Sach 12g G/F',
#  'Rewisca_Cap 100mg',
#  'Clonazepam_Tab 500mcg',
#  'Codeine Phos_Tab 60mg',
#  'Durogesic DTrans_T/Derm Patch 25mcg',
#  'Demeclocycline HCl_Cap 150mg',
#  'Gloves (100 Gauge) (Disp) Polyth Occlusi',
#  'Flecainide Acet_Tab 100mg',
#  'Welland_Aura Drnbl Ileo Pouch Maxi Clr C',
#  'Galantamine_Cap 8mg M/R',
#  'Unifine Pentips Needles Pen Inj Screw On',
#  'Clotrimazole_Soln 1%',
#  'Aspen_Sorbaderm No-Sting Barrier Film 1m',
#  'CliniFast 10.75cm x 3m (Yellow) Stkntte',
#  'Neoral_Cap 50mg',
#  'Evolve Hypromellose 0.3% Eye Dps 10ml P/',
#  'Aliskiren_Tab 300mg',
#  'Venaxx XL_Cap 75mg',
#  'Heparin Sod_Soln 10u/ml 5ml Amp',
#  'Qvar 100_Inha 100mcg (200 D)',
#  'Salts_Confidence Comfort + Flexifit Neon',
#  'Betmiga_Tab 50mg M/R',
#  'Tubifast 2-Way Stch 7.5cm x 5m (Blue) St',
#  'Oxycodone HCl_Oral Soln 5mg/5ml S/F',
#  'OxyNorm_Cap 5mg',
#  'Uro-Tainer NaCl 100ml Cath Maint Soln',
#  'Oxycodone HCl_Inj 10mg/ml 1ml Amp',
#  'Nicardipine HCl_Cap 30mg',
#  'Gyno-Daktarin_Crm 2% + Applic (14D)',
#  'Adcal-D3_Capl 750mg/200u',
#  'Loperamide HCl_Orodisper Tab 2mg S/F',
#  'CliniMed_LBF Ster No Sting Barrier Film',
#  'Zoladex_Implant 3.6mg SafeSystem Pfs',
#  'Calc Carb_Tab Chble 2.5g S/F',
#  'Cefalexin_Oral Susp 125mg/5ml',
#  'Cardura XL_Tab 4mg',
#  'Rasagiline Mesil_Tab 1mg',
#  'Co-Trimoxazole_Tab 80mg/400mg',
#  'Sod Clodronate_Tab 800mg',
#  'Mometasone Fur_Oint 0.1%',
#  'Mylife Penfine Classic Pen Inj Screw On',
#  'Piriton_Syr 2mg/5ml',
#  'Coloplast_SenSura Mio Orig Midi Clsd Bag',
#  'Longtec_Tab 5mg M/R',
#  'Coban Self-Adherent 10cm x 6m M/Layer Co',
#  'Venlafaxine_Tab 37.5mg M/R',
#  'Dimeticone_Lot 4%',
#  'Coloplast_Brava Mouldable Rings 48mm x 2',
#  'Sebco_Oint',
#  'Rewisca_Cap 25mg',
#  'Greenlan Lancets 0.35mm/28 Gauge',
#  'Depo-Medrone_Inj 40mg/ml 2ml Vl',
#  'Femara_Tab 2.5mg',
#  'Etonogestrel_Implant 68mg',
#  'Rectogesic_Oint 0.4%',
#  'Humapen Luxura HD 3ml 0.5u (1-30u) Hypod',
#  'Respond_OstoMart OstoFix Flng Security T',
#  'Dressit Ster Dress Pack',
#  'Chloramphen_Eye Dps 0.5% Ud',
#  'Glyceryl Trinit_Oint 0.4%',
#  'Juvela_G/F Tea Bisc',
#  'Hydrocort/Miconazole Nit_Oint 1%/2%',
#  'Lorazepam_Oral Soln 500mcg/5ml',
#  'Microdot Droplet Needles Pen Inj Screw O',
#  'Chlordiazepox HCl_Cap 5mg',
#  'Bisacodyl_Suppos 5mg',
#  'Hollister_Conform 2 Flex Wear 55mm Float',
#  'Miconazole Nit_Crm 2%',
#  'Donepezil HCl_Tab 10mg',
#  'Oestrogel_Gel 0.06% 80g (64 Applic)',
#  'Respond_OstoMart OstoMist Blackberry P/S',
#  'Hollister_Adapt Conformable Convex Barri',
#  'Mylife Pura (Reagent)_Strips',
#  'Veil_Finishing Pdr',
#  'Unilet ComforTouch Lancets 0.375mm/28 Ga',
#  'Prograf_Cap 1mg',
#  'Coloplast_SenSura Soft Seal Bag Maxi Tra',
#  'Silver Sulfadiazine_Crm 1%',
#  'Movicol_Liq S/F',
#  'Methadone HCl_Mix 1mg/1ml S/F',
#  'Cathejell Lidocaine C Lubricant Gel 12.5',
#  'Creon 10000_Cap E/C',
#  'Fybogel_H/Fbre Gran Eff Sach3.5g OrngS/F',
#  'Levofloxacin_Tab 250mg',
#  'Bisacodyl_Suppos 10mg',
#  'Juvela_G/F W/F Cornflakes',
#  'Fluanxol_Tab 500mcg',
#  'Midazolam HCl_Inj 5mg/ml 2ml Amp',
#  'Hydrocort_Crm 1%',
#  'Tiotropium/Olodaterol_Inha2.5/2.5mcg 60D',
#  'Lamotrigine_Tab Disper 100mg S/F',
#  'Half Securon SR_Tab 120mg',
#  'Elleste Solo MX 40_Patch 40mcg/24hrs',
#  'Allevyn Ag Gentle 10cm x 10cm Wound Dres',
#  'Coloplast_SenSura Mio Click B/Plt L/Conv',
#  'Gz Swabs 7.5cm x 7.5cm Ster',
#  'Flexi-Ban 10cm x 3.5m Sub-Compress Waddi',
#  'Jobst Elvarex Soft Acc For L/Extrem Clos',
#  'Sudocrem_Antis Healing Crm',
#  'Theophylline_Tab 300mg M/R',
#  'Dansac_Nova 2 Urost Pouch Clr Flng 43mm',
#  'Coloplast_Simpla Profile Night Bag + 120',
#  'Exenatide_Inj 10mcg/0.04ml 2.4mlPfs(60D)',
#  'Convatec_Combihesive Natura Flx Flng 45m',
#  'Buscopan Cramps_Tab 10mg',
#  'Stilnoct_Tab 10mg',
#  'Ursodeoxycholic Acid_Susp 250mg/5ml S/F',
#  'Paliperidone_Inj 100mg/1ml Pfs',
#  'Jade_Ultra Flex Self-Adh Sheath Clr Inte',
#  'Risperidone_Tab 500mcg',
#  'GlucoRx Safety Lancets 1.6mm/30 Gauge',
#  'Estring_Vag Delivery System 7.5mcg/24hr',
#  'Alogliptin_Tab 12.5mg',
#  'Strepsils_Loz Sbery S/F',
#  'Lido HCl/Adren (Base)_Inj 1% 20ml Vl',
#  'Dansac_Soft Paste',
#  'Evorel 100_Patch',
#  'Fencino_Transdermal Patch 100mcg/hr',
#  'Vortioxetine_Tab 20mg',
#  'BD Viva Needles Pen Inj Screw On 4mm/32',
#  'Pentasa_Suppos 1g',
#  'Sitagliptin_Tab 50mg',
#  'Methotrexate_Tab 10mg',
#  'Erythromycin_Ethylsuc Susp 250mg/5ml',
#  'Estradiol_Val Tab 1mg',
#  'Mesalazine_Gran Sach 1g M/R S/F',
#  'Amitriptyline HCl_Tab 50mg',
#  'Sukkarto SR_Tab 500mg',
#  'Emerade_Auto Inj 1/1000 1mg/ml 0.3ml',
#  'Iodoflex Paste 5g Wound Dress H/Gel Ster',
#  'Tranylcypromine Sulf_Tab 10mg',
#  'Otrivine_Adult Nsl P/Spy 0.1% 10ml',
#  'Clomipramine HCl_Tab 75mg M/R',
#  'Rochester_Clr Advantage Slc Sheath Lge 3',
#  'Fultium-D3_Oral Dps 2 740u/ml',
#  'Zonegran_Cap 50mg',
#  'Covidien Dover All Slc Foy Male 5-10ml 1',
#  'Oxcarbazepine_Oral Susp 300mg/5ml S/F',
#  'Limb LimbO Adult 1/2 Leg Lge Build/Short',
#  'Juvela_G/F Fibre Bread Roll',
#  'Hypromellose/Dextran 70_Eye Dps 0.3/0.1%',
#  'Aymes Complete Starter Pack_Liq',
#  'Zomorph_Cap 100mg',
#  'CliniSupplies_ProSys Night Bag Non-Ster',
#  'Morph Sulf_Oral Soln 10mg/5ml',
#  'UrgoKTwo Size 18-25cm (10cm) M/Layer Com',
#  'Clotrimazole_Crm 10%',
#  'Coloplast_Assura Seal Ex B/Plt 50mm Flng',
#  'QV Gentle Wsh',
#  'Epanutin_Susp 30mg/5ml',
#  'Abidec_Dps',
#  'Mirapexin_Tab 1.05mg M/R',
#  'Opus_Lift Plus 360 Citrus Medical Adh Re',
#  'Enalapril Mal_Tab 10mg',
#  'Phenytoin_Sod Cap 100mg',
#  'Mediven For Men Class 2 B/Knee Closed To',
#  'Ins Hum Insulat_Penfill 100u/ml 3ml',
#  'K-Lite Long 10cm x 5.25m M/Layer Compres',
#  'Chloral Hydrate_Oral Soln 500mg/5ml',
#  'Plavix_Tab 75mg',
#  'Hirudoid_Crm 0.3%',
#  'Fresubin 2kcal_Drink (6 Flav)',
#  'Ibandronic Acid_Tab 150mg',
#  'Caverject_Inj Pack (40mcg Vl + Dil)',
#  'Ramipril_Tab 2.5mg',
#  'Champix_2Wk Tt Init Pack (Tab 0.5mg/1mg)',
#  'Fostair_Inh 200mcg/6mcg (120D) CFF',
#  'Fml_Ophth Susp 0.1%',
#  'Prednisolone_Tab 2.5mg',
#  'Ketoconazole_Crm 2%',
#  'Bumetanide_Tab 5mg',
#  'Pro D3 Forte_Oral Soln 3 000u/ml',
#  'Alissa Carmellose 0.5% Eye Dps 0.4ml Ud',
#  'Barkat_G/F W/F Coffee Bisc',
#  'Morph Sulf_Tab 100mg M/R',
#  'Theophylline_Tab 200mg M/R',
#  'Hollister_Compact Closed Pouch Transpt C',
#  'Tildiem Ret 90_Tab 90mg',
#  'Azithromycin_Oral Susp 200mg/5ml',
#  'KerraLite Cool Non-Adh 6cm x 6cm Wound D',
#  'Lumecare Singles Hypromellose Eye Dps 0.',
#  'Microgynon 30 ED_Tab',
#  'Felodipine_Tab 2.5mg M/R',
#  'Ethinylest/Norgestimate_Tab 35mcg/250mcg',
#  'Aquacel Foam Adhesive 10cm x 20cm Wound',
#  'Diltiazem HCl_Cap 200mg M/R',
#  'Loestrin 30_Tab',
#  'Kentera_Transdermal Patch 3.9mg/24hrs',
#  'Co-Proxamol_Tab 32.5mg/325mg',
#  'Benzoyl Per_Gel 5%',
#  'Oxybutynin HCl_Liq Spec 2.5mg/5ml',
#  'Amoxicillin_Cap 250mg',
#  'Kapake_Cap 30mg/500mg',
#  'NovoFine Needles Pen Inj Screw On 8mm',
#  'OxyContin_Tab 40mg M/R',
#  'K-Soft 10cm x 3.5m M/Layer Compress Band',
#  'Carbimazole_Tab 5mg',
#  'ActivHeal Hydrocolloid 10cm x 10cm Wound',
#  'Carbocisteine_Soln750mg/10mlSach10ml S/F',
#  'Voltarol Emulgel_Aq Gel 1.16%',
#  'Erythromycin_Cap E/C 250mg',
#  'Bullen Hi-Slip Plus Hydro Nelaton Male 8',
#  'Enoxaparin_Inj 150mg/ml 0.8ml Pfs',
#  'Fortisip_Yogurt Style Liq (3 Flav)',
#  'Epilim_Syr 200mg/5ml',
#  'Neutrogena_T/Gel 2 in 1 Shampoo & Cond',
#  'Coloplast_SenSura Soft Seal Midi Split S',
#  'Ins Humalog_100u/ml 10ml Vl',
#  'Aminophylline Hydrate_Tab 225mg M/R',
#  'Medroxyprogest Acet_Tab 5mg',
#  'Normacol Plus_Gran',
#  'Chloroquine Phos_Tab 250mg',
#  'Dioralyte_Pdr Sach (Citrus)',
#  'Lacosamide_Tab 100mg',
#  'Quetiapine_Tab 150mg M/R',
#  'OptiLube Ster Lubri Jelly Sach 5g',
#  'Mst Continus_Tab 100mg',
#  'Gaviscon Advance_Liq (Aniseed) (Reckitt)',
#  'Zestril_Tab 20mg',
#  'Fultium-D3_Cap 800u',
#  'Peak_Combimate SuperFlex 2-Piece Flng 57',
#  'Tubilux Sod Chlor Nsl Dps 0.9%',
#  'Tadalafil_Tab 2.5mg',
#  'N-A Ultra 9.5cm x 9.5cm Type 1 Ktd Visco',
#  'GlucoMen Sensor (Reagent)_Strips',
#  'Fluoxetine HCl_Cap 20mg',
#  'Coloplast_Assura Maxi Clr Bag C/Fit 10-5',
#  'Omeprazole_Tab Disper 10mg (E/C Pellets)',
#  'Advazorb 7.5cm x 7.5cm Wound Dress Polyu',
#  'Glutafin Select_G/F Fibre Loaf Brown(Cut',
#  'Morphgesic SR_Tab 10mg',
#  'ProSys_Independence No Sting Adh Remover',
#  'Cetraben_Bath Oil',
#  'Samaritan_Olive Oil',
#  'Nutramigen 1 + LGG_Pdr',
#  'Sterculia_Gran 62% Sach 7g G/F',
#  'Roaccutane_Cap 10mg',
#  'Respond_HiLINE Stch Unisex Ostomy Belt 1',
#  'Rozex_Gel 0.75%',
#  'Urgotul 10cm x 10cm Wound Dress Soft Pol',
#  'Trachi-Dress Sml 60mm x 82mm TRDRE0001 T',
#  'Hydrocort But_Oint 0.1%',
#  'Betnovate RD_Oint 0.025%',
#  'Mag Sulf_Paste',
#  'Multi-thick_Pdr',
#  'Dansac_NovaLife 1 Convex Open + View Mid',
#  'Betameth Val_Crm 0.025% (1 in 4)',
#  'Mirena_Intra-Uterine System',
#  'Forceval_Cap',
#  'Utrogestan_Cap 100mg',
#  'Ispag Husk_Gran Eff Sach 3.5g Orange S/F',
#  'B.Braun Actreen Fle Glys Set Nelaton 6-1',
#  'Class 1 Stnd C/Kt B/Knee Stkn Elas Hose',
#  'Morph Sulf_Tab 10mg M/R',
#  'Estradiol_Gel 0.06% 80g (64 Applic)',
#  'Liq Paraf_Liq',
#  'Unomedical_Careline+ Leg Bag + Lever Tap',
#  'Tegretol Prolonged Release_Tab 400mg M/R',
#  'Hollister_Moderma Flex Soft Convex Drnbl',
#  'Nebilet_Tab 5mg',
#  'Cyprote Acet_Tab 50mg',
#  'Fostair NEXThaler_Inh 200mcg/6mcg (120D)',
#  'Feanolla_Tab 75mcg',
#  'Viridal Duo_S/Pack Inj 40mcg Cart',
#  'Durafiber 10cm x 10cm Wound Dress Protea',
#  'GlucoRx Q (Reagent)_Strips',
#  'Ursodeoxycholic Acid_Tab 150mg',
#  'Bimatoprost/Timolol_EyeDps300mcg/5mg 0.4',
#  'Unspecified Stkntte 7.5cm x 0.5m Elasctd',
#  'LoFric Origo+Water Nelaton Male 40cm Siz',
#  'Tamiflu_Cap 75mg',
#  'Isotard 60 XL_Tab 60mg',
#  'Morph Sulf_Tab 20mg',
#  'Vensir XL_Cap 75mg',
#  'Gabapentin_Oral Soln 50mg/ml S/F',
#  'Lyrica_Cap 150mg',
#  'Dansac_GX-tra Seals Washers 20mm (50mm O',
#  'Bramox_Tab 5mg',
#  'Erythromycin Stearate_Tab 500mg',
#  'Isosorbide Mononit_Cap 40mg M/R',
#  'Plenachol_Cap 20 000u',
#  'Testosterone_Gel 50mg/5g Ud Tube',
#  'Rizatriptan_Orodisper Tab 10mg S/F',
#  'PaediaSure Plus_Liq (3 Flav)',
#  'Normacol_Gran 62% Sach 7g',
#  'Ethinylest/Levonorgest_Tab 30/150mcg',
#  'Loratadine_Oral Soln 5mg/5ml',
#  'Ketorolac Trometamol_Eye Dps 0.5%',
#  'Kendall Kerlix AMD Gauze 11.4cm x 3.7m T',
#  'Sertraline HCl_Tab 50mg',
#  'Doxepin_Cap 50mg',
#  'Chlorphenamine Mal_Oral Soln 2mg/5ml',
#  'Timoptol-LA_Ophth Gel-Forming Soln 0.25%',
#  'GlucoRx Lancets 0.31mm/30 Gauge',
#  'Oxycodone HCl_Tab 30mg M/R',
#  'QV Crm',
#  'Isotard 25 XL_Tab 25mg',
#  'Tinzaparin Sod_Inj 20 000u/ml 0.5ml Pfs',
#  'InVita D3_Oral Soln 25 000u/1ml',
#  'Comfifast 10.75cm x 3m (Yellow)Stkntte E',
#  'Fresubin 2kcal Creme_Dessert (Cappucino)',
#  'Salts_SecuPlast Aloe Rings 25mm',
#  'Oxycodone HCl/NaloxoneHCl_Tab 20/10mgM/R',
#  'Saizen_Inj 6mg/1.03ml Cart',
#  'Swabs 10cm x 10cm Fabric Filmated Non-Wo',
#  'Ichthopaste (6/2%) 7.5cm x 6m Zn Paste &',
#  'Lido HCl_Inj 1% 10ml Amp',
#  'Allevyn Gentle Border 7.5cm x 7.5cm Woun',
#  'Daktarin Aktiv_Pdr Spy 0.16% 100g',
#  'Ensure Shake_Oral Pdr Sach 57g (Choc)',
#  'Coloplast_Brava Lubricating Deod 240ml',
#  'Infatrini Peptisorb_Liq',
#  'Aviva (Reagent)_Strips',
#  'Capasal_Therapeutic Shampoo',
#  'Fenofibrate_Cap 67mg (Micronised)',
#  'Propranolol HCl_Cap 160mg M/R',
#  'Salbutamol_Inh Soln 5mg/2.5ml Ud',
#  'Actilite 5cm x 5cm Manuka Honey Ster Gz',
#  'Tadalafil_Tab 10mg',
#  'Nasobec Aq_Nsl Spy 50mcg (200 D) 30ml',
#  'Methadone HCl_Mix 1mg/1ml',
#  'Urgotul Silver 10cm x 12cm Wound Dress S',
#  'Estradiol_Vag Delivery System7.5mcg/24hr',
#  'Jobst Opaque Class 1 Knee High Closed To',
#  'Peristeen Rectal Cath (10-Pack)',
#  'Prednisolone_Tab 10mg',
#  'Metoject_PEN Inj 20mg/0.4ml Pf Pen',
#  'Sumatriptan_Aq Nsl Spy 20mg/0.1ml Ud',
#  'Progesterone_Pess 400mg',
#  'Alfacalcidol_Cap 1mcg',
#  'Desmopressin Acet_Tab 200mcg',
#  'Methyldopa_Tab 500mg',
#  'Ins Tresiba_FlexTouch 200u/ml 3ml Pf Pen',
#  'Xylomet HCl_Nsl Spy 0.1% 10ml',
#  'Metoclopramide HCl_Inj 5mg/ml 2ml Amp',
#  'Coloplast SpeediCath Compact Plus Fle 10',
#  'APO-go PFS_Inf 5mg/ml 10ml Pfs',
#  'SodiClor_Oral Soln 1.46g/5ml',
#  'Lisinopril/Hydchloroth_Tab 20mg/12.5mg',
#  'Rinatec_Aq Nsl Spy 21mcg (180D) 15ml CFF',
#  'Monopost_Eye Dps 50mcg/ml 0.2mlUd P/F',
#  'Sharpsguard 5L',
#  'Amias_Tab 16mg',
#  'Escitalopram_Tab 20mg',
#  'Spiriva Respimat_Inha 2.5mcg (60D) + Dev',
#  'C-View 12cm x 12cm VP Adh Film Dress',
#  'Lodine Sr_Tab 600mg',
#  'Hy-Opti 0.1% Sod Hyaluronate Eye Dps 10m',
#  'Clinipod Sod Chlor Top Irrig 0.9% 20ml',
#  'Amitriptyline HCl_Tab 10mg',
#  'MacuShield_Cap',
#  'Levocetirizine_Oral Soln 500mcg/ml S/F',
#  'Eurax_Crm 10%',
#  'Oilatum_Crm (New Form) (Liq)',
#  'Umeclidinium/Vilanterol_Inha 65/22mcg30D',
#  'Prednisolone_Tab Solb 5mg',
#  'Dansac_Non Sting Adh Remover Sach',
#  'Augmentin-Duo 400/57_Pdr For Susp S/F',
#  'One-Alpha_Cap 500ng',
#  'Hylo-Fresh Sod Hyaluronate Eye Dps P/F 1',
#  'Goserelin Acet_Implant 10.8mg Pfs',
#  'Juvela_G/F Fresh Loaf Wte (Cut)',
#  'Chlorhex Glucon_Soln 4%',
#  'Vagifem_Vag Tab 10mcg',
#  'Tibolone_Tab 2.5mg',
#  'Nedocromil Sod_Eye Dps Aq 2%',
#  'Celluvisc_Eye Dps 0.5% 0.4ml Ud',
#  'Amoxil_Cap 500mg',
#  'Oilatum_Emollient',
#  'Zantac_Tab 300mg',
#  'Etoricoxib_Tab 30mg',
#  'C D Medical_Peel Easy Adh Remover Spy 50',
#  'Nerisone Fte_Oily Crm 0.3%',
#  'BSN_Cutimed Prote Crm 90g',
#  'Abasaglar_100u/ml 3ml Cart',
#  'Glucotabs_Tab (Tangy Orange)',
#  'Coloplast_Assura Insp Midi Closed Bag Tr',
#  'Valupak_Multivit & Mineral Tab OAD',
#  'CliniMed_Appeel No Sting Medical Adh Rem',
#  'Shortec_Cap 5mg',
#  'Tubifast 2-Way Stch 7.5cm x 1m (Blue) St',
#  'Fucibet_Crm',
#  'Combigan_Eye Dps',
#  'Ranolazine_Tab 375mg M/R',
#  'Rizatriptan_Tab 5mg',
#  'Respond_OstoMart OstoPEEL Mint No Sting',
#  'Lithium Carb_Tab 250mg',
#  'Pholcodine_Linct Strong 10mg/5ml S/F',
#  'Levonorgest_Tab 30mcg',
#  'Sod Cromoglicate_Eye Dps 2% 0.3ml Ud P/F',
#  'KerraPro 10 x 10 x 0.3cm Sheet Low Frict',
#  'Vivotif_(Oral Vac) Cap',
#  'Aspirin_Tab 300mg',
#  'Dianette_Tab 2mg/35mcg',
#  'Hydromol Sod Pidolate Crm 2.5% 50g (App)',
#  'Eumovate_Crm 0.05%',
#  'Acipimox_Cap 250mg',
#  'Dhc Continus_Tab 60mg',
#  'Amiloride HCl/Bumetanide_Tab 5mg/1mg',
#  'Calcipotriol/Betameth_Gel 0.005%/0.05%',
#  'Ins Glargine_Inj 100u/ml 3ml Pf Pen',
#  'Mesorb 10cm x 10cm Pfa Cellulose Dress',
#  'Clotrimazole_Pess 500mg',
#  'Equasym XL_Cap 20mg',
#  'Amoxicillin_Cap 500mg',
#  'Minims_Artificial Tears Ud P/F',
#  'Betameth Diprop/Clotrimazole_Crm0.064/1%',
#  'Dermatonics Once Heel Balm',
#  'Aciferol D3_Tab 20 000u',
#  'Canesten HC_Crm',
#  'Fexofenadine HCl_Tab 120mg',
#  'Valsartan_Tab 320mg',
#  'Nicorette Invisi_Patch 25mg/16hrs',
#  'Ellaone_Tab 30mg',
#  'Zolpidem Tart_Tab 5mg',
#  'Jade_Velcro Leg Strap',
#  'Viazem XL_Cap 360mg',
#  'Thicken Aid_Pdr',
#  'Anhydrol Fte_A-Pers Soln 20%',
#  'Perindopril Erbumine_Tab 8mg',
#  'Peristeen System',
#  'Oramorph_Oral Soln Conc 20mg/ml S/F',
#  'Nutramigen 2 LIPIL_Pdr',
#  'Provox TrachPhone HME 7707 Tracheo B/Aid',
#  'Nebusal Sod Chlor 7% Inh Soln 4ml',
#  'Ibuprofen_Tab 600mg',
#  'Coloplast_SenSura Click Soft Seal B/Plt',
#  'Natecal D3_Tab Chble 600mg/400u',
#  'Clobazam_Oral Susp 5mg/5ml S/F',
#  'Xemacort_Crm',
#  'Isosorbide Mononit_Tab 20mg',
#  'Bactroban_Crm 2%',
#  'Midodrine HCl_Tab 2.5mg',
#  'Levetiracetam_Tab 500mg',
#  'Clonidine HCl_Tab 100mcg',
#  'Emla_Crm 5%',
#  'Biatain Slc 12.5cm x 12.5cm Wound Dress',
#  'Oxybutynin HCl_Tab 10mg M/R',
#  'Mobile (Reagent)_Strips',
#  'Hollister_Conform 2 Flat Barrier +Adh 55',
#  'Jade_Ultra Flex Extra Self-Adh Sheath Cl',
#  'Piloc HCl_Eye Dps 4%',
#  'GlucoMen LX Sensor (Reagent)_Strips',
#  'PolyMem 7cm x 7cm Wound Dress Polyureth',
#  'Repaglinide_Tab 500mcg',
#  'Mezolar Matrix_TransdermalPatch 50mcg/hr',
#  'Sirdupla_Inh 125mcg/25mcg (120D)',
#  'Mebendazole_Oral Susp 100mg/5ml',
#  'Welland_FreeStyle Vie Convex Drnbl Pch M',
#  'Fortijuce_S/Pack Liq',
#  'Gliclazide_Tab 80mg',
#  'Omeprazole_Oral Susp 5mg/5ml',
#  'Hypromellose_Eye Dps 0.32%',
#  'Colomycin_Inj 2 000 000u Vl (Dry)',
#  'Singulair_Tab 10mg',
#  'Adoport_Cap 500mcg',
#  'Cipralex_Tab 20mg',
#  'Ondansetron HCl_Tab 8mg',
#  'Coloplast_SenSura Soft Seal Maxi Transpt',
#  'Lixisenatide_Inj 10mcg+20mcg/0.2ml 3mlPf',
#  'Verapamil HCl_Tab 40mg',
#  'Advagraf_Cap 1mg M/R',
#  'Loratadine_Tab 10mg',
#  'Ranitidine HCl_Tab 75mg',
#  'Mesorb 10cm x 15cm Pfa Cellulose Dress',
#  'Seroquel_Tab 100mg',
#  'Glutafin_G/F W/F H/Fbre Cracker',
#  'Tears Naturale_Eye Dps',
#  'Nystaform-HC_Oint',
#  'Neoclarityn_Tab 5mg',
#  'Fortini_Liq (2 Flav)',
#  'Isopto_Alkaline 1%',
#  'Vit E_Cap 75u',
#  'Etoricoxib_Tab 120mg',
#  'Monomil XL_Tab 60mg',
#  'Trifluoperazine_Oral Soln 1mg/5ml S/F',
#  'Epilim Chrono 500_Tab 500mg C/R',
#  'Carbimazole_Tab 20mg',
#  'Flixotide_Evohaler 125mcg (120 D)',
#  'Humapen Savvio Blue 3ml 1u (1-60u) Hypod',
#  'Salbutamol_Inha B/A 100mcg (200 D) CFF',
#  'Mometasone Fur_Crm 0.1%',
#  'Ethinylest/Norethist_Tab 35mcg/500mcg',
#  'Juvela_G/F Mix Wte',
#  'Silvercel Non-Adher 11cm x 11cm Wound Dr',
#  'Clindamycin Phos_Vag Crm 2% + Applic',
#  'Hollister_Conform 2 Maxi Closed Pouch +',
#  'Dosulepin HCl_Tab 75mg',
#  'Ropinirole HCl_Tab 1mg',
#  'Aclid/Formot_PdrFor Inh 396/11.8mcg(60D)',
#  'Micronor_Tab 350mcg',
#  'Aquacel Ag Extra 10cm x 10cm Wound Dress',
#  'Coloplast_Assura Insp C/exity S/Seal Max',
#  'Orlistat_Cap 60mg',
#  'Hollister_Compact Urost Pouch Transpt C/',
#  'Mepilex Border 7cm x 7.5cm Wound Dress S',
#  'ActiFormCool 10cm x 10cm Wound Dress H/G',
#  'Acti-Fast 2-Way Stch 10.75cmx5m(Yell)Stk',
#  'HBVAXPRO_Vac 10mcg/ml 1ml Pfs',
#  'Lustral_Tab 50mg',
#  'Pioglitazone HCl_Tab 15mg',
#  'Water For Inj_2ml Amp',
#  'Fortini_Smoothie Multi Fibre Liq(2 Flav)',
#  'E45_Lot',
#  'Povitulle 5cm x 5cm Povidone Iodine Fabr',
#  'Sotalol HCl_Tab 40mg',
#  'OxyNorm_Cap 20mg',
#  'Doxepin HCl_Crm 5%',
#  'Rosuvastatin Calc_Tab 20mg',
#  'Opatanol_Eye Dps 1mg/ml',
#  'Glutafin_G/F W/F Pasta Shell',
#  'Ramipril_Cap 5mg',
#  'Repinex XL_Tab 2mg',
#  'Seretide 500_Accuhaler 500mcg/50mcg(60D)',
#  'Morphgesic SR_Tab 30mg',
#  'Convatec_Combihesive Natura Closed Pouch',
#  'Ins Humulin I_KwikPen 100u/ml 3ml Pf Pen',
#  'AMI_Suportx Ostomy/Hernia Easy Peel Supp',
#  'Ranitidine HCl_Tab 300mg',
#  'Ezetimibe_Tab 10mg',
#  'Saline Steripoule_Inh Soln 0.9% 2.5ml Ud',
#  'BuTrans_Transdermal Patch 20mcg/hr',
#  'Levothyrox Sod_Oral Soln 50mcg/5ml S/F',
#  'Furosemide_Oral Soln 20mg/5ml S/F',
#  'Doxycycline Hyclate_Cap 50mg',
#  'Revaxis_Vac 0.5ml Pfs',
#  'Stericlens Sod Chlor Top Irrig A/Spy 240',
#  'Provera_Tab 100mg',
#  'Metolazone_Tab 2.5mg',
#  'Efracea_Cap 40mg M/R',
#  'Maexeni_Tab 150mcg/30mcg',
#  'Glycopyrronium Brom_Inj 0.2mg/ml 3ml Amp',
#  'Ventolin_Evohaler 100mcg (200 D)',
#  'Perampanel_Tab 10mg',
#  'Hospilite 15cm x 4.5m Cott Polyam & Elas',
#  'Arimidex_Tab 1mg',
#  'Adizem-XL_Cap 120mg',
#  'Fluclox Sod_Oral Soln 250mg/5ml',
#  'Lithium Carb_Tab 400mg M/R',
#  'Aymes Shake_S/Pack Pdr',
#  'Octasa_MR Tab E/C 400mg',
#  'Circadin_Tab 2mg M/R',
#  'Saxagliptin_Tab 2.5mg',
#  'Nebivolol_Tab 2.5mg',
#  'Dexameth_Tab Solb 2mg S/F',
#  'Pyridox HCl_Tab 50mg',
#  'Linaclotide_Cap 290mcg',
#  'Hydromorphone HCl_Cap 8mg M/R',
#  'Sod Bicarb_Cap 500mg',
#  'Cefalexin_Oral Susp 250mg/5ml',
#  'Mupirocin_Oint 2%',
#  'PF Drops 1% Carmellose Eye Dps 10ml',
#  'Miconazole_Oromucosal Gel 20mg/g S/F',
#  'Paracet_Oral Susp Paed 120mg/5ml S/F',
#  'Simvastatin_Tab 20mg',
#  'Zerobase Crm (Appl)',
#  'ActivHeal Hydrogel 8g Wound Dress H/Gel',
#  'Ethinylestr_Tab 10mcg',
#  'Fluticasone Prop_Pdr For Inh 500mcg(60D)',
#  'Galpseud Plus_Linct S/F',
#  'Clinimed_HydroFrame Mini Flange Extender',
#  'Myfortic_Tab 180mg G/R',
#  'LoFric Non PVC Nelaton Male 8-22 (30-Pac',
#  'Tocoph Acet_Susp 500mg/5ml',
#  'Haloperidol Decan_Inj 50mg/ml 1ml Amp',
#  'Augmentin_Tab 375mg',
#  'Zetuvit Plus 10cm x 10cm Super-Absorb Dr',
#  'Glucose_Gel 40%',
#  'Mag Hydrox_Mix',
#  'Bard_Uriplan Leg Bag 10cm Inlet Tube 750',
#  'Prednisolone Sod Phos_Ear/Eye Dps 0.5%',
#  'Isomol Gel 100g',
#  'Carteolol HCl_Eye Dps 1%',
#  'Glucojuice_Liq',
#  'Praxilene_Cap 100mg',
#  'Nurse It Ster Dress Pack',
#  'Zindaclin_Gel 1%',
#  'Hydrocort/Clotrimazole_Crm 1%/1%',
#  'ConvaTec_ConvaTec Silesse Sting Free Ski',
#  'Keppra_Tab 750mg',
#  'Atarax_Tab 25mg',
#  'CliniMed_Hyperseal Washers Sml (2.5mm th',
#  'Prothiaden_Tab 75mg',
#  'Angitil SR 180_Cap 180mg',
#  'Flixotide_Evohaler 250mcg (120 D)',
#  'Calc Acet_Tab 950mg',
#  'Slo-Phyllin_Cap 250mg',
#  'Hypromellose/Dextran 70_Eye Dps.3/.1% Ud',
#  'Entacapone_Tab 200mg',
#  'WyCath H2O Nelaton Soft Tip Male 40cm 10',
#  'Sunsense_Ultra Lot Spf 50+',
#  'Amorolfine HCl_Nail Lacquer Kit 5% 5ml',
#  'TriCare Needles Pen Inj Screw On 4mm/32',
#  'Opus_SkinSafe Non Sting Prote Film',
#  'Mefenamic Acid_Cap 250mg',
#  'Azithromycin_Tab 250mg',
#  'Mupirocin_Nsl Oint 2%',
#  'Levetiracetam_Oral Soln 500mg/5ml S/F',
#  'Mextra Superabsorbent 20cmx30cm Wound Dr',
#  'Femodette_Tab',
#  'Fluticasone/Salmeterol_Inh 250/50mcg 60D',
#  'Biotene Moisturising Mthwsh',
#  'Nerisone_Oily Crm 0.1%',
#  'Fluticasone Prop_Crm 0.05%',
#  'Xenical_Cap 120mg',
#  'Nefopam HCl_Tab 30mg',
#  'Alprostadil_Inj 10mcg Pfs Cart',
#  'Nutrison Pack_1200 Complete M/Fibre Liq',
#  'Betameth Val_Crm 0.1%',
#  'Elleste Duet_Tab 1mg',
#  'KerraPro 10 x 10 x 1.2cm Sheet Low Frict',
#  'Prontosan Top Irrig 40ml',
#  'Procyclidine HCl_Oral Soln 5mg/5ml S/F',
#  'Nystan_Susp (Ready Mixed)',
#  'Calci-D_Tab Chble 1g/1 000u',
#  'Advazorb Border Lite 7.5cm x 7.5cm Wound',
#  'Respond_OstoMart Cool Comfort Unisex Gmt',
#  'Advazorb 10cm x 10cm Wound Dress Polyure',
#  'Coloplast_Trident T2 Leg Bag 500ml Adjus',
#  'DuoDERM Ex Thin 7.5cm x 7.5cm Wound Dres',
#  'Elantan LA 25_Cap 25mg',
#  'Matrifen_Patch 50mcg/hr',
#  'Aspen_Sorbaderm Barrier Crm 28g',
#  'CliniMed_Hyperseal Washers+Manuka HoneyS',
#  'Alphaderm_Top Steroid Crm 1%/10%',
#  'Piroxicam_Orodisper Tab 20mg S/F',
#  'Terbinafine HCl_Crm 1%',
#  'Metoclopramide HCl_Oral Soln 5mg/5ml S/F',
#  'Barkat_G/F W/F Cornflakes',
#  'Beclomet Diprop_Inha 100mcg (200 D) CFF',
#  'GlucoMen Visio (Reagent)_Strips',
#  'Aquacel Foam Non-Adhesive 10cm x 10cm Wo',
#  'Fluocinonide_Oint 0.05%',
#  'Flotros_Tab 20mg',
#  'Salamol E-Breathe_Inh 100mcg (200 D) CFF',
#  'Coloplast_Trident T1 Leg Bag 500ml Short',
#  'Episenta_Cap 300mg M/R',
#  'Aciclovir_Tab Disper 800mg',
#  'Serc-8_Tab 8mg',
#  'Peptac_Liq (Aniseed) S/F',
#  'Indapamide_Tab 1.5mg M/R',
#  'Mebeverine HCl_Tab 135mg',
#  'Unilet Eco Lancets 0.375mm/28 Gauge',
#  'Trazodone HCl_Oral Liq 50mg/5ml S/F',
#  'Coloplast SpeediCath Compact Set Fle Siz',
#  'MicardisPlus_Tab 80mg/12.5mg',
#  ...}

# %% [markdown]
# We want to construct "groups" identified by `'bnf_name'`, where each group is a collection of prescriptions (i.e. dictionaries from `scripts`). We'll construct a dictionary called `groups`, using `bnf_names` as the keys. We'll represent a group with a `list`, since we can easily append new members to the group. To split our `scripts` into groups by `'bnf_name'`, we should iterate over `scripts`, appending prescription dictionaries to each group as we encounter them.

# %%
groups = {name: [] for name in bnf_names}

# %%
for script in scripts:
    groups[ script['bnf_name'] ].append(script)

# %%
len(groups)
# Out:
# 5619

# %%
item_totals = []
for k in groups.keys():
    item_totals.append((k, sum([ s['items'] for s in groups[k] ])))

# %%
len(item_totals)
# Out:
# 5619

# %%
item_totals
# Out:
# [('Hospiform 10cm x 4m Conform Syn Band', 10),
#  ('Warfarin Sod_Oral Susp 1mg/1ml S/F', 2),
#  ('Maxitram SR_Cap 50mg', 100),
#  ('Trimethoprim_Tab 200mg', 10979),
#  ('Fragmin_Inj 25 000u/ml 0.6ml Pfs', 6),
#  ('Co-Amilofruse_Tab 5mg/40mg', 1301),
#  ('Trental 400_Tab 400mg', 3),
#  ('CosmoCol_Oral Pdr Sach (Orng Lem & Lim)', 215),
#  ('Teleflex_Rusch Leg Bag 500ml 10cm Tubing', 2),
#  ('Dulaglutide_Inj 0.75mg/0.5ml Pf Dev', 2),
#  ('Hydrocort But_Scalp Lot 0.1%', 2),
#  ('Dalteparin Sod_Inj 25 000u/ml 0.4ml Pfs', 15),
#  ('Dalivit_Dps', 647),
#  ('Medikinet XL_Cap 20mg', 98),
#  ('Bumetanide_Tab 1mg', 6414),
#  ('Diazepam_Tab 5mg', 8224),
#  ('Dexameth_Oral Soln 2mg/5ml S/F', 21),
#  ('Aquacel Ag 5cm x 5cm Wound Dress Proteas', 69),
#  ('Sod Algin/Pot Bicarb_Susp S/F', 2636),
#  ('Clobavate_Oint 0.05%', 10),
#  ('Prempak-C_C/Pk Tab 1.25mg/150mcg', 44),
#  ('Aprovel_Tab 150mg', 6),
#  ('Ins Detemir_Inj 100u/ml 3ml Pf Pen', 33),
#  ('Gaviscon_Liq Orig Aniseed Relief', 244),
#  ('Medicareplus_Medi Derma-S Barrier Crm 90', 492),
#  ('Fosinopril Sod_Tab 10mg', 10),
#  ('Ispag Husk_Gran Sach 3.5g G/F', 17),
#  ('FemSeven 50_Patch 50mcg/24hrs', 5),
#  ('Dovobet_Gel Applic', 21),
#  ('Methylpred Acet/Lidoc_Inj 80/20mg/2ml Vl', 19),
#  ('ActiLymph Class 1 B/Knee Closed Toe Sand', 3),
#  ('Xatral_XL Tab 10mg', 39),
#  ('Activa Leg Ulcer Hose Kit Med Clsd Toe C', 13),
#  ('Cetirizine HCl_Oral Soln 1mg/1ml S/F', 2112),
#  ('CliniMed_Appeel Advance No Sting Medic A', 17),
#  ('Viazem XL_Cap 300mg', 53),
#  ('Hypromellose_Eye Dps 0.5%', 1890),
#  ('Movicol-Half_Pdr Sach 6.9g (Lem & Lim)', 108),
#  ('K-Y Lubri Jelly', 126),
#  ('Adipine XL_Tab 60mg', 45),
#  ('Carvedilol_Tab 25mg', 446),
#  ('Carbocisteine_Oral Soln 250mg/5ml', 1016),
#  ('Carvedilol_Tab 6.25mg', 496),
#  ('Tegaderm Foam Adh Oval 10cm x 11cm Wound', 240),
#  ('Forticreme Complete_Dessert (F/Fruits)', 66),
#  ('Prednisolone_Tab E/C 2.5mg', 1199),
#  ('Nicotine_Nsl Spy 500mcg (200 D) 10ml', 5),
#  ('Volumatic', 803),
#  ('Promethazine Teoclate_Tab 25mg', 33),
#  ('Pramipexole_Tab 350mcg', 62),
#  ('Thick & Easy_Food Thickener Pdr Sach 9g', 32),
#  ('Alimemazine Tart_Tab 10mg', 110),
#  ('Esomeprazole_Tab E/C 40mg', 2721),
#  ('Losec_Cap E/C 10mg', 2),
#  ('ChloraPrep_Soln Applic 3ml', 2),
#  ('Water For Inj_20ml Amp', 2),
#  ('Doublebase_Emollient Bath Add', 133),
#  ('Madopar_Tab Disper 50mg/12.5mg', 116),
#  ('Morph Sulf_Cap 30mg M/R', 285),
#  ('Aquacel Ag 15cm x 15cm Wound Dress Prote', 6),
#  ('Zipzoc_Zn Ox Impregnated Medic Stkn', 68),
#  ('Fragmin_Inj 25 000u/ml 0.5ml Pfs', 7),
#  ('Mezolar Matrix_T/Derm Patch 37.5mcg/hr', 13),
#  ('3m Health Care_Cavilon No Sting 3ml Barr', 39),
#  ('Bupeaze_Transdermal Patch 35mcg/hr(96hr)', 5),
#  ('Uro-Tainer Twin Solution R 2 x 30ml Cath', 12),
#  ('Gamolenic Acid_Cap 80mg', 2),
#  ('OneTouch Delica Lancets 0.32mm/30 Gauge', 272),
#  ('Norethist_Tab 350mcg', 157),
#  ('Lodoxamide Trometamol_Eye Dps 0.1%', 13),
#  ('Colecal & Calc_Tab Chble 880u/2.5g', 262),
#  ('Tildiem_Tab 60mg', 257),
#  ('AMI_Suportx Ostomy & A/Support Ladies Br', 2),
#  ('Hepat A_Vac 1440u/ml 1ml Pfs', 8),
#  ('Mesalazine_Foam Aero Enem 1g/D 14g', 11),
#  ('Ibuleve_Max Strgh Gel 10%', 3),
#  ('Cardioplen XL_Tab 2.5mg', 125),
#  ('Betameth Diprop_Oint 0.05%', 7),
#  ('Ins Degludec_100u/ml 3ml Cart', 9),
#  ('Ferrograd_Filmtab', 48),
#  ('Enstilar_Foam Aero 50mcg/0.5mg/g', 199),
#  ('Clarithromycin_Oral Susp 250mg/5ml', 526),
#  ('Cocois_Oint', 97),
#  ('Imodium_Original Cap 2mg', 4),
#  ('AproDerm Emollient Crm 450g', 55),
#  ('Genius_G/F Bread Wte (Cut)', 7),
#  ('Candesartan Cilexetil_Tab 4mg', 5854),
#  ('Coloplast_Sensura Mio Midi DrnblBag Grey', 20),
#  ('Evacal D3_Tab Chble 400u/1.5g', 1803),
#  ('Levonelle_Tab 1.5mg', 72),
#  ('Mediven Elegance Class 1 B/Knee Closed T', 2),
#  ('Ismo 20_Tab 20mg', 5),
#  ('Melatonin_Cap 10mg', 2),
#  ('Premarin_Tab 1.25mg', 96),
#  ('Hydrofilm 10cm x 12.5cm Vp Adh Film Dres', 10),
#  ('Hydrocort_Tab 10mg', 1499),
#  ('Clopixol_Tab 2mg', 3),
#  ('Etodolac_Tab 600mg M/R', 544),
#  ('Repinex XL_Tab 8mg', 34),
#  ('Sumatriptan_Inj 6mg/0.5ml Pfs Ref', 8),
#  ('Alprostadil_Cont Pack Inj 10mcg Cart', 2),
#  ('Alimemazine Tart_Oral Soln 30mg/5ml', 37),
#  ('Slo-Phyllin_Cap 125mg', 67),
#  ('CarePoint Needles Pen Inj Screw On 6mm', 17),
#  ('Calcipotriol_Scalp Soln 50mcg/ml', 125),
#  ('Sinemet CR_Tab 250mg', 97),
#  ('Lormetazepam_Tab 1mg', 17),
#  ('Sorbsan Ribbon (+ Probe) 40cm Wound Dres', 24),
#  ('Trio_Elisse Sting Free Skin Barrier Spy', 4),
#  ('Ponstan_Cap 250mg', 5),
#  ('Amoxil_Cap 250mg', 7),
#  ('Esomeprazole_Cap E/C 20mg', 688),
#  ('kliniderm superabsorbent 20cm x 20cm Pfa', 8),
#  ('Colecal_Tab 400u', 118),
#  ('CosmoCol_Half Oral Pdr Sach 6.9g', 28),
#  ('Simvador_Tab 10mg', 4),
#  ('Uniphyllin Continus_Tab 400mg', 242),
#  ('Gz & Cott Tiss BP 1988', 7),
#  ('Coloplast_Conveen Sheath Liner', 18),
#  ('Verapamil HCl_Tab 120mg M/R', 469),
#  ('Dansac_Nova Mini Cap Opqe C/Fit 20-50mm', 8),
#  ('Escitalopram_Tab 5mg', 585),
#  ('Timolol_Eye Dps 0.5%', 664),
#  ('Balneum Plus_Crm', 533),
#  ('Pelican_Cohesive Seals Sml 48mm', 2),
#  ('Amlodipine_Oral Soln 5mg/5ml S/F', 4),
#  ('E45_Emollient Bath Oil', 111),
#  ('Menthol & Eucalyptus_Inh BP 1980', 4),
#  ('Ovranette_Tab 150mcg/30mcg', 187),
#  ('Fresubin 2kcal Fibre_Drink (6 Flav)', 12),
#  ('L.IN.C_LINC-Flo Night Drain Bag Ster Nrv', 12),
#  ('Angitil SR 90_Cap 90mg', 122),
#  ('Glibenclamide_Tab 5mg', 4),
#  ('Influenza_Vac Inact 0.5ml Pfs', 11791),
#  ('Premarin_Tab 300mcg', 5),
#  ('Convatec_Sensi-Care Sting Free Prote Bar', 2),
#  ('Telfast 120_Tab 120mg', 4),
#  ('Salbutamol_Tab 4mg', 4),
#  ('Viscotears_Eye Gel 2mg/g 0.6ml Ud', 179),
#  ('Metformin HCl_Tab 850mg', 6491),
#  ('Bonviva_Tab 150mg F/C', 2),
#  ('Doublebase_Dayleve gel', 284),
#  ('Algivon 10cm x 10cm Wound Dress Algin St', 2),
#  ('Molaxole_Pdr Sach', 25),
#  ('Dihydrocodeine Tart_Tab 90mg M/R', 128),
#  ('Clotrimazole_Pess 100mg', 15),
#  ('Arthrotec 75_Tab', 7),
#  ('Malathion_Aq Lot 0.5%', 93),
#  ('Brinzolamide_Eye Dps 10mg/ml', 2652),
#  ('Salts_Confidence Natural Drnbl Pch Trans', 2),
#  ('E45_Emollient Shower Crm', 79),
#  ('Ipinnia XL_Tab 8mg', 9),
#  ('B.Braun Actreen Male Glys Set Nelaton 8-', 4),
#  ('Olanzapine_Orodisper Tab 20mg S/F', 6),
#  ('Colecal_Cap 20 000u', 976),
#  ('Half Beta-Prograne MR_Cap 80mg', 8),
#  ('Sumatriptan_Inj 6mg/0.5ml Pfs + Dev', 45),
#  ('Clindamycin Phos_Gel 1%', 42),
#  ('Reletrans_Transdermal Patch 10mcg/hr', 31),
#  ('Zomig_Rapimelt Orodisper Tab 5mg', 4),
#  ('Tubifast 2-Way Stch 10.75cm x 1m YellowS', 3),
#  ('Teoptic_Eye Dps 1%', 7),
#  ('Juvela_G/F W/F Flakes', 15),
#  ('Maxijul Super Solb_Pdr', 24),
#  ('Risperidone_Tab 2mg', 1273),
#  ('Promethazine HCl_Tab 10mg', 674),
#  ('Tentrini Pack_G/F M/Fibre Feed', 3),
#  ('Tetracycline_Tab 250mg', 67),
#  ('Fluticasone/Formoterol_Inh 125/5mcg 120D', 244),
#  ('Betnesol-N_Ear/Eye/Nose Dps', 34),
#  ('Coloplast_SenSura Mio Click B/Plt D/Conv', 2),
#  ('Subutex_Tab Subling 2mg', 24),
#  ('Tegaderm + Pad 9cm x 15cm VP Adh Film Dr', 2),
#  ('Epilim 500_Tab E/C 500mg', 526),
#  ('Cosopt_Ocumeter Plus Eye Dps', 256),
#  ('Zerolatum Plus_Bath Additive', 2),
#  ('Oxcarbazepine_Tab 300mg', 58),
#  ('Atomoxetine HCl_Cap 25mg', 43),
#  ('Memantine HCl_Oral Soln 10mg/ml S/F', 103),
#  ('Matrifen_Patch 25mcg/hr', 549),
#  ('Ascorbic Acid_Tab 200mg', 42),
#  ('Dansac_NovaLife 1 Open + View Midi Opqe', 11),
#  ('Alprostadil_Urethral Stick 1mg', 8),
#  ('Betaxolol_Soln Eye Dps 0.5%', 18),
#  ('Paliperidone_Inj 150mg/1.5ml Pfs', 10),
#  ('Hydromol_Bath & Shower Emollient', 767),
#  ('Serevent_Accuhaler 50mcg (60 D)', 46),
#  ('Goserelin Acet_Implant 3.6mg Pfs', 74),
#  ('Chemydur 60 XL_Tab 60mg', 1281),
#  ('Calamine_Lot', 237),
#  ('Coloplast_Sensura Mio Maxi Drnbl Bag Tra', 8),
#  ('Diamox SR_Cap 250mg', 2),
#  ('Spiroco XL_Tab 8mg', 2),
#  ('Dorzolamide_Eye Dps 2%', 927),
#  ('Movelat_Gel', 1174),
#  ('Propiverine HCl_Cap 30mg M/R', 11),
#  ('Sod Valpr_Oral Soln 200mg/5ml', 99),
#  ('Methylphenidate HCl_Tab 10mg', 370),
#  ('Estradiol/Norethist Acet_Tab 2mg/1mg', 9),
#  ('Midazolam_Liq Spec 50mg/5ml', 14),
#  ('Zetuvit E 20cm x 40cm Pfa Cellulose Dres', 81),
#  ('Ins Insuman Comb 25 SoloStar_3ml Pf Pen', 101),
#  ('N-A Dress 9.5cm x 9.5cm Type 1 Ktd Visco', 8),
#  ('Hydroxychlor Sulf_Tab 200mg', 4608),
#  ('Sytron_Elix 190mg/5ml S/F', 366),
#  ('Unomedical_Careline Leg Bag Straps', 3),
#  ('Elleste Solo_Tab 2mg', 263),
#  ('Prucalopride_Tab 1mg', 24),
#  ('Flurbiprofen_Loz 8.75mg', 15),
#  ('Allevyn Gentle Border 12.5cm x 12.5cm Wo', 102),
#  ('Hospicrepe 233 10cm x 4.5m Cott Stch Ban', 5),
#  ('Episenta_Gran Sach 500mg M/R', 4),
#  ('Diprobase_Crm', 4506),
#  ('Mesalazine_Suppos 1g', 39),
#  ('Isosorbide Dinit_Tab 20mg M/R', 26),
#  ('UrgoKTwo Size 25-32cm (10cm) M/Layer Com', 11),
#  ('Flamazine_Crm 1%', 63),
#  ('Anastrozole_Tab 1mg', 1605),
#  ('Salts_SecuPlast Mouldable Seals Stnd', 3),
#  ('Zetuvit Plus 15cm x 20cm Super-Absorb Dr', 7),
#  ('Juvela_G/F Loaf P/Bke', 2),
#  ('Cyanocobalamin_Tab 1mg M/R', 10),
#  ('Seebri_Breezhaler Inh Cap 55mcg + Dev', 953),
#  ('Combivent UDVs_Neb Soln Ud 2.5ml', 39),
#  ('Actico 10cm x 6m Short Stch Compress Ban', 39),
#  ('Lansoprazole_Orodisper Tab 30mg', 2861),
#  ('Furosemide_Tab 40mg', 32970),
#  ('Paraf_Soft Wte (S)', 11),
#  ('Felodipine_Tab 10mg M/R', 3484),
#  ('Softpore 10cm x 20cm Pfa + Adh Border Dr', 5),
#  ('Naloxegol_Tab 25mg', 6),
#  ('Buccolam_Oromuc Soln 10mg/2ml Oral Pfs', 28),
#  ('Calogen_Emuls (Sbery)', 48),
#  ('Moclobemide_Tab 300mg', 6),
#  ('Scanpor 2.5cm x 10m Surg Adh Tape Perm N', 4),
#  ('Elvanse_Cap 40mg', 9),
#  ('Omeprazole_Oral Susp 10mg/5ml', 60),
#  ('Solpadol_Cap 30mg/500mg', 33),
#  ('Simvastatin_Tab 40mg', 69612),
#  ('C-View 10cm x 12cm VP Adh Film Dress', 26),
#  ('Ethosuximide_Oral Soln 250mg/5ml', 9),
#  ('Timolol_Gel Eye Dps 1mg/g 0.4g Ud P/F', 81),
#  ('Exorex_Crm', 7),
#  ('Vistamethasone_Ear/Eye/Nose Dps 0.1%', 4),
#  ('Zomorph_Cap 10mg', 2728),
#  ('Spiriva_Pdr For Inh Cap 18mcg+HandiHaler', 312),
#  ('Melophthal 0.5% Carmellose Eye Dps 0.4ml', 7),
#  ('Venlalic XL_Tab 225mg', 230),
#  ('Omeprazole_Oral Susp 20mg/5ml', 6),
#  ('Duloxetine HCl_Cap G/R 60mg', 6137),
#  ('Isosorbide Mononit_Cap 60mg M/R', 594),
#  ('Beclomet Diprop_Nsl Spy 50mcg (200 D)', 6407),
#  ('Fluorome_Eye Dps 0.1%', 29),
#  ('Fluocinolone Aceton_Crm 0.00625%', 6),
#  ('Dosulepin HCl_Cap 25mg', 1853),
#  ('Vagisil_Medic Creme', 3),
#  ('Insight Cannula Swab Lge Tracheo Cleanin', 5),
#  ('Co-Tenidone_Tab 100mg/25mg', 150),
#  ('Latanoprost/Timolol_Eye Dps 50mcg/5mg/ml', 1092),
#  ('Lorazepam_Tab 1mg', 4046),
#  ('Vega_ZM3 Multivit/Min V/Cap', 4),
#  ('Bullen_Shelter Safe-Seal', 5),
#  ('Comfifast MultiStretch 2-way Stch 10.75c', 14),
#  ('Labetalol HCl_Tab 200mg', 128),
#  ('GluNEO (Reagent)_Strips', 32),
#  ('Fexofenadine HCl_Tab 30mg', 31),
#  ('Medroxyprogest Acet_Tab 100mg', 4),
#  ('Nabumetone_Tab 500mg', 60),
#  ('CarePoint Needles Pen Inj Screw On 8mm', 15),
#  ('Venlablue XL_Cap 37.5mg', 17),
#  ('Modafinil_Tab 200mg', 37),
#  ('Urea_Lot 10%', 11),
#  ('GelTears_Ophth Gel 0.2%', 234),
#  ('Isotrex_Gel 0.05%', 5),
#  ('Glucophage SR_Tab 750mg', 23),
#  ('Estraderm MX 100_Patch', 3),
#  ('Coloplast_Simpla Plus Leg Bag Ster 500ml', 32),
#  ('DesmoMelt_Oral Lyoph 120mcg', 38),
#  ('Subutex_Tab Subling 8mg', 16),
#  ('Madopar_Cap 100mg/25mg', 412),
#  ('Ethinylestr/Norelgest_24 Hr T/Derm Patch', 19),
#  ('Calc & Ergocalciferol_Tab 400u', 278),
#  ('Docusate Sod_Oral Soln 12.5mg/5ml S/F', 6),
#  ('TheiCal D-3_Tab Chble 1000mg/880u', 1302),
#  ('Zumenon_Tab 2mg', 7),
#  ('Incruse Ellipta_Inh 55mcg (30D)', 967),
#  ('Sigvaris Cotton Class 1 B/Knee Closed To', 8),
#  ('Acenocoumarol_Tab 1mg', 39),
#  ('Salts_Fresh Aire Odour Eliminating Deod', 57),
#  ('Fluticasone Prop_Inha 250mcg (120 D) CFF', 191),
#  ('Fresenius Sod Chlor Top Irrig 0.9% 1L', 2),
#  ('Convatec_Orahesive Pdr', 98),
#  ('Etrivex_Shampoo 500mcg/g', 28),
#  ('Ephed HCl_Nsl Dps 0.5% BP', 8),
#  ('Hylo-Forte Sod Hyaluronate Eye Dps 0.2%', 3009),
#  ('Hyoscine Butylbrom_Inj 20mg/ml 1ml Amp', 155),
#  ('Convatec_System 2 Belt', 2),
#  ('Erythromycin_Ethylsuc Susp 125mg/5ml S/F', 393),
#  ('CliniFix Tube Holder 110mm x 25mm Cath A', 6),
#  ('Diclofenac Sod_Gel 3%', 178),
#  ('Saxagliptin_Tab 5mg', 766),
#  ('Relvar Ellipta_Inha 184mcg/22mcg (30 D)', 249),
#  ('Menthol In Aq_Crm 2%', 13),
#  ('Salts_Dermacol Stoma Collar 35mm', 2),
#  ('Olmesartan Medox/Hydchloroth_Tab 20/12.5', 7),
#  ('Adizem-XL_Cap 240mg', 446),
#  ('Jevity 1.5kcal_Liq', 34),
#  ('Ropinirole HCl_Tab 3mg M/R', 2),
#  ('Terazosin HCl_Tab 5mg', 74),
#  ('Dalacin T_Top Lot 1%', 80),
#  ('Nicorette_Chewing Gum 4mg S/F(Icy Wte)', 2),
#  ('Complan_Shake Pdr Sach 57g (Banana)', 336),
#  ('Alphagan_Eye Dps 0.2%', 56),
#  ('Ethinylestr/Gestodene_Tab 20mcg/75mcg', 7),
#  ('CliniFast 7.5cm x 3m (Blue) Stkntte Elas', 2),
#  ('Clomifene Cit_Tab 50mg', 2),
#  ('Losec MUPS_Tab Disper 10mg (E/C Pellets)', 11),
#  ('Dovobet_Gel 0.005%/0.05%', 612),
#  ('Vipdomet_Tab 12.5mg/1g', 4),
#  ('Digoxin_Oral Soln Paed 50mcg/ml', 21),
#  ('Aciferol D3_Oral Soln 3 000u/ml', 9),
#  ('Rabeprazole Sod_Tab E/C 20mg', 907),
#  ('Cetaphil_Gentle Skin Cleanser', 2),
#  ('Mercilon_Tab', 132),
#  ('Mag Glycerophos_Oral Soln 121.25mg/5ml', 2),
#  ('Coloplast_Coloplast Prote Rings 20mm', 2),
#  ('Naftidrofuryl Oxal_Cap 100mg', 483),
#  ('Alfuzosin HCl_Tab 10mg M/R', 1871),
#  ('Zetuvit E (Non-Ster) 10cm x 20cm Pfa Cel', 27),
#  ('Toujeo_300u/ml 1.5ml Pf SoloStar Pen', 223),
#  ('Coloplast SpeediCath Fle Size 10-14 (30-', 57),
#  ('Zapain_Cap 30mg/500mg', 1201),
#  ('Dronedarone HCl_Tab 400mg', 58),
#  ('Co-Careldopa_Tab 25mg/100mg', 894),
#  ('Nutrison_Energy M/Fibre Liq (Vanilla)', 4),
#  ('Lisinopril_Tab 20mg', 12968),
#  ('Levothyrox Sod_Tab 25mcg', 38422),
#  ('Indometacin_Cap 50mg', 252),
#  ('Zovirax_Crm 5%', 7),
#  ('Movelat Relief_Gel', 21),
#  ('Meloxicam_Tab 15mg', 916),
#  ('Nitromin_P/Spy 400mcg (200 D)', 49),
#  ('Thiamine HCl_Tab 100mg', 11339),
#  ('Zeroneum Bath Add', 13),
#  ('kliniderm superabsorbent 10cm x 15cm Pfa', 8),
#  ('Tizanidine HCl_Tab 4mg', 53),
#  ('Ins Humalog_KwikPen 200u/ml 3ml Pf Pen', 9),
#  ('Kliniderm fiber cmc 10cm x 10cm Wound Dr', 2),
#  ('Methotrexate_Inj 22.5mg/0.45ml PF Dev', 2),
#  ('Dextrogel_Gel 40%', 21),
#  ('Canesten_Oral&Crm Duo(1 Cap 150mg/Crm2%)', 2),
#  ('Eczmol_Crm 1%', 16),
#  ('Sumatriptan_Aq Nsl Spy 10mg/0.1ml Ud', 38),
#  ('Targinact_Tab 10mg/5mg M/R', 3),
#  ('Starch Maize Modified_Pdr Sach 12g G/F', 2),
#  ('Rewisca_Cap 100mg', 94),
#  ('Clonazepam_Tab 500mcg', 3336),
#  ('Codeine Phos_Tab 60mg', 145),
#  ('Durogesic DTrans_T/Derm Patch 25mcg', 74),
#  ('Demeclocycline HCl_Cap 150mg', 5),
#  ('Gloves (100 Gauge) (Disp) Polyth Occlusi', 4),
#  ('Flecainide Acet_Tab 100mg', 464),
#  ('Welland_Aura Drnbl Ileo Pouch Maxi Clr C', 2),
#  ('Galantamine_Cap 8mg M/R', 5),
#  ('Unifine Pentips Needles Pen Inj Screw On', 338),
#  ('Clotrimazole_Soln 1%', 38),
#  ('Aspen_Sorbaderm No-Sting Barrier Film 1m', 316),
#  ('CliniFast 10.75cm x 3m (Yellow) Stkntte', 6),
#  ('Neoral_Cap 50mg', 48),
#  ('Evolve Hypromellose 0.3% Eye Dps 10ml P/', 3),
#  ('Aliskiren_Tab 300mg', 12),
#  ('Venaxx XL_Cap 75mg', 129),
#  ('Heparin Sod_Soln 10u/ml 5ml Amp', 10),
#  ('Qvar 100_Inha 100mcg (200 D)', 3006),
#  ('Salts_Confidence Comfort + Flexifit Neon', 3),
#  ('Betmiga_Tab 50mg M/R', 124),
#  ('Tubifast 2-Way Stch 7.5cm x 5m (Blue) St', 78),
#  ('Oxycodone HCl_Oral Soln 5mg/5ml S/F', 834),
#  ('OxyNorm_Cap 5mg', 35),
#  ('Uro-Tainer NaCl 100ml Cath Maint Soln', 15),
#  ('Oxycodone HCl_Inj 10mg/ml 1ml Amp', 46),
#  ('Nicardipine HCl_Cap 30mg', 2),
#  ('Gyno-Daktarin_Crm 2% + Applic (14D)', 3),
#  ('Adcal-D3_Capl 750mg/200u', 7801),
#  ('Loperamide HCl_Orodisper Tab 2mg S/F', 40),
#  ('CliniMed_LBF Ster No Sting Barrier Film', 218),
#  ('Zoladex_Implant 3.6mg SafeSystem Pfs', 87),
#  ('Calc Carb_Tab Chble 2.5g S/F', 5),
#  ('Cefalexin_Oral Susp 125mg/5ml', 281),
#  ('Cardura XL_Tab 4mg', 10),
#  ('Rasagiline Mesil_Tab 1mg', 716),
#  ('Co-Trimoxazole_Tab 80mg/400mg', 320),
#  ('Sod Clodronate_Tab 800mg', 7),
#  ('Mometasone Fur_Oint 0.1%', 1222),
#  ('Mylife Penfine Classic Pen Inj Screw On', 387),
#  ('Piriton_Syr 2mg/5ml', 213),
#  ('Coloplast_SenSura Mio Orig Midi Clsd Bag', 39),
#  ('Longtec_Tab 5mg M/R', 284),
#  ('Coban Self-Adherent 10cm x 6m M/Layer Co', 5),
#  ('Venlafaxine_Tab 37.5mg M/R', 167),
#  ('Dimeticone_Lot 4%', 55),
#  ('Coloplast_Brava Mouldable Rings 48mm x 2', 13),
#  ('Sebco_Oint', 105),
#  ('Rewisca_Cap 25mg', 46),
#  ('Greenlan Lancets 0.35mm/28 Gauge', 343),
#  ('Depo-Medrone_Inj 40mg/ml 2ml Vl', 91),
#  ('Femara_Tab 2.5mg', 4),
#  ('Etonogestrel_Implant 68mg', 77),
#  ('Rectogesic_Oint 0.4%', 31),
#  ('Humapen Luxura HD 3ml 0.5u (1-30u) Hypod', 4),
#  ('Respond_OstoMart OstoFix Flng Security T', 2),
#  ('Dressit Ster Dress Pack', 1212),
#  ('Chloramphen_Eye Dps 0.5% Ud', 6),
#  ('Glyceryl Trinit_Oint 0.4%', 120),
#  ('Juvela_G/F Tea Bisc', 2),
#  ('Hydrocort/Miconazole Nit_Oint 1%/2%', 981),
#  ('Lorazepam_Oral Soln 500mcg/5ml', 2),
#  ('Microdot Droplet Needles Pen Inj Screw O', 61),
#  ('Chlordiazepox HCl_Cap 5mg', 83),
#  ('Bisacodyl_Suppos 5mg', 12),
#  ('Hollister_Conform 2 Flex Wear 55mm Float', 2),
#  ('Miconazole Nit_Crm 2%', 1854),
#  ('Donepezil HCl_Tab 10mg', 5907),
#  ('Oestrogel_Gel 0.06% 80g (64 Applic)', 97),
#  ('Respond_OstoMart OstoMist Blackberry P/S', 14),
#  ('Hollister_Adapt Conformable Convex Barri', 2),
#  ('Mylife Pura (Reagent)_Strips', 255),
#  ('Veil_Finishing Pdr', 5),
#  ('Unilet ComforTouch Lancets 0.375mm/28 Ga', 22),
#  ('Prograf_Cap 1mg', 159),
#  ('Coloplast_SenSura Soft Seal Bag Maxi Tra', 3),
#  ('Silver Sulfadiazine_Crm 1%', 25),
#  ('Movicol_Liq S/F', 13),
#  ('Methadone HCl_Mix 1mg/1ml S/F', 492),
#  ('Cathejell Lidocaine C Lubricant Gel 12.5', 214),
#  ('Creon 10000_Cap E/C', 904),
#  ('Fybogel_H/Fbre Gran Eff Sach3.5g OrngS/F', 99),
#  ('Levofloxacin_Tab 250mg', 7),
#  ('Bisacodyl_Suppos 10mg', 79),
#  ('Juvela_G/F W/F Cornflakes', 29),
#  ('Fluanxol_Tab 500mcg', 2),
#  ('Midazolam HCl_Inj 5mg/ml 2ml Amp', 739),
#  ('Hydrocort_Crm 1%', 6507),
#  ('Tiotropium/Olodaterol_Inha2.5/2.5mcg 60D', 36),
#  ('Lamotrigine_Tab Disper 100mg S/F', 149),
#  ('Half Securon SR_Tab 120mg', 212),
#  ('Elleste Solo MX 40_Patch 40mcg/24hrs', 4),
#  ('Allevyn Ag Gentle 10cm x 10cm Wound Dres', 2),
#  ('Coloplast_SenSura Mio Click B/Plt L/Conv', 2),
#  ('Gz Swabs 7.5cm x 7.5cm Ster', 122),
#  ('Flexi-Ban 10cm x 3.5m Sub-Compress Waddi', 3),
#  ('Jobst Elvarex Soft Acc For L/Extrem Clos', 4),
#  ('Sudocrem_Antis Healing Crm', 1400),
#  ('Theophylline_Tab 300mg M/R', 9),
#  ('Dansac_Nova 2 Urost Pouch Clr Flng 43mm', 2),
#  ('Coloplast_Simpla Profile Night Bag + 120', 287),
#  ('Exenatide_Inj 10mcg/0.04ml 2.4mlPfs(60D)', 279),
#  ('Convatec_Combihesive Natura Flx Flng 45m', 8),
#  ('Buscopan Cramps_Tab 10mg', 8),
#  ('Stilnoct_Tab 10mg', 7),
#  ('Ursodeoxycholic Acid_Susp 250mg/5ml S/F', 9),
#  ('Paliperidone_Inj 100mg/1ml Pfs', 11),
#  ('Jade_Ultra Flex Self-Adh Sheath Clr Inte', 3),
#  ('Risperidone_Tab 500mcg', 2114),
#  ('GlucoRx Safety Lancets 1.6mm/30 Gauge', 12),
#  ('Estring_Vag Delivery System 7.5mcg/24hr', 5),
#  ('Alogliptin_Tab 12.5mg', 254),
#  ('Strepsils_Loz Sbery S/F', 2),
#  ('Lido HCl/Adren (Base)_Inj 1% 20ml Vl', 4),
#  ('Dansac_Soft Paste', 14),
#  ('Evorel 100_Patch', 56),
#  ('Fencino_Transdermal Patch 100mcg/hr', 93),
#  ('Vortioxetine_Tab 20mg', 15),
#  ('BD Viva Needles Pen Inj Screw On 4mm/32', 89),
#  ('Pentasa_Suppos 1g', 52),
#  ('Sitagliptin_Tab 50mg', 1430),
#  ('Methotrexate_Tab 10mg', 207),
#  ('Erythromycin_Ethylsuc Susp 250mg/5ml', 455),
#  ('Estradiol_Val Tab 1mg', 91),
#  ('Mesalazine_Gran Sach 1g M/R S/F', 7),
#  ('Amitriptyline HCl_Tab 50mg', 8437),
#  ('Sukkarto SR_Tab 500mg', 1008),
#  ('Emerade_Auto Inj 1/1000 1mg/ml 0.3ml', 8),
#  ('Iodoflex Paste 5g Wound Dress H/Gel Ster', 16),
#  ('Tranylcypromine Sulf_Tab 10mg', 9),
#  ('Otrivine_Adult Nsl P/Spy 0.1% 10ml', 5),
#  ('Clomipramine HCl_Tab 75mg M/R', 5),
#  ('Rochester_Clr Advantage Slc Sheath Lge 3', 2),
#  ('Fultium-D3_Oral Dps 2 740u/ml', 4),
#  ('Zonegran_Cap 50mg', 4),
#  ('Covidien Dover All Slc Foy Male 5-10ml 1', 2),
#  ('Oxcarbazepine_Oral Susp 300mg/5ml S/F', 2),
#  ('Limb LimbO Adult 1/2 Leg Lge Build/Short', 2),
#  ('Juvela_G/F Fibre Bread Roll', 7),
#  ('Hypromellose/Dextran 70_Eye Dps 0.3/0.1%', 138),
#  ('Aymes Complete Starter Pack_Liq', 8),
#  ('Zomorph_Cap 100mg', 131),
#  ('CliniSupplies_ProSys Night Bag Non-Ster', 707),
#  ('Morph Sulf_Oral Soln 10mg/5ml', 6536),
#  ('UrgoKTwo Size 18-25cm (10cm) M/Layer Com', 5),
#  ('Clotrimazole_Crm 10%', 25),
#  ('Coloplast_Assura Seal Ex B/Plt 50mm Flng', 2),
#  ('QV Gentle Wsh', 319),
#  ('Epanutin_Susp 30mg/5ml', 6),
#  ('Abidec_Dps', 1233),
#  ('Mirapexin_Tab 1.05mg M/R', 2),
#  ('Opus_Lift Plus 360 Citrus Medical Adh Re', 4),
#  ('Enalapril Mal_Tab 10mg', 1808),
#  ('Phenytoin_Sod Cap 100mg', 1569),
#  ('Mediven For Men Class 2 B/Knee Closed To', 4),
#  ('Ins Hum Insulat_Penfill 100u/ml 3ml', 343),
#  ('K-Lite Long 10cm x 5.25m M/Layer Compres', 64),
#  ('Chloral Hydrate_Oral Soln 500mg/5ml', 4),
#  ('Plavix_Tab 75mg', 29),
#  ('Hirudoid_Crm 0.3%', 66),
#  ('Fresubin 2kcal_Drink (6 Flav)', 177),
#  ('Ibandronic Acid_Tab 150mg', 452),
#  ('Caverject_Inj Pack (40mcg Vl + Dil)', 3),
#  ('Ramipril_Tab 2.5mg', 1205),
#  ('Champix_2Wk Tt Init Pack (Tab 0.5mg/1mg)', 34),
#  ('Fostair_Inh 200mcg/6mcg (120D) CFF', 989),
#  ('Fml_Ophth Susp 0.1%', 13),
#  ('Prednisolone_Tab 2.5mg', 210),
#  ('Ketoconazole_Crm 2%', 147),
#  ('Bumetanide_Tab 5mg', 32),
#  ('Pro D3 Forte_Oral Soln 3 000u/ml', 20),
#  ('Alissa Carmellose 0.5% Eye Dps 0.4ml Ud', 46),
#  ('Barkat_G/F W/F Coffee Bisc', 4),
#  ('Morph Sulf_Tab 100mg M/R', 2),
#  ('Theophylline_Tab 200mg M/R', 72),
#  ('Hollister_Compact Closed Pouch Transpt C', 13),
#  ('Tildiem Ret 90_Tab 90mg', 365),
#  ('Azithromycin_Oral Susp 200mg/5ml', 275),
#  ('KerraLite Cool Non-Adh 6cm x 6cm Wound D', 2),
#  ('Lumecare Singles Hypromellose Eye Dps 0.', 18),
#  ('Microgynon 30 ED_Tab', 280),
#  ('Felodipine_Tab 2.5mg M/R', 2793),
#  ('Ethinylest/Norgestimate_Tab 35mcg/250mcg', 108),
#  ('Aquacel Foam Adhesive 10cm x 20cm Wound', 2),
#  ('Diltiazem HCl_Cap 200mg M/R', 102),
#  ('Loestrin 30_Tab', 175),
#  ('Kentera_Transdermal Patch 3.9mg/24hrs', 9),
#  ('Co-Proxamol_Tab 32.5mg/325mg', 53),
#  ('Benzoyl Per_Gel 5%', 450),
#  ('Oxybutynin HCl_Liq Spec 2.5mg/5ml', 2),
#  ('Amoxicillin_Cap 250mg', 1684),
#  ('Kapake_Cap 30mg/500mg', 49),
#  ('NovoFine Needles Pen Inj Screw On 8mm', 487),
#  ('OxyContin_Tab 40mg M/R', 30),
#  ('K-Soft 10cm x 3.5m M/Layer Compress Band', 673),
#  ('Carbimazole_Tab 5mg', 1686),
#  ('ActivHeal Hydrocolloid 10cm x 10cm Wound', 2),
#  ('Carbocisteine_Soln750mg/10mlSach10ml S/F', 69),
#  ('Voltarol Emulgel_Aq Gel 1.16%', 1099),
#  ('Erythromycin_Cap E/C 250mg', 66),
#  ('Bullen Hi-Slip Plus Hydro Nelaton Male 8', 3),
#  ('Enoxaparin_Inj 150mg/ml 0.8ml Pfs', 52),
#  ('Fortisip_Yogurt Style Liq (3 Flav)', 4),
#  ('Epilim_Syr 200mg/5ml', 27),
#  ('Neutrogena_T/Gel 2 in 1 Shampoo & Cond', 10),
#  ('Coloplast_SenSura Soft Seal Midi Split S', 8),
#  ('Ins Humalog_100u/ml 10ml Vl', 86),
#  ('Aminophylline Hydrate_Tab 225mg M/R', 212),
#  ('Medroxyprogest Acet_Tab 5mg', 9),
#  ('Normacol Plus_Gran', 20),
#  ('Chloroquine Phos_Tab 250mg', 4),
#  ('Dioralyte_Pdr Sach (Citrus)', 172),
#  ('Lacosamide_Tab 100mg', 82),
#  ('Quetiapine_Tab 150mg M/R', 43),
#  ('OptiLube Ster Lubri Jelly Sach 5g', 4),
#  ('Mst Continus_Tab 100mg', 54),
#  ('Gaviscon Advance_Liq (Aniseed) (Reckitt)', 5568),
#  ('Zestril_Tab 20mg', 4),
#  ('Fultium-D3_Cap 800u', 6080),
#  ('Peak_Combimate SuperFlex 2-Piece Flng 57', 4),
#  ('Tubilux Sod Chlor Nsl Dps 0.9%', 109),
#  ('Tadalafil_Tab 2.5mg', 5),
#  ('N-A Ultra 9.5cm x 9.5cm Type 1 Ktd Visco', 27),
#  ('GlucoMen Sensor (Reagent)_Strips', 3),
#  ('Fluoxetine HCl_Cap 20mg', 27574),
#  ('Coloplast_Assura Maxi Clr Bag C/Fit 10-5', 7),
#  ('Omeprazole_Tab Disper 10mg (E/C Pellets)', 247),
#  ('Advazorb 7.5cm x 7.5cm Wound Dress Polyu', 2),
#  ('Glutafin Select_G/F Fibre Loaf Brown(Cut', 3),
#  ('Morphgesic SR_Tab 10mg', 103),
#  ('ProSys_Independence No Sting Adh Remover', 2),
#  ('Cetraben_Bath Oil', 214),
#  ('Samaritan_Olive Oil', 2),
#  ('Nutramigen 1 + LGG_Pdr', 124),
#  ('Sterculia_Gran 62% Sach 7g G/F', 3),
#  ('Roaccutane_Cap 10mg', 14),
#  ('Respond_HiLINE Stch Unisex Ostomy Belt 1', 5),
#  ('Rozex_Gel 0.75%', 60),
#  ('Urgotul 10cm x 10cm Wound Dress Soft Pol', 61),
#  ('Trachi-Dress Sml 60mm x 82mm TRDRE0001 T', 2),
#  ('Hydrocort But_Oint 0.1%', 5),
#  ('Betnovate RD_Oint 0.025%', 117),
#  ('Mag Sulf_Paste', 10),
#  ('Multi-thick_Pdr', 3),
#  ('Dansac_NovaLife 1 Convex Open + View Mid', 2),
#  ('Betameth Val_Crm 0.025% (1 in 4)', 769),
#  ('Mirena_Intra-Uterine System', 205),
#  ('Forceval_Cap', 1079),
#  ('Utrogestan_Cap 100mg', 16),
#  ('Ispag Husk_Gran Eff Sach 3.5g Orange S/F', 100),
#  ('B.Braun Actreen Fle Glys Set Nelaton 6-1', 2),
#  ('Class 1 Stnd C/Kt B/Knee Stkn Elas Hose', 495),
#  ('Morph Sulf_Tab 10mg M/R', 822),
#  ('Estradiol_Gel 0.06% 80g (64 Applic)', 38),
#  ('Liq Paraf_Liq', 2),
#  ('Unomedical_Careline+ Leg Bag + Lever Tap', 11),
#  ('Tegretol Prolonged Release_Tab 400mg M/R', 1354),
#  ('Hollister_Moderma Flex Soft Convex Drnbl', 10),
#  ('Nebilet_Tab 5mg', 2),
#  ('Cyprote Acet_Tab 50mg', 71),
#  ('Fostair NEXThaler_Inh 200mcg/6mcg (120D)', 216),
#  ('Feanolla_Tab 75mcg', 13),
#  ('Viridal Duo_S/Pack Inj 40mcg Cart', 2),
#  ('Durafiber 10cm x 10cm Wound Dress Protea', 69),
#  ('GlucoRx Q (Reagent)_Strips', 4),
#  ('Ursodeoxycholic Acid_Tab 150mg', 64),
#  ('Bimatoprost/Timolol_EyeDps300mcg/5mg 0.4', 93),
#  ('Unspecified Stkntte 7.5cm x 0.5m Elasctd', 2),
#  ('LoFric Origo+Water Nelaton Male 40cm Siz', 43),
#  ('Tamiflu_Cap 75mg', 31),
#  ('Isotard 60 XL_Tab 60mg', 361),
#  ('Morph Sulf_Tab 20mg', 21),
#  ('Vensir XL_Cap 75mg', 990),
#  ('Gabapentin_Oral Soln 50mg/ml S/F', 26),
#  ('Lyrica_Cap 150mg', 1326),
#  ('Dansac_GX-tra Seals Washers 20mm (50mm O', 3),
#  ('Bramox_Tab 5mg', 4),
#  ('Erythromycin Stearate_Tab 500mg', 21),
#  ('Isosorbide Mononit_Cap 40mg M/R', 302),
#  ('Plenachol_Cap 20 000u', 123),
#  ('Testosterone_Gel 50mg/5g Ud Tube', 5),
#  ('Rizatriptan_Orodisper Tab 10mg S/F', 242),
#  ('PaediaSure Plus_Liq (3 Flav)', 82),
#  ('Normacol_Gran 62% Sach 7g', 2),
#  ('Ethinylest/Levonorgest_Tab 30/150mcg', 655),
#  ('Loratadine_Oral Soln 5mg/5ml', 474),
#  ('Ketorolac Trometamol_Eye Dps 0.5%', 38),
#  ('Kendall Kerlix AMD Gauze 11.4cm x 3.7m T', 2),
#  ('Sertraline HCl_Tab 50mg', 28550),
#  ('Doxepin_Cap 50mg', 14),
#  ('Chlorphenamine Mal_Oral Soln 2mg/5ml', 1980),
#  ('Timoptol-LA_Ophth Gel-Forming Soln 0.25%', 100),
#  ('GlucoRx Lancets 0.31mm/30 Gauge', 1257),
#  ('Oxycodone HCl_Tab 30mg M/R', 27),
#  ('QV Crm', 316),
#  ('Isotard 25 XL_Tab 25mg', 95),
#  ('Tinzaparin Sod_Inj 20 000u/ml 0.5ml Pfs', 18),
#  ('InVita D3_Oral Soln 25 000u/1ml', 766),
#  ('Comfifast 10.75cm x 3m (Yellow)Stkntte E', 14),
#  ('Fresubin 2kcal Creme_Dessert (Cappucino)', 22),
#  ('Salts_SecuPlast Aloe Rings 25mm', 19),
#  ('Oxycodone HCl/NaloxoneHCl_Tab 20/10mgM/R', 12),
#  ('Saizen_Inj 6mg/1.03ml Cart', 2),
#  ('Swabs 10cm x 10cm Fabric Filmated Non-Wo', 34),
#  ('Ichthopaste (6/2%) 7.5cm x 6m Zn Paste &', 21),
#  ('Lido HCl_Inj 1% 10ml Amp', 7),
#  ('Allevyn Gentle Border 7.5cm x 7.5cm Woun', 205),
#  ('Daktarin Aktiv_Pdr Spy 0.16% 100g', 2),
#  ('Ensure Shake_Oral Pdr Sach 57g (Choc)', 2),
#  ('Coloplast_Brava Lubricating Deod 240ml', 25),
#  ('Infatrini Peptisorb_Liq', 8),
#  ('Aviva (Reagent)_Strips', 3203),
#  ('Capasal_Therapeutic Shampoo', 1655),
#  ('Fenofibrate_Cap 67mg (Micronised)', 89),
#  ('Propranolol HCl_Cap 160mg M/R', 1255),
#  ('Salbutamol_Inh Soln 5mg/2.5ml Ud', 910),
#  ('Actilite 5cm x 5cm Manuka Honey Ster Gz', 16),
#  ('Tadalafil_Tab 10mg', 551),
#  ('Nasobec Aq_Nsl Spy 50mcg (200 D) 30ml', 5),
#  ('Methadone HCl_Mix 1mg/1ml', 541),
#  ('Urgotul Silver 10cm x 12cm Wound Dress S', 2),
#  ('Estradiol_Vag Delivery System7.5mcg/24hr', 2),
#  ('Jobst Opaque Class 1 Knee High Closed To', 8),
#  ('Peristeen Rectal Cath (10-Pack)', 6),
#  ('Prednisolone_Tab 10mg', 8),
#  ('Metoject_PEN Inj 20mg/0.4ml Pf Pen', 40),
#  ('Sumatriptan_Aq Nsl Spy 20mg/0.1ml Ud', 99),
#  ('Progesterone_Pess 400mg', 2),
#  ('Alfacalcidol_Cap 1mcg', 547),
#  ('Desmopressin Acet_Tab 200mcg', 382),
#  ('Methyldopa_Tab 500mg', 23),
#  ('Ins Tresiba_FlexTouch 200u/ml 3ml Pf Pen', 36),
#  ('Xylomet HCl_Nsl Spy 0.1% 10ml', 217),
#  ('Metoclopramide HCl_Inj 5mg/ml 2ml Amp', 26),
#  ('Coloplast SpeediCath Compact Plus Fle 10', 76),
#  ('APO-go PFS_Inf 5mg/ml 10ml Pfs', 2),
#  ('SodiClor_Oral Soln 1.46g/5ml', 2),
#  ('Lisinopril/Hydchloroth_Tab 20mg/12.5mg', 328),
#  ('Rinatec_Aq Nsl Spy 21mcg (180D) 15ml CFF', 45),
#  ('Monopost_Eye Dps 50mcg/ml 0.2mlUd P/F', 369),
#  ('Sharpsguard 5L', 2),
#  ('Amias_Tab 16mg', 5),
#  ('Escitalopram_Tab 20mg', 1518),
#  ('Spiriva Respimat_Inha 2.5mcg (60D) + Dev', 952),
#  ('C-View 12cm x 12cm VP Adh Film Dress', 6),
#  ('Lodine Sr_Tab 600mg', 27),
#  ('Hy-Opti 0.1% Sod Hyaluronate Eye Dps 10m', 3),
#  ('Clinipod Sod Chlor Top Irrig 0.9% 20ml', 2),
#  ('Amitriptyline HCl_Tab 10mg', 34454),
#  ('MacuShield_Cap', 11),
#  ('Levocetirizine_Oral Soln 500mcg/ml S/F', 4),
#  ('Eurax_Crm 10%', 102),
#  ('Oilatum_Crm (New Form) (Liq)', 1255),
#  ('Umeclidinium/Vilanterol_Inha 65/22mcg30D', 113),
#  ('Prednisolone_Tab Solb 5mg', 1458),
#  ('Dansac_Non Sting Adh Remover Sach', 7),
#  ('Augmentin-Duo 400/57_Pdr For Susp S/F', 5),
#  ('One-Alpha_Cap 500ng', 24),
#  ('Hylo-Fresh Sod Hyaluronate Eye Dps P/F 1', 23),
#  ('Goserelin Acet_Implant 10.8mg Pfs', 182),
#  ('Juvela_G/F Fresh Loaf Wte (Cut)', 219),
#  ('Chlorhex Glucon_Soln 4%', 230),
#  ('Vagifem_Vag Tab 10mcg', 996),
#  ('Tibolone_Tab 2.5mg', 596),
#  ('Nedocromil Sod_Eye Dps Aq 2%', 350),
#  ('Celluvisc_Eye Dps 0.5% 0.4ml Ud', 664),
#  ('Amoxil_Cap 500mg', 38),
#  ('Oilatum_Emollient', 845),
#  ('Zantac_Tab 300mg', 9),
#  ('Etoricoxib_Tab 30mg', 92),
#  ('C D Medical_Peel Easy Adh Remover Spy 50', 296),
#  ('Nerisone Fte_Oily Crm 0.3%', 6),
#  ('BSN_Cutimed Prote Crm 90g', 160),
#  ('Abasaglar_100u/ml 3ml Cart', 5),
#  ('Glucotabs_Tab (Tangy Orange)', 5),
#  ('Coloplast_Assura Insp Midi Closed Bag Tr', 2),
#  ('Valupak_Multivit & Mineral Tab OAD', 23),
#  ('CliniMed_Appeel No Sting Medical Adh Rem', 387),
#  ('Shortec_Cap 5mg', 402),
#  ('Tubifast 2-Way Stch 7.5cm x 1m (Blue) St', 3),
#  ('Fucibet_Crm', 944),
#  ('Combigan_Eye Dps', 57),
#  ('Ranolazine_Tab 375mg M/R', 728),
#  ('Rizatriptan_Tab 5mg', 6),
#  ('Respond_OstoMart OstoPEEL Mint No Sting', 13),
#  ('Lithium Carb_Tab 250mg', 13),
#  ('Pholcodine_Linct Strong 10mg/5ml S/F', 545),
#  ('Levonorgest_Tab 30mcg', 8),
#  ('Sod Cromoglicate_Eye Dps 2% 0.3ml Ud P/F', 7),
#  ('KerraPro 10 x 10 x 0.3cm Sheet Low Frict', 15),
#  ('Vivotif_(Oral Vac) Cap', 66),
#  ('Aspirin_Tab 300mg', 53),
#  ('Dianette_Tab 2mg/35mcg', 72),
#  ('Hydromol Sod Pidolate Crm 2.5% 50g (App)', 20),
#  ('Eumovate_Crm 0.05%', 704),
#  ('Acipimox_Cap 250mg', 3),
#  ('Dhc Continus_Tab 60mg', 9),
#  ('Amiloride HCl/Bumetanide_Tab 5mg/1mg', 3),
#  ('Calcipotriol/Betameth_Gel 0.005%/0.05%', 650),
#  ('Ins Glargine_Inj 100u/ml 3ml Pf Pen', 277),
#  ('Mesorb 10cm x 10cm Pfa Cellulose Dress', 17),
#  ('Clotrimazole_Pess 500mg', 344),
#  ('Equasym XL_Cap 20mg', 279),
#  ('Amoxicillin_Cap 500mg', 44866),
#  ('Minims_Artificial Tears Ud P/F', 52),
#  ('Betameth Diprop/Clotrimazole_Crm0.064/1%', 157),
#  ('Dermatonics Once Heel Balm', 195),
#  ('Aciferol D3_Tab 20 000u', 15),
#  ('Canesten HC_Crm', 318),
#  ('Fexofenadine HCl_Tab 120mg', 3471),
#  ('Valsartan_Tab 320mg', 51),
#  ('Nicorette Invisi_Patch 25mg/16hrs', 68),
#  ('Ellaone_Tab 30mg', 17),
#  ('Zolpidem Tart_Tab 5mg', 1075),
#  ('Jade_Velcro Leg Strap', 5),
#  ('Viazem XL_Cap 360mg', 51),
#  ('Thicken Aid_Pdr', 15),
#  ('Anhydrol Fte_A-Pers Soln 20%', 17),
#  ('Perindopril Erbumine_Tab 8mg', 7220),
#  ('Peristeen System', 30),
#  ('Oramorph_Oral Soln Conc 20mg/ml S/F', 8),
#  ('Nutramigen 2 LIPIL_Pdr', 200),
#  ('Provox TrachPhone HME 7707 Tracheo B/Aid', 3),
#  ('Nebusal Sod Chlor 7% Inh Soln 4ml', 81),
#  ('Ibuprofen_Tab 600mg', 307),
#  ('Coloplast_SenSura Click Soft Seal B/Plt', 7),
#  ('Natecal D3_Tab Chble 600mg/400u', 46),
#  ('Clobazam_Oral Susp 5mg/5ml S/F', 35),
#  ('Xemacort_Crm', 2),
#  ('Isosorbide Mononit_Tab 20mg', 2558),
#  ('Bactroban_Crm 2%', 2),
#  ('Midodrine HCl_Tab 2.5mg', 28),
#  ('Levetiracetam_Tab 500mg', 2798),
#  ('Clonidine HCl_Tab 100mcg', 139),
#  ('Emla_Crm 5%', 837),
#  ('Biatain Slc 12.5cm x 12.5cm Wound Dress', 18),
#  ('Oxybutynin HCl_Tab 10mg M/R', 582),
#  ('Mobile (Reagent)_Strips', 1871),
#  ('Hollister_Conform 2 Flat Barrier +Adh 55', 2),
#  ('Jade_Ultra Flex Extra Self-Adh Sheath Cl', 2),
#  ('Piloc HCl_Eye Dps 4%', 6),
#  ('GlucoMen LX Sensor (Reagent)_Strips', 328),
#  ('PolyMem 7cm x 7cm Wound Dress Polyureth', 7),
#  ('Repaglinide_Tab 500mcg', 18),
#  ('Mezolar Matrix_TransdermalPatch 50mcg/hr', 50),
#  ('Sirdupla_Inh 125mcg/25mcg (120D)', 1550),
#  ('Mebendazole_Oral Susp 100mg/5ml', 334),
#  ('Welland_FreeStyle Vie Convex Drnbl Pch M', 12),
#  ('Fortijuce_S/Pack Liq', 16),
#  ('Gliclazide_Tab 80mg', 22381),
#  ('Omeprazole_Oral Susp 5mg/5ml', 6),
#  ('Hypromellose_Eye Dps 0.32%', 10),
#  ('Colomycin_Inj 2 000 000u Vl (Dry)', 9),
#  ('Singulair_Tab 10mg', 5),
#  ('Adoport_Cap 500mcg', 5),
#  ('Cipralex_Tab 20mg', 6),
#  ('Ondansetron HCl_Tab 8mg', 32),
#  ('Coloplast_SenSura Soft Seal Maxi Transpt', 8),
#  ('Lixisenatide_Inj 10mcg+20mcg/0.2ml 3mlPf', 4),
#  ('Verapamil HCl_Tab 40mg', 463),
#  ('Advagraf_Cap 1mg M/R', 9),
#  ('Loratadine_Tab 10mg', 8487),
#  ('Ranitidine HCl_Tab 75mg', 14),
#  ('Mesorb 10cm x 15cm Pfa Cellulose Dress', 4),
#  ('Seroquel_Tab 100mg', 3),
#  ('Glutafin_G/F W/F H/Fbre Cracker', 9),
#  ('Tears Naturale_Eye Dps', 594),
#  ('Nystaform-HC_Oint', 3),
#  ('Neoclarityn_Tab 5mg', 17),
#  ('Fortini_Liq (2 Flav)', 11),
#  ('Isopto_Alkaline 1%', 3),
#  ('Vit E_Cap 75u', 16),
#  ('Etoricoxib_Tab 120mg', 49),
#  ('Monomil XL_Tab 60mg', 5135),
#  ('Trifluoperazine_Oral Soln 1mg/5ml S/F', 3),
#  ('Epilim Chrono 500_Tab 500mg C/R', 1878),
#  ('Carbimazole_Tab 20mg', 374),
#  ('Flixotide_Evohaler 125mcg (120 D)', 4),
#  ('Humapen Savvio Blue 3ml 1u (1-60u) Hypod', 17),
#  ('Salbutamol_Inha B/A 100mcg (200 D) CFF', 5420),
#  ('Mometasone Fur_Crm 0.1%', 1065),
#  ('Ethinylest/Norethist_Tab 35mcg/500mcg', 17),
#  ('Juvela_G/F Mix Wte', 194),
#  ('Silvercel Non-Adher 11cm x 11cm Wound Dr', 2),
#  ('Clindamycin Phos_Vag Crm 2% + Applic', 41),
#  ('Hollister_Conform 2 Maxi Closed Pouch +', 3),
#  ('Dosulepin HCl_Tab 75mg', 1639),
#  ('Ropinirole HCl_Tab 1mg', 343),
#  ('Aclid/Formot_PdrFor Inh 396/11.8mcg(60D)', 50),
#  ('Micronor_Tab 350mcg', 641),
#  ('Aquacel Ag Extra 10cm x 10cm Wound Dress', 11),
#  ('Coloplast_Assura Insp C/exity S/Seal Max', 2),
#  ('Orlistat_Cap 60mg', 5),
#  ('Hollister_Compact Urost Pouch Transpt C/', 2),
#  ('Mepilex Border 7cm x 7.5cm Wound Dress S', 159),
#  ('ActiFormCool 10cm x 10cm Wound Dress H/G', 3),
#  ('Acti-Fast 2-Way Stch 10.75cmx5m(Yell)Stk', 65),
#  ('HBVAXPRO_Vac 10mcg/ml 1ml Pfs', 50),
#  ('Lustral_Tab 50mg', 3),
#  ('Pioglitazone HCl_Tab 15mg', 1077),
#  ('Water For Inj_2ml Amp', 11),
#  ('Fortini_Smoothie Multi Fibre Liq(2 Flav)', 4),
#  ('E45_Lot', 214),
#  ('Povitulle 5cm x 5cm Povidone Iodine Fabr', 4),
#  ('Sotalol HCl_Tab 40mg', 1061),
#  ('OxyNorm_Cap 20mg', 10),
#  ('Doxepin HCl_Crm 5%', 2),
#  ('Rosuvastatin Calc_Tab 20mg', 1499),
#  ('Opatanol_Eye Dps 1mg/ml', 101),
#  ('Glutafin_G/F W/F Pasta Shell', 6),
#  ('Ramipril_Cap 5mg', 29002),
#  ('Repinex XL_Tab 2mg', 24),
#  ('Seretide 500_Accuhaler 500mcg/50mcg(60D)', 4364),
#  ('Morphgesic SR_Tab 30mg', 122),
#  ('Convatec_Combihesive Natura Closed Pouch', 10),
#  ('Ins Humulin I_KwikPen 100u/ml 3ml Pf Pen', 1105),
#  ('AMI_Suportx Ostomy/Hernia Easy Peel Supp', 9),
#  ('Ranitidine HCl_Tab 300mg', 4158),
#  ('Ezetimibe_Tab 10mg', 6600),
#  ('Saline Steripoule_Inh Soln 0.9% 2.5ml Ud', 198),
#  ('BuTrans_Transdermal Patch 20mcg/hr', 262),
#  ('Levothyrox Sod_Oral Soln 50mcg/5ml S/F', 27),
#  ('Furosemide_Oral Soln 20mg/5ml S/F', 11),
#  ('Doxycycline Hyclate_Cap 50mg', 174),
#  ('Revaxis_Vac 0.5ml Pfs', 1764),
#  ('Stericlens Sod Chlor Top Irrig A/Spy 240', 15),
#  ('Provera_Tab 100mg', 2),
#  ('Metolazone_Tab 2.5mg', 5),
#  ('Efracea_Cap 40mg M/R', 2),
#  ('Maexeni_Tab 150mcg/30mcg', 4),
#  ('Glycopyrronium Brom_Inj 0.2mg/ml 3ml Amp', 40),
#  ('Ventolin_Evohaler 100mcg (200 D)', 25836),
#  ('Perampanel_Tab 10mg', 2),
#  ('Hospilite 15cm x 4.5m Cott Polyam & Elas', 3),
#  ('Arimidex_Tab 1mg', 8),
#  ('Adizem-XL_Cap 120mg', 496),
#  ('Fluclox Sod_Oral Soln 250mg/5ml', 400),
#  ('Lithium Carb_Tab 400mg M/R', 74),
#  ('Aymes Shake_S/Pack Pdr', 19),
#  ('Octasa_MR Tab E/C 400mg', 567),
#  ('Circadin_Tab 2mg M/R', 1112),
#  ('Saxagliptin_Tab 2.5mg', 246),
#  ('Nebivolol_Tab 2.5mg', 250),
#  ('Dexameth_Tab Solb 2mg S/F', 9),
#  ('Pyridox HCl_Tab 50mg', 310),
#  ('Linaclotide_Cap 290mcg', 110),
#  ('Hydromorphone HCl_Cap 8mg M/R', 2),
#  ('Sod Bicarb_Cap 500mg', 1944),
#  ('Cefalexin_Oral Susp 250mg/5ml', 151),
#  ('Mupirocin_Oint 2%', 70),
#  ('PF Drops 1% Carmellose Eye Dps 10ml', 39),
#  ('Miconazole_Oromucosal Gel 20mg/g S/F', 698),
#  ('Paracet_Oral Susp Paed 120mg/5ml S/F', 3159),
#  ('Simvastatin_Tab 20mg', 45652),
#  ('Zerobase Crm (Appl)', 3459),
#  ('ActivHeal Hydrogel 8g Wound Dress H/Gel', 11),
#  ('Ethinylestr_Tab 10mcg', 4),
#  ('Fluticasone Prop_Pdr For Inh 500mcg(60D)', 6),
#  ('Galpseud Plus_Linct S/F', 15),
#  ('Clinimed_HydroFrame Mini Flange Extender', 2),
#  ('Myfortic_Tab 180mg G/R', 2),
#  ('LoFric Non PVC Nelaton Male 8-22 (30-Pac', 53),
#  ('Tocoph Acet_Susp 500mg/5ml', 14),
#  ('Haloperidol Decan_Inj 50mg/ml 1ml Amp', 3),
#  ('Augmentin_Tab 375mg', 12),
#  ('Zetuvit Plus 10cm x 10cm Super-Absorb Dr', 51),
#  ('Glucose_Gel 40%', 365),
#  ('Mag Hydrox_Mix', 61),
#  ('Bard_Uriplan Leg Bag 10cm Inlet Tube 750', 2),
#  ('Prednisolone Sod Phos_Ear/Eye Dps 0.5%', 8),
#  ('Isomol Gel 100g', 18),
#  ('Carteolol HCl_Eye Dps 1%', 40),
#  ('Glucojuice_Liq', 20),
#  ('Praxilene_Cap 100mg', 8),
#  ('Nurse It Ster Dress Pack', 211),
#  ('Zindaclin_Gel 1%', 2),
#  ('Hydrocort/Clotrimazole_Crm 1%/1%', 1345),
#  ('ConvaTec_ConvaTec Silesse Sting Free Ski', 12),
#  ('Keppra_Tab 750mg', 40),
#  ('Atarax_Tab 25mg', 24),
#  ('CliniMed_Hyperseal Washers Sml (2.5mm th', 3),
#  ('Prothiaden_Tab 75mg', 6),
#  ('Angitil SR 180_Cap 180mg', 35),
#  ('Flixotide_Evohaler 250mcg (120 D)', 30),
#  ('Calc Acet_Tab 950mg', 5),
#  ('Slo-Phyllin_Cap 250mg', 232),
#  ('Hypromellose/Dextran 70_Eye Dps.3/.1% Ud', 2),
#  ('Entacapone_Tab 200mg', 69),
#  ('WyCath H2O Nelaton Soft Tip Male 40cm 10', 2),
#  ('Sunsense_Ultra Lot Spf 50+', 73),
#  ('Amorolfine HCl_Nail Lacquer Kit 5% 5ml', 700),
#  ('TriCare Needles Pen Inj Screw On 4mm/32', 49),
#  ('Opus_SkinSafe Non Sting Prote Film', 16),
#  ('Mefenamic Acid_Cap 250mg', 116),
#  ('Azithromycin_Tab 250mg', 1962),
#  ('Mupirocin_Nsl Oint 2%', 186),
#  ('Levetiracetam_Oral Soln 500mg/5ml S/F', 395),
#  ('Mextra Superabsorbent 20cmx30cm Wound Dr', 2),
#  ('Femodette_Tab', 39),
#  ('Fluticasone/Salmeterol_Inh 250/50mcg 60D', 846),
#  ('Biotene Moisturising Mthwsh', 12),
#  ('Nerisone_Oily Crm 0.1%', 3),
#  ('Fluticasone Prop_Crm 0.05%', 4),
#  ('Xenical_Cap 120mg', 4),
#  ('Nefopam HCl_Tab 30mg', 1652),
#  ('Alprostadil_Inj 10mcg Pfs Cart', 3),
#  ('Nutrison Pack_1200 Complete M/Fibre Liq', 10),
#  ('Betameth Val_Crm 0.1%', 3328),
#  ('Elleste Duet_Tab 1mg', 395),
#  ('KerraPro 10 x 10 x 1.2cm Sheet Low Frict', 6),
#  ('Prontosan Top Irrig 40ml', 7),
#  ('Procyclidine HCl_Oral Soln 5mg/5ml S/F', 6),
#  ('Nystan_Susp (Ready Mixed)', 1799),
#  ('Calci-D_Tab Chble 1g/1 000u', 24),
#  ('Advazorb Border Lite 7.5cm x 7.5cm Wound', 2),
#  ('Respond_OstoMart Cool Comfort Unisex Gmt', 7),
#  ('Advazorb 10cm x 10cm Wound Dress Polyure', 6),
#  ('Coloplast_Trident T2 Leg Bag 500ml Adjus', 11),
#  ('DuoDERM Ex Thin 7.5cm x 7.5cm Wound Dres', 27),
#  ('Elantan LA 25_Cap 25mg', 346),
#  ('Matrifen_Patch 50mcg/hr', 262),
#  ('Aspen_Sorbaderm Barrier Crm 28g', 137),
#  ('CliniMed_Hyperseal Washers+Manuka HoneyS', 2),
#  ('Alphaderm_Top Steroid Crm 1%/10%', 2),
#  ('Piroxicam_Orodisper Tab 20mg S/F', 3),
#  ('Terbinafine HCl_Crm 1%', 693),
#  ('Metoclopramide HCl_Oral Soln 5mg/5ml S/F', 58),
#  ('Barkat_G/F W/F Cornflakes', 6),
#  ('Beclomet Diprop_Inha 100mcg (200 D) CFF', 303),
#  ('GlucoMen Visio (Reagent)_Strips', 2),
#  ('Aquacel Foam Non-Adhesive 10cm x 10cm Wo', 6),
#  ('Fluocinonide_Oint 0.05%', 9),
#  ('Flotros_Tab 20mg', 20),
#  ('Salamol E-Breathe_Inh 100mcg (200 D) CFF', 2110),
#  ('Coloplast_Trident T1 Leg Bag 500ml Short', 4),
#  ('Episenta_Cap 300mg M/R', 10),
#  ('Aciclovir_Tab Disper 800mg', 33),
#  ('Serc-8_Tab 8mg', 18),
#  ('Peptac_Liq (Aniseed) S/F', 2510),
#  ('Indapamide_Tab 1.5mg M/R', 4790),
#  ('Mebeverine HCl_Tab 135mg', 6851),
#  ('Unilet Eco Lancets 0.375mm/28 Gauge', 14),
#  ('Trazodone HCl_Oral Liq 50mg/5ml S/F', 232),
#  ('Coloplast SpeediCath Compact Set Fle Siz', 15),
#  ('MicardisPlus_Tab 80mg/12.5mg', 5),
#  ...]

# %% [markdown]
# Now that we've constructed our groups we should sum up `'items'` in each group and find the `'bnf_name'` with the largest sum. The result, `max_item`, should have the form `[(bnf_name, item total)]`, e.g. `[('Foobar', 2000)]`.

# %%
max(item_totals, key=lambda x: x[1])
# Out:
# ('Omeprazole_Cap E/C 20mg', 113826)

# %%
max_item = sorted(item_totals, key=lambda x: x[1], reverse=True)[:1]

# %%
max_item
# Out:
# [('Omeprazole_Cap E/C 20mg', 113826)]

# %% [markdown]
# **TIP:** If you are getting an error from the grader below, please make sure your answer conforms to the correct format of `[(bnf_name, item total)]`.

# %%
grader.score.pw__most_common_item(max_item)
# Out:
# ==================
# Your score: 1.000
# ==================

# %% [markdown]
# **Challenge:** Write a function that constructs groups as we did above. The function should accept a list of dictionaries (e.g. `scripts` or `practices`) and a tuple of fields to `groupby` (e.g. `('bnf_name',)` or `('bnf_name', 'post_code')`) and returns a dictionary of groups. The following questions will require you to aggregate data in groups, so this could be a useful function for the rest of the miniproject.

# %%
def group_by_field(data, fields):
    #first create the keys in the new dictionary
    names = { tuple(item[field] for field in fields) for item in data }
    
    #we initialize a new dictionary with an empty list for each key
    groups = { name: [] for name in names } 
    
     #we iterate over the data to create the groups
    for item in data:
        name = tuple(item[field] for field in fields)
        groups[name].append(item)
    return groups

# %%
groups = group_by_field(scripts, ('bnf_name',))

# %%
test_max_item = [m]
assert test_max_item == max_item
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-0f162556f6b5> in <module>
# ----> 1 test_max_item = [m]
#       2 assert test_max_item == max_item
#
# NameError: name 'm' is not defined

# %% [markdown]
# ## Question 3: postal_totals
#
# Our data set is broken up among different files. This is typical for tabular data to reduce redundancy. Each table typically contains data about a particular type of event, processes, or physical object. Data on prescriptions and medical practices are in separate files in our case. If we want to find the total items prescribed in each postal code, we will have to _join_ our prescription data (`scripts`) to our clinic data (`practices`).
#
# Find the total items prescribed in each postal code, representing the results as a list of tuples `(post code, total items prescribed)`. Sort your results ascending alphabetically by post code and take only results from the first 100 post codes. Only include post codes if there is at least one prescription from a practice in that post code.
#
# **NOTE:** Some practices have multiple postal codes associated with them. Use the alphabetically first postal code.

# %% [markdown]
# We can join `scripts` and `practices` based on the fact that `'practice'` in `scripts` matches `'code'` in `practices`. However, we must first deal with the repeated values of `'code'` in `practices`. We want the alphabetically first postal codes.

# %%
practice_postal = {}
for practice in practices:
    if practice['code'] in practice_postal:
        practice_postal[practice['code']] = min(practice_postal[practice['code']], practice['post_code'])
    else:
        practice_postal[practice['code']] = practice['post_code']

# %%
practice_postal
# Out:
# {'A81001': 'TS18 1HU',
#  'A81002': 'TS18 2AW',
#  'A81003': 'TS25 1QU',
#  'A81004': 'TS1 3BE',
#  'A81005': 'TS14 7DJ',
#  'A81006': 'TS18 2AT',
#  'A81007': 'TS24 7PW',
#  'A81008': 'TS6 6TD',
#  'A81009': 'TS5 6HF',
#  'A81011': 'TS24 7PW',
#  'A81012': 'TS3 6AL',
#  'A81013': 'TS12 2FF',
#  'A81014': 'TS23 2LA',
#  'A81015': 'TS10 1TZ',
#  'A81016': 'TS1 3QY',
#  'A81017': 'TS17 0EE',
#  'A81018': 'TS10 4NW',
#  'A81019': 'TS3 7RL',
#  'A81020': 'TS4 3BU',
#  'A81021': 'TS6 6TD',
#  'A81022': 'TS12 2TG',
#  'A81023': 'TS1 2NX',
#  'A81025': 'TS18 1HU',
#  'A81026': 'TS5 6HA',
#  'A81027': 'TS15 9DD',
#  'A81029': 'TS1 2NX',
#  'A81030': 'TS1 3RY',
#  'A81031': 'TS24 7PW',
#  'A81032': 'TS14 7DJ',
#  'A81033': 'TS3 6AL',
#  'A81034': 'TS17 0EE',
#  'A81035': 'TS1 3RX',
#  'A81036': 'TS20 2UZ',
#  'A81037': 'TS1 2NX',
#  'A81038': 'TS3 6AL',
#  'A81039': 'TS16 9EA',
#  'A81040': 'TS23 2DG',
#  'A81041': 'TS24 9DN',
#  'A81042': 'TS6 9QG',
#  'A81043': 'TS6 0HA',
#  'A81044': 'TS25 1QU',
#  'A81045': 'TS10 1SR',
#  'A81046': 'TS18 1YE',
#  'A81047': 'TS11 6BW',
#  'A81048': 'TS11 7BL',
#  'A81049': 'TS3 6AL',
#  'A81051': 'TS5 5NN',
#  'A81052': 'TS10 4NW',
#  'A81053': 'TS13 4HW',
#  'A81054': 'TS10 1UA',
#  'A81056': 'TS23 2JW',
#  'A81057': 'TS23 2LS',
#  'A81058': 'TS8 0TL',
#  'A81060': 'TS26 8DB',
#  'A81063': 'TS24 0NZ',
#  'A81064': 'TS1 2NX',
#  'A81065': 'TS6 6TD',
#  'A81066': 'TS21 1JS',
#  'A81067': 'TS18 2BP',
#  'A81070': 'TS25 3DQ',
#  'A81602': 'TS23 2DG',
#  'A81605': 'TS10 3LA',
#  'A81608': 'TS17 6NP',
#  'A81609': 'TS18 2AT',
#  'A81610': 'TS23 2DG',
#  'A81611': 'TS8 0TL',
#  'A81612': 'TS25 1AX',
#  'A81613': 'TS26 8DB',
#  'A81618': 'TS12 1BJ',
#  'A81621': 'TS3 9NB',
#  'A81622': 'TS26 8DD',
#  'A81623': 'TS18 2EP',
#  'A82003': 'LA12 7BT',
#  'A82004': 'CA9 3QX',
#  'A82005': 'LA22 9BP',
#  'A82006': 'CA16 6QR',
#  'A82007': 'LA14 1LF',
#  'A82008': 'LA14 5ES',
#  'A82009': 'LA13 9SH',
#  'A82010': 'LA14 5JY',
#  'A82012': 'CA8 1NL',
#  'A82013': 'CA17 4AY',
#  'A82014': 'CA7 8DS',
#  'A82015': 'CA1 1EB',
#  'A82016': 'CA1 1DG',
#  'A82017': 'CA1 1DG',
#  'A82018': 'CA1 1BP',
#  'A82019': 'CA1 2HE',
#  'A82020': 'CA2 7AJ',
#  'A82021': 'CA13 9HT',
#  'A82022': 'CA5 7PZ',
#  'A82023': 'CA14 5UR',
#  'A82024': 'CA20 1PN',
#  'A82025': 'LA9 4JE',
#  'A82026': 'LA9 7HR',
#  'A82027': 'LA9 6SA',
#  'A82028': 'CA12 4DB',
#  'A82029': 'CA7 5JH',
#  'A82030': 'LA6 2HQ',
#  'A82031': 'CA10 3LW',
#  'A82032': 'CA15 8EL',
#  'A82033': 'LA18 4BY',
#  'A82034': 'LA7 7PW',
#  'A82035': 'CA11 8HW',
#  'A82036': 'CA11 8HW',
#  'A82037': 'CA7 4AH',
#  'A82038': 'CA10 1RW',
#  'A82039': 'LA15 8AB',
#  'A82040': 'CA28 7PD',
#  'A82041': 'CA28 7RG',
#  'A82044': 'CA22 2BD',
#  'A82045': 'CA7 9QD',
#  'A82046': 'LA23 2EG',
#  'A82047': 'CA14 2DL',
#  'A82048': 'CA14 3FT',
#  'A82049': 'CA14 2ED',
#  'A82050': 'CA14 2AJ',
#  'A82052': 'CA1 1DG',
#  'A82053': 'LA11 7DJ',
#  'A82055': 'CA7 3HH',
#  'A82057': 'CA13 9HT',
#  'A82058': 'CA28 7BA',
#  'A82060': 'CA28 7PA',
#  'A82062': 'LA14 2LR',
#  'A82063': 'CA12 5JY',
#  'A82064': 'CA22 2DB',
#  'A82065': 'LA11 7DJ',
#  'A82068': 'LA12 7BT',
#  'A82070': 'LA23 1BA',
#  'A82071': 'LA14 3HY',
#  'A82072': 'LA13 9RX',
#  'A82074': 'LA5 0DP',
#  'A82075': 'CA28 7BU',
#  'A82608': 'LA10 5DL',
#  'A82613': 'LA21 8ER',
#  'A82617': 'CA10 1DQ',
#  'A82619': 'LA15 8AF',
#  'A82620': 'CA11 0PD',
#  'A82621': 'LA16 7JP',
#  'A82623': 'CA14 2RW',
#  'A82629': 'LA14 5SL',
#  'A82631': 'CA4 0HP',
#  'A82635': 'CA1 1LB',
#  'A82641': 'CA1 1LB',
#  'A82642': 'LA22 0NU',
#  'A82646': 'CA6 5XA',
#  'A82647': 'LA11 6PH',
#  'A83001': 'DL16 6QA',
#  'A83003': 'DL15 0EQ',
#  'A83004': 'SR7 8LF',
#  'A83005': 'DL1 3RT',
#  'A83006': 'DL3 6HZ',
#  'A83007': 'TS27 4LQ',
#  'A83008': 'DL4 2HP',
#  'A83009': 'DH3 3SL',
#  'A83010': 'DL3 9JP',
#  'A83011': 'DH1 1QW',
#  'A83012': 'SR8 5TW',
#  'A83013': 'DL1 4YL',
#  'A83014': 'DH1 2QW',
#  'A83015': 'DL14 6AB',
#  'A83016': 'DH9 8AD',
#  'A83017': 'DH6 3HW',
#  'A83018': 'DH8 5YA',
#  'A83019': 'DH1 2QW',
#  'A83020': 'DL15 9HU',
#  'A83021': 'DL14 6RP',
#  'A83022': 'DH7 8NH',
#  'A83023': 'DH9 0AB',
#  'A83024': 'DH4 6RQ',
#  'A83025': 'DL14 7EJ',
#  'A83026': 'DH7 6JW',
#  'A83027': 'DH6 4DH',
#  'A83028': 'DH3 3QD',
#  'A83029': 'DH3 4LE',
#  'A83030': 'DH7 7DG',
#  'A83031': 'DL3 8SQ',
#  'A83032': 'DL13 5AF',
#  'A83033': 'DH2 1HS',
#  'A83034': 'DL3 7JR',
#  'A83035': 'DL13 2XD',
#  'A83036': 'DH1 5BH',
#  'A83037': 'DL5 5LH',
#  'A83038': 'NE16 6HU',
#  'A83040': 'DL1 5JN',
#  'A83041': 'SR7 9AB',
#  'A83042': 'TS28 5PZ',
#  'A83043': 'DL12 0QE',
#  'A83044': 'SR8 4QP',
#  'A83045': 'DL17 8JJ',
#  'A83046': 'DL12 8HT',
#  'A83047': 'DL3 0PD',
#  'A83048': 'DL2 2DS',
#  'A83049': 'DH8 0BW',
#  'A83050': 'DH2 3DJ',
#  'A83051': 'SR7 7JE',
#  'A83052': 'DL16 6ED',
#  'A83054': 'TS21 3BN',
#  'A83055': 'DH1 2UW',
#  'A83057': 'SR8 4LD',
#  'A83060': 'DL13 5NX',
#  'A83061': 'DL2 3BE',
#  'A83066': 'DL5 4SE',
#  'A83068': 'SR8 4PF',
#  'A83070': 'DL2 1AA',
#  'A83071': 'SR7 7JE',
#  'A83072': 'DH7 0LP',
#  'A83073': 'DH9 7XT',
#  'A83603': 'DL16 6BQ',
#  'A83610': 'TS28 5PZ',
#  'A83616': 'DH6 2LQ',
#  'A83617': 'DH7 9YT',
#  'A83618': 'NE17 7SB',
#  'A83619': 'DH6 2LT',
#  'A83622': 'DH7 0BD',
#  'A83626': 'DL14 9SU',
#  'A83627': 'DH6 2TH',
#  'A83630': 'DH7 8SJ',
#  'A84002': 'NE65 7UW',
#  'A84003': 'NE63 9UT',
#  'A84005': 'NE22 6JX',
#  'A84006': 'NE66 2NL',
#  'A84007': 'NE20 9SD',
#  'A84008': 'NE70 7ER',
#  'A84009': 'NE24 1DX',
#  'A84011': 'NE20 9SD',
#  'A84013': 'NE22 7DU',
#  'A84014': 'NE24 1DX',
#  'A84015': 'NE63 0XX',
#  'A84016': 'NE42 5PW',
#  'A84018': 'NE45 5LG',
#  'A84020': 'NE62 5RA',
#  'A84021': 'NE66 2NR',
#  'A84022': 'NE65 0HD',
#  'A84024': 'NE46 1QJ',
#  'A84025': 'NE23 6QN',
#  'A84026': 'TD15 1LL',
#  'A84027': 'NE48 2HE',
#  'A84028': 'NE63 0NG',
#  'A84029': 'NE61 5LX',
#  'A84030': 'NE23 6US',
#  'A84031': 'NE61 1JX',
#  'A84032': 'NE71 6BL',
#  'A84033': 'NE46 1QJ',
#  'A84034': 'NE49 9AP',
#  'A84035': 'NE41 8DH',
#  'A84036': 'NE61 1BJ',
#  'A84037': 'NE23 7EF',
#  'A84038': 'NE23 6QN',
#  'A84039': 'NE61 1JX',
#  'A84040': 'NE46 4BU',
#  'A84042': 'NE61 4EG',
#  'A84043': 'NE23 1XZ',
#  'A84044': 'TD15 2HB',
#  'A84045': 'NE47 6LA',
#  'A84047': 'NE43 7LL',
#  'A84604': 'NE71 6BL',
#  'A84609': 'NE65 9PR',
#  'A84613': 'NE65 7DG',
#  'A85001': 'NE9 5EY',
#  'A85002': 'NE8 2XB',
#  'A85003': 'NE39 1PW',
#  'A85004': 'NE10 8PH',
#  'A85005': 'NE8 1RQ',
#  'A85006': 'NE11 9AD',
#  'A85007': 'NE9 5XY',
#  'A85008': 'DH3 2QT',
#  'A85009': 'NE10 9QG',
#  'A85010': 'NE21 5AE',
#  'A85011': 'NE10 9QG',
#  'A85012': 'NE8 1HR',
#  'A85013': 'NE8 1AD',
#  'A85014': 'NE40 4US',
#  'A85016': 'NE9 7AD',
#  'A85017': 'NE8 4DP',
#  'A85018': 'NE21 4RD',
#  'A85019': 'NE8 1NB',
#  'A85020': 'NE16 4PD',
#  'A85021': 'NE8 2UR',
#  'A85023': 'NE8 2PQ',
#  'A85024': 'NE17 7BU',
#  'A85605': 'NE40 3NT',
#  'A85609': 'NE8 4QR',
#  'A85611': 'NE10 0RR',
#  'A85614': 'NE8 1AD',
#  'A86003': 'NE1 8DQ',
#  'A86004': 'NE4 8AY',
#  'A86005': 'NE12 8LS',
#  'A86006': 'NE3 1NB',
#  'A86007': 'NE2 1JQ',
#  'A86008': 'NE3 2PE',
#  'A86009': 'NE6 1SG',
#  'A86010': 'NE6 5SL',
#  'A86011': 'NE6 3BS',
#  'A86012': 'NE4 9QB',
#  'A86013': 'NE5 2QW',
#  'A86015': 'NE2 2AH',
#  'A86016': 'NE7 7XX',
#  'A86017': 'NE4 7JT',
#  'A86018': 'NE3 1NU',
#  'A86020': 'NE2 3LD',
#  'A86021': 'NE4 8QB',
#  'A86022': 'NE5 1LJ',
#  'A86023': 'NE6 4QD',
#  'A86024': 'NE6 1SA',
#  'A86025': 'NE5 2LH',
#  'A86026': 'NE15 9PA',
#  'A86027': 'NE1 7XR',
#  'A86028': 'NE3 1DQ',
#  'A86029': 'NE6 1SG',
#  'A86030': 'NE15 6TQ',
#  'A86031': 'NE4 9XD',
#  'A86033': 'NE3 5NF',
#  'A86035': 'NE3 5JP',
#  'A86036': 'NE3 1TX',
#  'A86037': 'NE4 6SH',
#  'A86038': 'NE15 8LX',
#  'A86601': 'NE5 2UY',
#  'A87002': 'NE29 0HQ',
#  'A87003': 'NE28 6RZ',
#  'A87004': 'NE29 0SF',
#  'A87005': 'NE26 2ND',
#  'A87006': 'NE26 1NA',
#  'A87007': 'NE12 9BQ',
#  'A87008': 'NE26 3LW',
#  'A87009': 'NE29 0HT',
#  'A87011': 'NE25 9XJ',
#  'A87012': 'NE13 6LN',
#  'A87013': 'NE28 0AD',
#  'A87014': 'NE27 0HJ',
#  'A87015': 'NE29 0SF',
#  'A87016': 'NE28 6BB',
#  'A87017': 'NE13 6JJ',
#  'A87019': 'NE29 0DZ',
#  'A87020': 'NE25 9PH',
#  'A87022': 'NE27 0HJ',
#  'A87023': 'NE27 0HJ',
#  'A87027': 'NE28 0PP',
#  'A87029': 'NE28 7LP',
#  'A87030': 'NE29 6HT',
#  'A87600': 'NE26 1DU',
#  'A87612': 'NE12 6HS',
#  'A88001': 'NE31 1NU',
#  'A88002': 'NE33 4QY',
#  'A88003': 'NE34 6RE',
#  'A88004': 'NE32 5SE',
#  'A88005': 'NE34 9BP',
#  'A88006': 'NE34 0BX',
#  'A88007': 'NE33 4DX',
#  'A88008': 'NE33 5DU',
#  'A88009': 'NE35 9AN',
#  'A88010': 'NE32 5AG',
#  'A88011': 'NE10 9QG',
#  'A88012': 'NE31 2SP',
#  'A88013': 'NE34 8PS',
#  'A88014': 'NE33 4JP',
#  'A88015': 'NE33 5DU',
#  'A88016': 'NE35 9AN',
#  'A88020': 'NE33 2PG',
#  'A88022': 'NE31 1NU',
#  'A88023': 'SR6 7EE',
#  'A88025': 'NE32 3UX',
#  'A88601': 'NE33 4EG',
#  'A88603': 'NE31 1NU',
#  'A88608': 'NE33 3ET',
#  'A88611': 'NE33 4JP',
#  'A89001': 'SR2 8AD',
#  'A89002': 'SR1 2HJ',
#  'A89003': 'NE38 7NQ',
#  'A89004': 'DH5 9EZ',
#  'A89005': 'SR2 8AX',
#  'A89006': 'SR4 7XF',
#  'A89007': 'SR4 7XF',
#  'A89008': 'SR5 5PS',
#  'A89009': 'DH4 4LE',
#  'A89010': 'NE37 2PU',
#  'A89011': 'SR3 2AN',
#  'A89012': 'NE38 7NQ',
#  'A89013': 'SR1 2QB',
#  'A89014': 'SR6 0AB',
#  'A89015': 'SR6 8DZ',
#  'A89016': 'SR6 0QQ',
#  'A89017': 'SR4 7AF',
#  'A89018': 'SR2 8JG',
#  'A89019': 'SR5 2LT',
#  'A89020': 'SR4 6QE',
#  'A89021': 'DH4 5EQ',
#  'A89022': 'NE37 2PU',
#  'A89023': 'DH4 4DN',
#  'A89024': 'SR3 4HG',
#  'A89025': 'NE38 7NQ',
#  'A89026': 'NE37 2PU',
#  'A89027': 'SR3 4HG',
#  'A89028': 'DH4 4RB',
#  'A89029': 'SR3 1RN',
#  'A89030': 'DH4 4RW',
#  'A89031': 'SR4 7XF',
#  'A89032': 'SR3 2AN',
#  'A89034': 'SR2 7BA',
#  'A89035': 'SR2 0RX',
#  'A89036': 'SR5 3EX',
#  'A89038': 'NE38 7NQ',
#  'A89040': 'SR6 0AB',
#  'A89041': 'SR3 4BY',
#  'A89042': 'SR3 2AW',
#  'A89603': 'SR5 2LT',
#  'A89604': 'SR5 2LT',
#  'A89610': 'SR2 0RY',
#  'A89611': 'SR2 7PF',
#  'A89612': 'SR1 1XW',
#  'A89614': 'SR4 0LS',
#  'A89616': 'NE38 9EH',
#  'A89617': 'NE38 9AB',
#  'B81002': 'HU7 4DW',
#  'B81003': 'DN35 8EB',
#  'B81004': 'HU18 1LP',
#  'B81005': 'DN18 5ER',
#  'B81006': 'YO15 2QW',
#  'B81007': 'DN15 9TA',
#  'B81008': 'HU9 2LJ',
#  'B81009': 'YO43 3FF',
#  'B81010': 'HU13 9LZ',
#  'B81011': 'HU3 5QE',
#  'B81012': 'DN31 3AE',
#  'B81013': 'DN14 6JD',
#  'B81014': 'YO16 4LZ',
#  'B81015': 'DN35 7XE',
#  'B81016': 'DN31 1QZ',
#  'B81017': 'HU3 1TY',
#  'B81018': 'HU6 9BS',
#  'B81019': 'DN32 9SW',
#  'B81020': 'HU7 4PT',
#  'B81021': 'HU6 7ER',
#  'B81022': 'DN16 3LG',
#  'B81023': 'DN31 1QZ',
#  'B81024': 'HU10 6BP',
#  'B81025': 'HU19 2PZ',
#  'B81026': 'DN16 2AB',
#  'B81027': 'HU3 4BB',
#  'B81029': 'DN14 9DY',
#  'B81030': 'DN33 3JF',
#  'B81031': 'DN34 4GB',
#  'B81032': 'HU1 3SA',
#  'B81034': 'HU17 5NL',
#  'B81035': 'HU5 3TJ',
#  'B81036': 'YO42 2BS',
#  'B81037': 'YO25 6EB',
#  'B81038': 'HU4 6RF',
#  'B81039': 'DN40 1JW',
#  'B81040': 'HU9 5HH',
#  'B81041': 'HU15 2UL',
#  'B81042': 'HU17 7BZ',
#  'B81043': 'DN9 1EP',
#  'B81045': 'DN16 2UT',
#  'B81046': 'HU6 9BX',
#  'B81047': 'HU3 1DS',
#  'B81048': 'HU5 2NT',
#  'B81049': 'HU6 8QF',
#  'B81050': 'HU12 8JD',
#  'B81051': 'HU17 8JW',
#  'B81052': 'HU5 3QA',
#  'B81053': 'HU9 4AL',
#  'B81054': 'HU5 2ST',
#  'B81055': 'DN35 0LN',
#  'B81056': 'HU5 5JT',
#  'B81057': 'HU3 6BX',
#  'B81058': 'HU13 0RG',
#  'B81060': 'YO15 2AT',
#  'B81061': 'HU15 1AY',
#  'B81062': 'HU12 8JE',
#  'B81063': 'DN20 8NT',
#  'B81064': 'DN15 7AN',
#  'B81065': 'DN17 3DR',
#  'B81066': 'HU9 3JA',
#  'B81068': 'DN14 6RU',
#  'B81069': 'YO16 4LZ',
#  'B81070': 'YO16 4LZ',
#  'B81072': 'HU5 2NT',
#  'B81074': 'HU9 2LR',
#  'B81075': 'HU5 5BE',
#  'B81077': 'DN34 4GB',
#  'B81080': 'HU8 9RW',
#  'B81081': 'HU9 2LJ',
#  'B81082': 'HU17 7JY',
#  'B81084': 'HU16 4AJ',
#  'B81085': 'HU8 8JS',
#  'B81087': 'DN34 5DX',
#  'B81088': 'DN14 7DD',
#  'B81089': 'HU9 5AD',
#  'B81090': 'DN15 7PG',
#  'B81091': 'DN34 4GB',
#  'B81092': 'YO25 6UH',
#  'B81094': 'HU7 4BJ',
#  'B81095': 'HU6 7HP',
#  'B81097': 'HU9 3JA',
#  'B81099': 'DN21 4PQ',
#  'B81100': 'HU10 6QJ',
#  'B81101': 'HU17 0HB',
#  'B81104': 'HU5 2EG',
#  'B81108': 'DN31 2BH',
#  'B81109': 'DN20 8AS',
#  'B81112': 'HU7 4DW',
#  'B81113': 'DN16 2AB',
#  'B81602': 'HU16 4DA',
#  'B81603': 'DN32 9SW',
#  'B81606': 'DN31 3AE',
#  'B81616': 'HU7 4DW',
#  'B81617': 'DN15 6HX',
#  'B81619': 'HU13 9AJ',
#  'B81620': 'DN35 7DL',
#  'B81622': 'HU17 0HB',
#  'B81628': 'DN38 6HZ',
#  'B81631': 'HU7 5DD',
#  'B81634': 'HU7 4DW',
#  'B81635': 'HU11 4AR',
#  'B81642': 'DN35 0LN',
#  'B81644': 'HU1 3SA',
#  'B81645': 'HU9 3JA',
#  'B81647': 'DN18 5PU',
#  'B81648': 'DN40 3EL',
#  'B81653': 'HU16 4QX',
#  'B81655': 'DN34 4GB',
#  'B81656': 'DN34 5LP',
#  'B81658': 'HU13 0RG',
#  'B81663': 'DN31 2BH',
#  'B81664': 'DN31 3AE',
#  'B81665': 'DN41 7JB',
#  'B81666': 'HU14 3DB',
#  'B81671': 'DN34 5DA',
#  'B82001': 'YO11 1UB',
#  'B82002': 'YO61 3JR',
#  'B82003': 'YO24 4HD',
#  'B82004': 'HG3 5AT',
#  'B82005': 'YO24 3WX',
#  'B82006': 'YO24 4HD',
#  'B82007': 'BD24 9JA',
#  'B82008': 'HG4 1HL',
#  'B82010': 'HG4 2BE',
#  'B82011': 'YO17 8PH',
#  'B82012': 'HG2 8AY',
#  'B82013': 'HG1 5JP',
#  'B82014': 'HG2 7SA',
#  'B82016': 'HG1 5AR',
#  'B82017': 'YO21 1SD',
#  'B82018': 'YO19 6LE',
#  'B82019': 'YO7 3RP',
#  'B82020': 'BD20 7LG',
#  'B82021': 'YO24 4DB',
#  'B82022': 'TS9 6BL',
#  'B82023': 'DL10 7LD',
#  'B82024': 'YO11 3LJ',
#  'B82025': 'YO17 9RF',
#  'B82026': 'YO32 2LL',
#  'B82027': 'HG1 5AR',
#  'B82028': 'BD23 1EU',
#  'B82029': 'DL11 7TH',
#  'B82030': 'HG4 3SE',
#  'B82031': 'LS25 6ED',
#  'B82032': 'YO51 9BD',
#  'B82033': 'YO18 8BL',
#  'B82034': 'DL10 4BB',
#  'B82035': 'DL10 6HB',
#  'B82036': 'HG4 2AX',
#  'B82037': 'YO14 9AE',
#  'B82038': 'YO12 7LB',
#  'B82041': 'YO8 9AJ',
#  'B82042': 'YO7 1LU',
#  'B82044': 'TS9 5DY',
#  'B82045': 'DL8 3QR',
#  'B82046': 'TS13 5AY',
#  'B82047': 'YO10 4DU',
#  'B82049': 'YO7 1LG',
#  'B82050': 'DL7 8FW',
#  'B82053': 'BD23 2HZ',
#  'B82054': 'YO12 6UB',
#  'B82057': 'YO26 8BN',
#  'B82059': 'HG1 4HG',
#  'B82060': 'HG5 0AD',
#  'B82061': 'LA2 7JP',
#  'B82062': 'YO21 1TX',
#  'B82063': 'YO13 9JF',
#  'B82064': 'YO61 1QW',
#  'B82066': 'DL8 2AT',
#  'B82067': 'HG5 0JY',
#  'B82068': 'YO62 5HD',
#  'B82069': 'HG5 0UB',
#  'B82071': 'YO23 3UA',
#  'B82072': 'DL10 4UJ',
#  'B82073': 'LS25 5AA',
#  'B82074': 'YO8 4QH',
#  'B82075': 'DL7 8AW',
#  'B82077': 'YO62 6AR',
#  'B82078': 'DL8 5EP',
#  'B82079': 'YO61 1LL',
#  'B82080': 'YO32 5UA',
#  'B82081': 'YO41 4DY',
#  'B82083': 'YO24 4HD',
#  'B82086': 'YO21 2PA',
#  'B82088': 'YO12 7AS',
#  'B82091': 'HG1 5AR',
#  'B82092': 'YO11 1UB',
#  'B82095': 'YO26 5LD',
#  'B82097': 'YO8 4BL',
#  'B82098': 'YO1 7NP',
#  'B82100': 'YO24 3BZ',
#  'B82101': 'YO22 5DP',
#  'B82103': 'YO31 7YD',
#  'B82104': 'DL9 3JD',
#  'B82105': 'LS24 8HD',
#  'B82609': 'YO62 4EF',
#  'B82611': 'YO12 7RE',
#  'B82619': 'YO60 6PS',
#  'B82622': 'DL11 6SU',
#  'B82628': 'YO14 0NN',
#  'B83002': 'LS29 8TQ',
#  'B83005': 'BD3 7HZ',
#  'B83006': 'BD20 0DG',
#  'B83007': 'BD9 6LL',
#  'B83008': 'BD21 2JH',
#  'B83009': 'BD12 9NG',
#  'B83010': 'BD6 2DD',
#  'B83011': 'BD5 8EL',
#  'B83012': 'BD8 9PB',
#  'B83013': 'BD18 3EE',
#  'B83014': 'BD16 4RP',
#  'B83015': 'BD4 9QA',
#  'B83016': 'BD3 0HX',
#  'B83017': 'BD7 4PL',
#  'B83018': 'BD10 8RU',
#  'B83019': 'LS29 7HG',
#  'B83020': 'BD13 2GD',
#  'B83021': 'BD21 2LD',
#  'B83022': 'BD17 5NH',
#  'B83023': 'BD21 1SA',
#  'B83025': 'BD5 0NX',
#  'B83026': 'BD3 0BS',
#  'B83027': 'BD22 8DH',
#  'B83028': 'BD6 1TD',
#  'B83029': 'BD12 0TH',
#  'B83030': 'BD13 3LG',
#  'B83031': 'BD16 3PA',
#  'B83032': 'BD3 8QH',
#  'B83033': 'BD21 1LA',
#  'B83034': 'BD7 3AH',
#  'B83035': 'BD7 3EG',
#  'B83037': 'BD15 0NJ',
#  'B83038': 'BD9 5PZ',
#  'B83039': 'BD18 1QB',
#  'B83040': 'BD18 4RX',
#  'B83041': 'BD4 7SS',
#  'B83042': 'BD4 7SS',
#  'B83043': 'BD5 8EL',
#  'B83044': 'BD4 9QA',
#  'B83045': 'BD14 6NF',
#  'B83049': 'BD14 6ES',
#  'B83050': 'BD15 7NJ',
#  'B83051': 'BD5 0HR',
#  'B83052': 'BD8 9LB',
#  'B83054': 'BD10 9AZ',
#  'B83055': 'BD7 3JX',
#  'B83056': 'BD2 3AA',
#  'B83058': 'BD3 8QH',
#  'B83061': 'BD22 7HN',
#  'B83062': 'BD10 0JE',
#  'B83063': 'BD18 3EG',
#  'B83064': 'BD2 1QG',
#  'B83067': 'BD16 4RP',
#  'B83069': 'BD8 9DW',
#  'B83070': 'BD7 3HY',
#  'B83602': 'BD21 3AU',
#  'B83604': 'BD8 8RA',
#  'B83611': 'BD3 8QH',
#  'B83613': 'BD8 7SY',
#  'B83614': 'BD8 8RA',
#  'B83617': 'BD8 9DW',
#  'B83620': 'LS29 0LZ',
#  'B83621': 'BD7 3EG',
#  'B83622': 'BD8 9LB',
#  'B83624': 'LS29 8TH',
#  'B83626': 'BD2 4RA',
#  'B83627': 'BD9 4LH',
#  'B83628': 'BD8 7RT',
#  'B83629': 'BD2 4RA',
#  'B83631': 'BD7 2BL',
#  'B83638': 'BD3 0BS',
#  'B83641': 'BD8 9DP',
#  'B83642': 'BD8 9DW',
#  'B84001': 'HX6 3AB',
#  'B84002': 'HX1 4NJ',
#  'B84003': 'HD6 1AT',
#  'B84004': 'HX7 7BZ',
#  'B84005': 'HX1 2HB',
#  'B84006': 'OL14 5RN',
#  'B84007': 'HX6 4BN',
#  'B84008': 'HX3 8AF',
#  'B84009': 'HX4 8BD',
#  'B84010': 'HX2 9LL',
#  'B84011': 'HD6 1AT',
#  'B84012': 'HX1 4JG',
#  'B84013': 'HX2 0QL',
#  'B84014': 'HD6 3NA',
#  'B84016': 'HX5 9BA',
#  'B84017': 'HX5 0AQ',
#  'B84019': 'HX1 2ES',
#  'B84021': 'HX1 3LW',
#  'B84610': 'HX1 5UA',
#  'B84612': 'HX1 5AX',
#  'B84613': 'HX2 8AL',
#  'B84615': 'HX3 9QB',
#  'B84618': 'HX2 8RQ',
#  'B84623': 'HD6 3HT',
#  'B85001': 'BD19 5AP',
#  'B85002': 'HD8 9JL',
#  'B85004': 'WF13 1HN',
#  'B85005': 'HD8 8DJ',
#  'B85006': 'HD9 3TR',
#  'B85008': 'WF17 5ED',
#  'B85009': 'WF13 3JY',
#  'B85010': 'HD5 8DY',
#  'B85011': 'HD7 5JY',
#  'B85012': 'WF16 0HH',
#  'B85014': 'WF16 0HH',
#  'B85015': 'WF17 5DN',
#  'B85016': 'HD1 3UP',
#  'B85018': 'WF17 5SS',
#  'B85019': 'WF14 8DU',
#  'B85020': 'WF13 1HN',
#  'B85021': 'BD19 3RQ',
#  'B85022': 'HD9 6AG',
#  'B85023': 'HD5 8XW',
#  'B85024': 'HD5 9XP',
#  'B85025': 'WF17 9PL',
#  'B85026': 'HD8 0SJ',
#  'B85027': 'HD3 3DY',
#  'B85028': 'HD2 2QA',
#  'B85030': 'BD19 5AP',
#  'B85031': 'HD8 0HH',
#  'B85032': 'HD9 5QQ',
#  'B85033': 'HD3 3JD',
#  'B85036': 'HD3 4LB',
#  'B85037': 'HD4 6JE',
#  'B85038': 'WF12 0DH',
#  'B85041': 'WF17 7PF',
#  'B85042': 'HD1 4TS',
#  'B85044': 'HD1 3SB',
#  'B85048': 'HD2 1DH',
#  'B85051': 'HD7 4QQ',
#  'B85054': 'HD7 6DF',
#  'B85055': 'WF13 4HT',
#  'B85058': 'HD1 5PU',
#  'B85059': 'HD7 5AB',
#  'B85060': 'HD1 5PX',
#  'B85061': 'HD8 9DA',
#  'B85606': 'WF12 9DW',
#  'B85610': 'HD9 3TP',
#  'B85611': 'HD2 1AE',
#  'B85612': 'WF15 6DF',
#  'B85614': 'HD1 6DZ',
#  'B85619': 'WF16 9LQ',
#  'B85620': 'WF12 7BD',
#  'B85621': 'BD19 5AN',
#  'B85622': 'WF17 5QT',
#  'B85623': 'HD1 4LE',
#  'B85634': 'HD2 2YD',
#  'B85636': 'HD1 4QR',
#  'B85638': 'HD7 4AQ',
#  'B85640': 'WF17 9HE',
#  'B85641': 'HD1 3XH',
#  'B86001': 'LS27 9NB',
#  'B86002': 'LS11 8LH',
#  'B86003': 'LS12 3HD',
#  'B86004': 'LS16 7RX',
#  'B86005': 'LS11 5HT',
#  'B86006': 'LS26 0AG',
#  'B86007': 'LS14 5JS',
#  'B86008': 'LS17 5DT',
#  'B86009': 'LS15 8BZ',
#  'B86010': 'LS22 5BQ',
#  'B86011': 'LS28 7QR',
#  'B86012': 'LS11 8SU',
#  'B86013': 'LS17 6PZ',
#  'B86014': 'LS28 7DE',
#  'B86015': 'LS13 2UP',
#  'B86016': 'LS9 9EF',
#  'B86017': 'LS6 2RX',
#  'B86018': 'LS28 7XP',
#  'B86019': 'LS7 3DR',
#  'B86020': 'WF3 3SA',
#  'B86022': 'LS8 3BZ',
#  'B86023': 'LS17 7BE',
#  'B86024': 'LS12 1HU',
#  'B86025': 'LS6 1SG',
#  'B86028': 'LS27 9EW',
#  'B86029': 'LS21 3HD',
#  'B86030': 'LS6 2AF',
#  'B86031': 'LS7 3EX',
#  'B86032': 'LS21 1BQ',
#  'B86033': 'LS22 6RT',
#  'B86034': 'LS23 6PY',
#  'B86035': 'LS10 2PT',
#  'B86036': 'LS25 7JN',
#  'B86037': 'LS25 7JU',
#  'B86038': 'LS19 7PS',
#  'B86039': 'LS7 4LF',
#  'B86041': 'LS5 3QT',
#  'B86042': 'LS10 3NB',
#  'B86043': 'LS9 9JD',
#  'B86044': 'LS16 6FR',
#  'B86047': 'LS19 6DD',
#  'B86048': 'LS25 1HB',
#  'B86049': 'LS6 2SF',
#  'B86050': 'LS28 5PL',
#  'B86051': 'LS19 7JN',
#  'B86052': 'LS20 8AR',
#  'B86054': 'LS9 9EF',
#  'B86055': 'LS15 8BA',
#  'B86056': 'LS17 8AE',
#  'B86057': 'LS27 9NB',
#  'B86058': 'LS28 6DR',
#  'B86059': 'LS6 4JN',
#  'B86060': 'LS12 1JE',
#  'B86061': 'LS8 4HQ',
#  'B86062': 'LS14 6DX',
#  'B86064': 'WF3 1RQ',
#  'B86066': 'LS8 1AY',
#  'B86067': 'LS27 9EN',
#  'B86068': 'LS5 3JN',
#  'B86069': 'LS4 2EL',
#  'B86070': 'LS19 7JN',
#  'B86071': 'LS12 5SG',
#  'B86074': 'LS18 4JY',
#  'B86075': 'LS15 9JB',
#  'B86077': 'LS26 0UE',
#  'B86081': 'LS9 6AU',
#  'B86086': 'LS6 3DS',
#  'B86089': 'WF10 2DP',
#  'B86092': 'LS25 7AB',
#  'B86093': 'LS14 1HX',
#  'B86094': 'LS28 9AP',
#  'B86095': 'LS11 9RE',
#  'B86096': 'LS10 2JJ',
#  'B86100': 'LS7 3JT',
#  'B86101': 'LS27 7HL',
#  'B86102': 'LS9 8RZ',
#  'B86103': 'LS8 5DE',
#  'B86104': 'LS13 2BL',
#  'B86106': 'LS14 6GG',
#  'B86107': 'LS17 5DT',
#  'B86623': 'LS8 5BS',
#  'B86625': 'LS22 6JS',
#  'B86633': 'LS10 2PT',
#  'B86638': 'LS9 7RD',
#  'B86642': 'LS10 2PE',
#  'B86643': 'LS8 5AN',
#  'B86648': 'LS15 8NN',
#  'B86651': 'LS8 4HA',
#  'B86654': 'LS8 4AA',
#  'B86655': 'LS13 4JH',
#  'B86658': 'LS25 1AN',
#  'B86666': 'LS7 3JT',
#  'B87001': 'WF4 4PA',
#  'B87002': 'WF4 5BY',
#  'B87003': 'WF7 7HZ',
#  'B87004': 'WF1 4PR',
#  'B87005': 'WF10 1PH',
#  'B87006': 'WF9 3AP',
#  'B87007': 'WF8 1NF',
#  'B87008': 'WF2 8FE',
#  'B87009': 'WF7 5HE',
#  'B87011': 'WF8 1SU',
#  'B87012': 'WF1 5PN',
#  'B87013': 'WF1 2PE',
#  'B87015': 'WF8 4PQ',
#  'B87016': 'WF9 2RD',
#  'B87017': 'WF1 1PG',
#  'B87018': 'WF10 4EN',
#  'B87019': 'WF3 4HS',
#  'B87020': 'WF2 7GP',
#  'B87021': 'WF11 0JA',
#  'B87022': 'WF2 9PE',
#  'B87023': 'WF10 3TG',
#  'B87025': 'WF10 1DP',
#  'B87026': 'WF9 4DP',
#  'B87027': 'WF1 3JQ',
#  'B87028': 'WF4 1HJ',
#  'B87029': 'SK5 6ET',
#  'B87030': 'WF11 8NQ',
#  'B87031': 'WF5 8DF',
#  'B87032': 'WF7 6JL',
#  'B87033': 'WF6 1QD',
#  'B87036': 'WF9 3AP',
#  'B87039': 'WF6 2AZ',
#  'B87040': 'WF5 8DF',
#  'B87041': 'WF6 2EP',
#  'B87042': 'WF10 2QP',
#  'B87044': 'WF2 0DP',
#  'B87600': 'WF6 2BU',
#  'B87602': 'WF6 2JZ',
#  'B87604': 'WF1 4SD',
#  'C81001': 'S43 4PL',
#  'C81002': 'S21 4BZ',
#  'C81003': 'SK22 4BP',
#  'C81004': 'DE5 3TH',
#  'C81005': 'DE55 1LU',
#  'C81006': 'DE1 1TH',
#  'C81007': 'DE1 1FW',
#  'C81008': 'S45 9NR',
#  'C81009': 'DE1 1PG',
#  'C81010': 'NG10 1QQ',
#  'C81012': 'S40 2AB',
#  'C81013': 'DE45 1SP',
#  'C81014': 'DE21 6AT',
#  'C81015': 'S41 8DU',
#  'C81016': 'DE45 1ED',
#  'C81017': 'DE7 6AX',
#  'C81018': 'DE6 5HY',
#  'C81019': 'DE1 1TH',
#  'C81020': 'DE11 0HU',
#  'C81021': 'DE7 8ES',
#  'C81022': 'DE7 5PZ',
#  'C81023': 'NG10 1RY',
#  'C81025': 'S18 1PY',
#  'C81026': 'NG10 5HZ',
#  'C81027': 'DE55 4JJ',
#  'C81028': 'DE4 3NL',
#  'C81029': 'DE55 5PS',
#  'C81030': 'DE4 2SA',
#  'C81031': 'DE75 7DX',
#  'C81032': 'DE11 0PP',
#  'C81033': 'NG20 8DG',
#  'C81034': 'SK17 6JP',
#  'C81035': 'DE23 8AL',
#  'C81036': 'DE1 1DZ',
#  'C81037': 'DE6 1DR',
#  'C81038': 'DE56 0JB',
#  'C81039': 'S32 5QH',
#  'C81040': 'DE22 2DS',
#  'C81041': 'S44 6DF',
#  'C81042': 'DE3 0HA',
#  'C81044': 'S41 8NA',
#  'C81045': 'S40 4AA',
#  'C81046': 'DE7 6GR',
#  'C81047': 'DE24 0GE',
#  'C81048': 'DE56 4GG',
#  'C81049': 'DE75 7HA',
#  'C81050': 'DE55 2AA',
#  'C81051': 'DE21 6LA',
#  'C81052': 'DE75 7AL',
#  'C81053': 'DE55 7AH',
#  'C81054': 'DE23 3TX',
#  'C81055': 'S42 5ND',
#  'C81056': 'S45 9NG',
#  'C81057': 'DE65 6QT',
#  'C81058': 'S43 1JG',
#  'C81059': 'DE5 3HR',
#  'C81060': 'DE11 7JG',
#  'C81061': 'DE7 5PR',
#  'C81062': 'DE4 4JG',
#  'C81063': 'SK23 0RH',
#  'C81064': 'DE22 2QN',
#  'C81065': 'SK17 9BZ',
#  'C81066': 'DE72 3HG',
#  'C81067': 'S40 3PY',
#  'C81068': 'DE21 7RJ',
#  'C81069': 'DE56 1AY',
#  'C81070': 'S18 2EJ',
#  'C81071': 'DE23 8JX',
#  'C81072': 'DE23 8RJ',
#  'C81073': 'DE1 1JX',
#  'C81074': 'SK17 9AY',
#  'C81075': 'DE6 3BX',
#  'C81076': 'SK17 8NS',
#  'C81077': 'SK13 7DE',
#  'C81080': 'SK23 7SR',
#  'C81081': 'SK13 8PS',
#  'C81082': 'SK17 0AQ',
#  'C81083': 'NG10 1RY',
#  'C81084': 'S40 1LE',
#  'C81086': 'DE6 1RR',
#  'C81087': 'DE24 8GT',
#  'C81089': 'S18 8QY',
#  'C81090': 'DE7 5PZ',
#  'C81091': 'S21 1DX',
#  'C81092': 'S33 6RJ',
#  'C81094': 'DE4 5PB',
#  'C81095': 'S21 3TY',
#  'C81096': 'S80 4DY',
#  'C81097': 'NG10 4NP',
#  'C81099': 'DE55 7DW',
#  'C81100': 'DE24 8QJ',
#  'C81101': 'DE4 3FD',
#  'C81104': 'DE12 6JF',
#  'C81106': 'SK13 1DJ',
#  'C81108': 'DE73 8EF',
#  'C81110': 'DE65 5GZ',
#  'C81113': 'DE3 9BJ',
#  'C81114': 'DE11 9JT',
#  'C81115': 'DE7 5QS',
#  'C81118': 'DE23 6QQ',
#  'C81604': 'DE7 5AN',
#  ...}

# %%
len(practice_postal)
# Out:
# 10843

# %% [markdown]
# **Challenge:** This is an aggregation of the practice data grouped by practice codes. Write an alternative implementation of the above cell using the `group_by_field` function you defined previously.

# %%
assert practice_postal['K82019'] == 'HP21 8TR'

# %% [markdown]
# Now we can join `practice_postal` to `scripts`.

# %%
joined = scripts[:] #creates a copy of the script list
for script in joined:
    script['post_code'] = practice_postal[script['practice']]

# %% [markdown]
# Finally we'll group the prescription dictionaries in `joined` by `'post_code'` and sum up the items prescribed in each group, as we did in the previous question.

# %%
items_by_post = sorted([ (k[0], sum(member['items'] for member in group )) for k, group in group_by_field(joined, ('post_code',)).items() ])

# %%
items_by_post[:8]
# Out:
# [('B11 4BW', 20673),
#  ('B18 7AL', 19001),
#  ('B21 9RY', 29103),
#  ('B23 6DJ', 24859),
#  ('B70 7AW', 36531),
#  ('BB11 2DL', 34356),
#  ('BB2 1AX', 28254),
#  ('BB3 1PY', 54514)]

# %%
# postal_totals = [('B11 4BW', 20673)] * 100

postal_totals = items_by_post[:100]

grader.score.pw__postal_totals(postal_totals)
# Out:
# ==================
# Your score: 1.000
# ==================

# %% [markdown]
# ## Question 4: items_by_region
#
# Now we'll combine the techniques we've developed to answer a more complex question. Find the most commonly dispensed item in each postal code, representing the results as a list of tuples (`post_code`, `bnf_name`, amount dispensed as proportion of total). Sort your results ascending alphabetically by post code and take only results from the first 100 post codes.
#
# **NOTE:** We'll continue to use the `joined` variable we created before, where we've chosen the alphabetically first postal code for each practice. Additionally, some postal codes will have multiple `'bnf_name'` with the same number of items prescribed for the maximum. In this case, we'll take the alphabetically first `'bnf_name'`.
#
# There are several approaches to solve this problem but we will guide you through one of them. Feel free to solve it your own way if it is easier for you to understand and implement. If your kernel keeps on dying, it's probably an indication that you are running out of memory. Consider deleting objects you don't need anymore using the `del` statement and shutdown any other running notebooks. For example:
# ```Python
# del some_object_not_needed
# ```

# %% [markdown]
# The first step is to calculate the total items for each `'post_code'` and `'bnf_name'`. Let's call that result `total_items_by_post_bnf`. Consider what is the best data structure(s) to represent `total_items_by_post_bnf`. It should have 141196 `('post_code', 'bnf_name')` groups.

# %%
grouped_by_post_bnf = group_by_field(joined, ('post_code', 'bnf_name',))

# %%
grouped_by_post_bnf[('BH18 8EE', 'Permethrin_Crm 5%')]
# Out:
# [{'bnf_code': '1310040Q0AAABAB',
#   'items': 7,
#   'practice': 'J81041',
#   'bnf_name': 'Permethrin_Crm 5%',
#   'nic': 96.98,
#   'act_cost': 89.87,
#   'quantity': 390,
#   'post_code': 'BH18 8EE'},
#  {'bnf_code': '1310040Q0AAABAB',
#   'items': 1,
#   'practice': 'J81046',
#   'bnf_name': 'Permethrin_Crm 5%',
#   'nic': 59.68,
#   'act_cost': 55.26,
#   'quantity': 240,
#   'post_code': 'BH18 8EE'}]

# %%
total_items_by_post_bnf = []

for key, value in grouped_by_post_bnf.items():
    new_item = {'post_code': key[0],
               'bnf_name': key[1],
                'total': sum(v['items'] for v in value) }
    total_items_by_post_bnf.append(new_item)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-5f045a2e1106> in <module>
# ----> 1 calc_fields(('DA11 8BZ',), grouped_post_code[('DA11 8BZ',)])
#
# <ipython-input-78-d9f77c7c54f3> in calc_fields(group, data)
#       3     #Goal is to Return a tuple of the form(post_code, bnf_name, max_proportion) where post_code is taken from the group, bnf_name and
#       4     #max_proportion are determined fromthe information in data
# ----> 5     arg_max = sorted(data, keys=lambda x: x['total'], reverse=True)[0]
#       6     return arg_max
#
# TypeError: 'keys' is an invalid keyword argument for sort()

# %%
total_items_by_post_bnf = []

for key, value in grouped_by_post_bnf.items():
    new_item = {'post_code' : key[0],
               'bnf_name' : key[1],
               'total': sum(v['items'] for v in value)}
    total_items_by_post_bnf.append(new_item)

# %%
total_items_by_post_bnf[:4]
# Out:
# [{'post_code': 'BH23 3AF', 'bnf_name': 'Paracet_Tab Solb 500mg', 'total': 49},
#  {'post_code': 'TS23 2DG',
#   'bnf_name': 'K-Soft 10cm x 3.5m M/Layer Compress Band',
#   'total': 4},
#  {'post_code': 'M30 0NU', 'bnf_name': 'Quinine Bisulf_Tab 300mg', 'total': 44},
#  {'post_code': 'SR4 7XF',
#   'bnf_name': 'Oilatum Jnr_Bath Additive',
#   'total': 14}]

# %%
assert len(total_items_by_post_bnf) == 141196

# %% [markdown]
# Next, let's take `total_items_by_post_bnf` and group it by `'post_code'`. In other words, we want a  data structure that maps a `'post_code'` to a list of all records that belong to that `'post_code'`. There should be 118 groups.

# %%
grouped_post_code = group_by_field(total_items_by_post_bnf, ('post_code',))

assert len(grouped_post_code) == 118

# %%
print(grouped_post_code)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Now with `grouped_post_code`, let's iterate over each group and calculate the following fields for each `'post_code'`:
# 1. the sum of total items for all `'bnf_name'`
# 1. the most total items
# 1. the `'bnf_name'` that had the most total items
#
# Once again, consider the best data structure(s) to use to represent the result. It may help to write and use a function when developing your solution.

# %%
def calc_fields(group, data):
    #data is a list of dictionaries from grouped_post_code collection group is going to be a tuple(post_code,)
    #Goal is to Return a tuple of the form(post_code, bnf_name, max_proportion) where post_code is taken from the group, bnf_name and
    #max_proportion are determined fromthe information in data
    arg_max = sorted(data, key=lambda x: x['total'], reverse=True)[0]
    
    post_code = group[0]
    bnf_name = arg_max['bnf_name']
    bnf_name_total = arg_max['total'] #numerator in max proportion
    total_in_post_code = sum(d['total'] for d in data) #denominator in max proportion
    
    return (post_code, bnf_name, bnf_name_total/total_in_post_code)

# %%
calc_fields(('DA11 8BZ',), grouped_post_code[('DA11 8BZ',)])
# Out:
# ('DA11 8BZ', 'Amoxicillin_Cap 500mg', 0.021502698215026983)

# %%
most_item_data_by_post = [calc_fields(group, data) for group, data in grouped_post_code.items()]

# %%
most_item_data_by_post
# Out:
# [('TW13 4GU', 'Omeprazole_Cap E/C 20mg', 0.03073937908496732),
#  ('SS0 7AF', 'Omeprazole_Cap E/C 20mg', 0.02118781584681719),
#  ('NE37 2PU', 'Paracet_Tab 500mg', 0.02777391304347826),
#  ('LE10 1DS', 'Aspirin Disper_Tab 75mg', 0.02211411776629168),
#  ('S63 9EH', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.03003995745537126),
#  ('M30 0NU', 'Omeprazole_Cap E/C 20mg', 0.03824666953158573),
#  ('BB9 7SR', 'Omeprazole_Cap E/C 20mg', 0.023833193804939305),
#  ('TS1 2NX', 'Paracet_Tab 500mg', 0.027549713373789975),
#  ('TS23 2DG', 'Paracet_Tab 500mg', 0.025532452758642483),
#  ('WN3 5HL', 'Omeprazole_Cap E/C 20mg', 0.046486243539118434),
#  ('W10 6DZ', 'Amoxicillin_Cap 500mg', 0.029451549434333497),
#  ('CW7 1AT', 'Omeprazole_Cap E/C 20mg', 0.038342136965990176),
#  ('BB2 1AX', 'Omeprazole_Cap E/C 20mg', 0.03645501521908402),
#  ('DN34 4GB', 'Omeprazole_Cap E/C 20mg', 0.03894778497490263),
#  ('CV1 4FS', 'Omeprazole_Cap E/C 20mg', 0.02988443966675625),
#  ('LA1 1PN', 'Omeprazole_Cap E/C 20mg', 0.03593535438892997),
#  ('B23 6DJ', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.024095900880968663),
#  ('B70 7AW', 'Paracet_Tab 500mg', 0.0266896608360023),
#  ('CH65 6TG', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.027421283379832604),
#  ('LE5 3GH', 'Metformin HCl_Tab 500mg', 0.0354924268862986),
#  ('CW1 3AW', 'Omeprazole_Cap E/C 20mg', 0.03687757394234369),
#  ('FY2 0JG', 'Omeprazole_Cap E/C 20mg', 0.03794959344888452),
#  ('WN2 5NG', 'Omeprazole_Cap E/C 20mg', 0.04119324413248519),
#  ('N9 7HD', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.026281508499967434),
#  ('SE15 5LJ', 'Metformin HCl_Tab 500mg', 0.02451173155066195),
#  ('HA0 4UZ', 'Metformin HCl_Tab 500mg', 0.02961986376620523),
#  ('L5 0QW', 'Omeprazole_Cap E/C 20mg', 0.03383854757659264),
#  ('BB8 0JZ', 'Atorvastatin_Tab 20mg', 0.022563442442074293),
#  ('TS10 4NW', 'Paracet_Tab 500mg', 0.023228006465755853),
#  ('SS8 0JA', 'Omeprazole_Cap E/C 20mg', 0.026893212353864944),
#  ('BL3 5HP', 'Omeprazole_Cap E/C 20mg', 0.03359487236158692),
#  ('WS10 8SY', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.02675027782187649),
#  ('B21 9RY', 'Metformin HCl_Tab 500mg', 0.03549462254750369),
#  ('KT6 6EZ', 'Omeprazole_Cap E/C 20mg', 0.029557408595253368),
#  ('CB9 8HF', 'Omeprazole_Cap E/C 20mg', 0.03586107485828934),
#  ('LE18 2EW', 'Lansoprazole_Cap 15mg (E/C Gran)', 0.026545337066551798),
#  ('PL7 1AD', 'Omeprazole_Cap E/C 20mg', 0.03856973759050591),
#  ('ST3 6AB', 'Omeprazole_Cap E/C 20mg', 0.03128794729363132),
#  ('BL9 0NJ', 'Omeprazole_Cap E/C 20mg', 0.033622356683924895),
#  ('YO16 4LZ', 'Aspirin Disper_Tab 75mg', 0.022947416974169743),
#  ('NE24 1DX', 'Paracet_Tab 500mg', 0.0320651205165277),
#  ('TW8 8DS', 'Omeprazole_Cap E/C 20mg', 0.040050480680004455),
#  ('OL11 1DN', 'Omeprazole_Cap E/C 20mg', 0.032178791672462556),
#  ('CT11 8AD', 'Omeprazole_Cap E/C 20mg', 0.02371612786870463),
#  ('BB7 2JG', 'Omeprazole_Cap E/C 20mg', 0.029471795446899183),
#  ('WA9 1LN', 'Lansoprazole_Cap 15mg (E/C Gran)', 0.021319659964917016),
#  ('S65 1DA', 'Influenza_Vac Inact 0.5ml Pfs', 0.023771326534882748),
#  ('TS24 7PW', 'Paracet_Tab 500mg', 0.03858642431322693),
#  ('DA1 2HA', 'Omeprazole_Cap E/C 20mg', 0.020977948226270374),
#  ('SE1 6JP', 'Metformin HCl_Tab 500mg', 0.023339995558516544),
#  ('RM3 9SU', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.027516093578269743),
#  ('M26 2SP', 'Omeprazole_Cap E/C 20mg', 0.04085582480513283),
#  ('WN7 2PE', 'Omeprazole_Cap E/C 20mg', 0.041504539559014265),
#  ('BB3 1PY', 'Omeprazole_Cap E/C 20mg', 0.03428477088454342),
#  ('NW10 8RY', 'Metformin HCl_Tab 500mg', 0.030900570686215375),
#  ('SM3 8EP', 'Omeprazole_Cap E/C 20mg', 0.02976166633286601),
#  ('HG1 5AR', 'Omeprazole_Cap E/C 20mg', 0.030014686084934523),
#  ('SK11 6JL', 'Omeprazole_Cap E/C 20mg', 0.029244760200234393),
#  ('BL9 0SN', 'Omeprazole_Cap E/C 20mg', 0.03257264351523742),
#  ('SR4 7XF', 'Paracet_Tab 500mg', 0.03414722227795277),
#  ('NE10 9QG', 'Paracet_Tab 500mg', 0.044305701820370094),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.03415082474725487),
#  ('WV13 2DR', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.023903793877792224),
#  ('WN7 1HR', 'Omeprazole_Cap E/C 20mg', 0.03693768056128766),
#  ('DA11 8BZ', 'Amoxicillin_Cap 500mg', 0.021502698215026983),
#  ('BD3 8QH', 'Atorvastatin_Tab 40mg', 0.03422179914326511),
#  ('FY5 2TZ', 'Omeprazole_Cap E/C 20mg', 0.037575127660535945),
#  ('TN34 1BA', 'Omeprazole_Cap E/C 20mg', 0.03102866779089376),
#  ('GL1 3PX', 'Omeprazole_Cap E/C 20mg', 0.027334732423924448),
#  ('L36 7XY', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0304811669932506),
#  ('LN2 2JP', 'Omeprazole_Cap E/C 20mg', 0.036189981157819504),
#  ('TS17 0EE', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.025048254079663098),
#  ('OL4 1YN', 'Omeprazole_Cap E/C 20mg', 0.02989427633977397),
#  ('SK6 1ND', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.019072510860735352),
#  ('KT14 6DH', 'Amlodipine_Tab 5mg', 0.01980716047537185),
#  ('NN16 8DN', 'Omeprazole_Cap E/C 20mg', 0.03547300624372181),
#  ('OL1 1NL', 'Omeprazole_Cap E/C 20mg', 0.033425912390975976),
#  ('SS9 5UU', 'Influvac Sub-Unit_Vac 0.5ml Pfs', 0.02536884460624641),
#  ('TW3 3LN', 'Omeprazole_Cap E/C 20mg', 0.02742831518895892),
#  ('S74 9AF', 'Omeprazole_Cap E/C 20mg', 0.035946116987614136),
#  ('SM6 0HY', 'Omeprazole_Cap E/C 20mg', 0.03170636300417246),
#  ('LS9 9EF', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.03184116875819442),
#  ('GL50 4DP', 'Omeprazole_Cap E/C 20mg', 0.02469861805351367),
#  ('BL1 8TU', 'Omeprazole_Cap E/C 20mg', 0.03095821215368131),
#  ('WA7 1AB', 'Omeprazole_Cap E/C 20mg', 0.041487147214019464),
#  ('M11 4EJ', 'Omeprazole_Cap E/C 20mg', 0.03207286540619874),
#  ('WD18 0JP', 'Omeprazole_Cap E/C 20mg', 0.032471237044784634),
#  ('DN22 7XF', 'Simvastatin_Tab 40mg', 0.019888143695899377),
#  ('FY4 1TJ', 'Omeprazole_Cap E/C 20mg', 0.04512928155710333),
#  ('TN24 0GP', 'Amoxicillin_Cap 500mg', 0.08493069890887643),
#  ('WS3 3JP', 'Paracet_Tab 500mg', 0.022388059701492536),
#  ('NG7 5HY', 'Paracet_Tab 500mg', 0.02509737782596474),
#  ('HU7 4DW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.026594986458142424),
#  ('SR5 2LT', 'Paracet_Tab 500mg', 0.03603964806771355),
#  ('B18 7AL', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.02926161780958897),
#  ('BB4 5SL', 'Omeprazole_Cap E/C 20mg', 0.040696883081529876),
#  ('NG7 3GW', 'Paracet_Tab 500mg', 0.022318906091083737),
#  ('L7 6HD', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.026874016302943456),
#  ('NE38 7NQ', 'Paracet_Tab 500mg', 0.031134594625305382),
#  ('HA3 7LT', 'Omeprazole_Cap E/C 20mg', 0.0265001712702021),
#  ('BH23 3AF', 'Omeprazole_Cap E/C 20mg', 0.03733292364418497),
#  ('ST8 6AG', 'Omeprazole_Cap E/C 20mg', 0.03963379302352532),
#  ('CH1 4DS', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.026979808105398826),
#  ('TS3 6AL', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.026963931364538344),
#  ('WA10 2DJ', 'Lansoprazole_Cap 15mg (E/C Gran)', 0.019433579244442244),
#  ('ME8 8AA', 'Omeprazole_Cap E/C 20mg', 0.02328067466444946),
#  ('CW5 5NX', 'Omeprazole_Cap E/C 20mg', 0.036574992911823076),
#  ('OL9 7AY', 'Omeprazole_Cap E/C 20mg', 0.03317602310347256),
#  ('TR1 2JA', 'Omeprazole_Cap E/C 20mg', 0.04630044285216699),
#  ('GU9 9QS', 'Omeprazole_Cap E/C 20mg', 0.028601661946406898),
#  ('BB11 2DL', 'Omeprazole_Cap E/C 20mg', 0.02884503434625684),
#  ('L31 0DJ', 'Omeprazole_Cap E/C 20mg', 0.031093092156556992),
#  ('WF13 1HN', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.021566624764299182),
#  ('FY7 8GU', 'Omeprazole_Cap E/C 20mg', 0.03420067879209816),
#  ('BH18 8EE', 'Omeprazole_Cap E/C 20mg', 0.029000583563798747),
#  ('SS13 3HQ', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.025575779606885986),
#  ('M35 0AD', 'Omeprazole_Cap E/C 20mg', 0.03085140306122449),
#  ('ST1 4PB', 'Omeprazole_Cap E/C 20mg', 0.029595079869567012)]

# %% [markdown]
# Now, we are ready to:
# 1. calculate the ratio (the amount dispensed as proportion of total)
# 1. [sort](https://docs.python.org/3/howto/sorting.html) alphabetically by the post code
# 1. format the answer as a list of tuples
# 1. take only the first 100 tuples
# 1. submit to the grader

# %%
items_by_region = sorted(most_item_data_by_post)[:100]

# %%
len(items_by_region)
# Out:
# 100

# %%
# items_by_region = [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247)] * 100

# %%
grader.score.pw__items_by_region(items_by_region)
# Out:
# ==================
# Your score: 1.000
# ==================

# %% [markdown]
# *Copyright &copy; 2021 WorldQuant University. This content is licensed solely for personal use. Redistribution or publication of this material is strictly prohibited.*
